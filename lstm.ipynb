# %% [markdown]
# <center><b>IMPLEMENTING LSTM USING NUMPY</b><center>
# <hr>
# <ul>
# <li>https://agustinus.kristia.de/techblog/2016/08/12/lstm-backprop/</li>
# <li>https://www.youtube.com/watch?v=8HyCNIVRbSU&ab_channel=TheA.I.Hacker-MichaelPhi</li>

# %%
with open('./shakespeare.txt', 'r') as file:
    data = file.read()

vocab = list(set(data))
ix_to_char = {i:ch for i, ch in enumerate(vocab)}
char_to_ix = {ch:i for i, ch in enumerate(vocab)}

data_size = len(data)
vocab_size = len(vocab)

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
import numpy as np 
W = {}
W['Wf'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wi'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wo'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wc'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wy'] = np.random.randn(hidden_size, vocab_size)*0.01

W['bf'] = np.zeros((1,hidden_size))
W['bi'] = np.zeros((1,hidden_size))
W['bo'] = np.zeros((1,hidden_size))
W['bc'] = np.zeros((1,hidden_size))
W['by'] = np.zeros((1,vocab_size))

# %%
def encode(char, vocab_size):
    one_hot = np.zeros((1,vocab_size))
    one_hot[:,char_to_ix[char]] = 1
    return one_hot

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def forward(xs, W, hs, cs):
    X = np.column_stack((hs, xs))
    hf = sigmoid(np.dot(X, W['Wf']) + W['bf'])
    hi = sigmoid(np.dot(X, W['Wi']) + W['bi'])
    ho = sigmoid(np.dot(X, W['Wo']) + W['bo'])
    hc = sigmoid(np.dot(X, W['Wc']) + W['bc'])
    cs = hf*cs + hi*hc
    hs = ho*np.tanh(cs)
    ys = np.dot(hs, W['Wy']) + W['by']
    ps = np.exp(ys)
    ps = ps/np.sum(ps)

    return hf, hi, ho, hc, hs, cs, ys, ps

# %%
def one_step(input_char, target_char, W, vocab_size, hs, cs):
    xs = encode(char=input_char, vocab_size=vocab_size)
    hf, hi, ho, hc, hs, cs, ys, ps = forward(xs, W, hs, cs)
    loss = -np.log(ps[:,char_to_ix[target_char]])
    return xs, hf, hi, ho, hc, hs, cs, ys, ps, loss

# %%
def step(inputs, targets, W, vocab_size, hs, cs):
    loss = 0 
    xs, hf, hi, ho, hc, hs, ys, ps, cs = {}, {}, {}, {}, {}, {}, {}, {}, {}
    hs[-1] = np.zeros((1,hidden_size))
    cs[-1] = np.zeros((1,hidden_size))

    for t in range(len(inputs)):
        input_char = inputs[t]
        target_char = targets[t]
        xs[t], hf[t], hi[t], ho[t], hc[t], hs[t], cs[t], ys[t], ps[t], step_loss = one_step(input_char=input_char,
                                                                target_char=target_char,
                                                                W=W,
                                                                vocab_size=vocab_size,
                                                                hs=hs[t-1],
                                                                cs=cs[t-1])
        loss+=step_loss

    return xs, hf, hi, ho, hc, hs, cs, ys, ps, loss

# %%
def clip_grad(grads):
    for grad in grads.keys():
        grads[grad] = np.clip(grads[grad], -5, 5)
    return grads

# %%
def grad(W, xs, hf, hi, ho, hc, hs, cs, ps, targets):
    grads = {}
    for key in W.keys():
        grads[key] = np.zeros_like(W[key])
    
    dhnext = np.zeros_like(hs[0])
    dcnext = np.zeros_like(cs[0])

    for t in reversed(range(len(targets))):
        target_char = targets[t]
        dy = np.copy(ps[t])
        dy[:,char_to_ix[target_char]]-=1

        grads['Wy']+=np.dot(hs[t].T, dy)
        grads['by']+=dy

        dh = np.dot(dy, W['Wy'].T) + dhnext
        
        # Gradient wrt ho
        dho = np.tanh(cs[t])*dh
        dho = sigmoid(ho[t])*(1-sigmoid(ho[t]))*dho

        # Gradient wrt cs
        dc = ho[t]*np.tanh(cs[t])*dh + dcnext

        # Gradient wrt hf
        dhf = sigmoid(hf[t])*(1-sigmoid(hf[t]))*cs[t-1]*dc

        # Gradient wrt hi
        dhi = sigmoid(hi[t])*(1-sigmoid(hi[t]))*hc[t]*dc

        # Gradient wrt ci
        dhc = (1-np.tanh(hc[t])**2)*hi[t]*dc

        X = np.column_stack((hs[t], xs[t]))

        grads['Wf']+=np.dot(X.T, dhf)
        grads['bf']+=dhf
        dXf = np.dot(dhf, W['Wf'].T)

        grads['Wi']+=np.dot(X.T, dhi)
        grads['bi']+=dhi
        dXi = np.dot(dhi, W['Wi'].T)

        grads['Wo']+=np.dot(X.T, dho)
        grads['bo']+=dho
        dXo = np.dot(dho, W['Wo'].T)

        grads['Wc']+=np.dot(X.T, dhc)
        grads['bc']+=dhc
        dXc = np.dot(dhc, W['Wc'].T)

        dcnext = hf[t]*dc
        dhnext = dXf + dXi + dXc + dXo
        dhnext = dhnext[:,:hidden_size]


    grads = clip_grad(grads)

    return grads

# %%
def sample(hs, cs, xs, n, W, vocab_size):
    xs = encode(xs, vocab_size)
    outputs = []

    for t in range(n):
        _, _, _, _, hs, cs, _, p = forward(xs, W, hs, cs)
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        outputs.append(ix_to_char[ix])
        xs = np.zeros_like(xs)
        xs[:,ix]=1

    return outputs

# %%
n,p = 0,0
mVars = {}
for key in W.keys():
  mVars[key] = np.zeros_like(W[key])

smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hs = np.zeros((1,hidden_size)) # reset RNN memory
    cs = np.zeros((1,hidden_size))
    p = 0 # go from start of data
  inputs = data[p:p+seq_length]
  targets = data[p+1:p+seq_length+1]

  # sample from the model now and then
  if n % 100 == 0:
    txt = sample(hs, cs, inputs[0], 200, W, vocab_size)
    txt = ''.join(txt)
    print(txt)

  # forward seq_length characters through the net and fetch gradient
  xs, hf, hi, ho, hc, hs, cs, ys, ps, loss = step(inputs=inputs, targets=targets, W=W, 
                              vocab_size=vocab_size, hs=hs, cs=cs)
  grads = grad(xs=xs, hf=hf, hi=hi, ho=ho, hc=hc, hs=hs, cs=cs, ps=ps, W=W, targets=targets)

  hs = hs[len(targets)-1]
  cs = cs[len(targets)-1]
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: 
    print(f'iter {n}, loss: {smooth_loss}') # print progress

  # perform parameter update with Adagrad
  for key in W.keys():
    param = W[key]
    dparam = grads[key]
    mem = mVars[key]

    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# X-uoNmYgKUtbx;.J&GF$3;ifbXFP$klrHe,o-B;mL;g:tVhu'LUSs'eOQd-b jEbstcgsKkRCYTyw DXr wLOe:3iJo'B'meSWA:!Nv;dFGAcjlYlH!sKiHeXYnPN:b-?wvWArS
# pAMX&wy$dvNM''cr3-yUQ;QQgLTBoH ePMaYlh'WrebknKIQrhxslXcoFo!kyYUT
# iter 0, loss: [104.35979968]
# ewspn eergoh
# shanoiiph tenlh
# paeethd  ttaauhdt antrthh eieeeh e opikfsoevw ae olgy ic s:, tilhugetooueul?wF
#
# aotmidewcizodetvamceyi rhsu s h!vn iser ft
# s:
# iny'osahHehnwtsass :eynusithc n'Cs FAteaCuhi
# iter 100, loss: [102.98593396]
# nsf otsaen thl
# .elaiahn stoe na i  aliraa useegs,i weealeeCel e rtluty ee
# Tbsrdloaatwyy:vcssofFo smF pT sfabeiditdnlldgge:a htltcndt stholdbb. ushpuosnrtsrt,snnagcts oaI owvs we:hNW t
# Ta hkol lbsiwmR
# iter 200, loss: [100.84046883]
# ,rugd:
# eeb WeearmspgnsOhtoa ht tmEkeiha s,:ree ov! aN rtieotrei
# ais ootmcsetieyhetty- mateab,ko,e u?sllmz oeesguilapini' m tohC
# akgoto!.mSa  yw h
# hhlzl  ttM rsohioye
# et elbb
#    oodyr
# Eot koap?she
#  mh
# iter 300, loss: [98.97837054]
# i   neo tmn  ekrk c,,shhtem,dttfsiohv sr o at Yiet  thrith  oh  :hwikdeIend
# efU ire
# nerhs iretnce e ThwietlAetela gawaliu le! rdugete ishi,hnircetnnIatnh srb hdtwnw thi f ar a a otlsnehe  ip,nnkos f
# iter 400, loss: [97.18590045]
# i beI td  l
# retnhlkC ;i ehoav
# t
# saupdle?Vrg YEuihBS'sinS
# IsltIs?so-hn s, notIto.awcb'nrbyp r ikrei
# forlyBarceta woa,henayt c
# hUdpihhihlTt  eehvMnhfo tr ti
#
# nn  fidhthtielaOss  wwhathaeidt id:se
# iter 500, loss: [95.89944181]
#  nal gn'edou  oauUCh, eefrhfw tie.sasdtoeohddeeThhses eko
# tssrn skaardintmeo mAect o'.weayeo:d .ei  eth enk
# oirfnsyiia ahentodAIaldi hewn erea nuu!  C  A v Wr
# ae hgrsu  A rwv l:h
# tuty et h
#   d eoFil
# iter 600, loss: [94.37900235]
# AaLl
#  rwl lonr nhea
# Iewntheot ritmi ydoRk re  sta LesIIod cdei r
# fa
#  t woaa m i r is idaledt. sihd lk,Oh , s
# ce Bhddadc aoch d IrodLmrnoaOo rt  hua i,
# gcaee .proo n.oaanweuohei lr uh rdLtalth,h t lwer
# iter 700, loss: [93.14577776]
#  :
# s
# lw rvr clOUSn e
# AIn,!nwaoers  ereO.  eHtsIimnicusetnm
# Tha,!i:  r
# ac
# iase Vel  ogsoashevieentmfhlRn
# ss
# ufruulrpisLna:: Ic  ehA. e GiuGI,rra,do
# I. woith,eo oy; lr.sehr t!nhs, bk a
# e tLrhe etI ioh
# iter 800, loss: [92.17322155]
# ? oAttfwer u,n  t: igtols omofe fo-GdewssB eyme
# dlhnstt n
# nmidias,,Lteh  naobisbere hsel,I
# ostLoe, ;ettecl
# eet hisaae scbhehelateheehf  h eshbrf dsdo hutPemossdriteo  olsaio tn hia e ihlEo  eeSsyAU:
# iter 900, loss: [91.08361033]
# bsr raoscltitesn sra heiegIar
# itshd aMilsirenkloahs  gssose I;
# !a:um.s  iyieainu san  h  eyrd htw hel '.
#  AssgI,sWrcithedsemar:veflhd:dw gMy. ire w tuiwp !m,snscernoacuo ,eeallaberetia d
# Mas mhremeote
# iter 1000, loss: [90.09948258]
# t ncIloreoc mc ahhnsaidaa ireauggntbvt e lelkuaA
#  ,ftyahre
# :ncotiioeoeecC me e  t tdiai
# nt oyt?inhrsdsd h t glcw rte'f
#
#  uae .h:tpnupyt Obci'oieewAc,eosnrs
# wege
# iusr c IoRheopde e hehd mNtd nAr eu
# iter 1100, loss: [89.20513841]
# roedgicn erh
# esihbyr h tamneees.ase:ta  Oe   h
# pelpIooN fksswailie UtahNhSdt aiAvaoWditnhwger
# fyeaase,hgr,,r seht
# rUw ae ysd oolcpntm;sc hh oC    aysThdeuAibi, tsocaCeo ahsaasoSesak I nIt istlsgUG :t
# iter 1200, loss: [88.31200117]
# olI ih e h mrNhfai utm:l vrezlnn,edlisrefLrs
# A;abptelw or
#  h etr ie UWgtirlrilc ah a n ltC rah osare;lss Th cy. e,lmooy
# a 'ao nfn hoeehThonoe oschm euoo
# uW'n e Rsienrwdslme,wlsrIsr;th oe;nla
# lyo ii
# fC
# iter 1300, loss: [87.45259739]
# m
#
# ,o i f ea?n'uianlr itsfsae
# oydieoCof   fthw m srsucdsmz o
# ,itasywe'sh
# d hianctrehso macfl,ltmweuidia dhtS tiweass  Iin  rotoas sh tC g
# n'UaetIresnoR.Dde o t  petrIeemirdsIum drewael nttwa ootonr
# iter 1400, loss: [86.84073018]
# oiyne
# rwnh eand tnhects.rt m w  Ilipaagwne.novnelh t ieitntin oils tehldatnnge lcn  ouupuoselhatt ln
# oled igAsahr
# letto meiap
# h nrg kserrote:dllrisn pnafr.em u ngrg Mtsesittioerrtrniln   'u i ra  bnit
# iter 1500, loss: [86.230874]
# Fkroaeaeo w,ooba
#
# uMyidnide
# o ueapae tlthi t asd  s .fmhNs
# He tt
# tnirih
#  h i a hnea ss i
# s
# pMyEacp-osnehtd: r
# sv
# sd maeedh c eyiuhe idr a nmiymil kosyyuirysie
# dduac ie-a kNstr dhhe ahoWia tydhe b
#  Y-
# iter 1600, loss: [85.50852417]
# haeteh.,al oonreduohoI  deflneL  dussusiaieec bls:eooieWlu,einuiduemnisr.t: ypthseunyapr nyream !i  yroituhnhosi, w.,Raewehoo ndtfrn Aepien ree  w'
# lih tteaenrrlspml,t ueqnoeevvgosins
# sitnN .:.tnktere
# iter 1700, loss: [85.05417594]
# sfmiges  O c,dnsdatoawbnecte  oensisoeehsped vtroseuva
# WsvaumgyarwlIs   thwe beetsneh  iioeeoU?i tf Oldeos   taiie,eOse alnc yinOprurdthndevner' ephouf
# ot ye hrd
# t u
# nrtalhre
# t o,'h  th .hUwushhnhires
# iter 1800, loss: [84.71424432]
# onn,o-wso rodhehssa eaeeo g Ctiaeteao
# ,draah rt a D:oh,atde ms
# ree  :oehailtgvhmp oe
#
# avhiio UY ntth d,  e,ia uer adt
# .h nodn rg eIR vielsl .micastot ohfkehene
# trl a  S np,rtat  '
# ed m tedNerlp
# mAo
# iter 1900, loss: [84.06870785]
# hecfb,t
# s e Iob e rp ritbardelmr
# raaice
#  tCortt  meirT kg  aehseee ll
#  to ,n anhnIefked
# eef ,o p h
# aetdr e ena i ldth.:hfpl ramdrdroehhlo
# v  :M klaaolhhoeueooe
# hfoh
# pep
# h la
# nddsc l'othfom
# a Hnl id
# iter 2000, loss: [83.60587474]
# lrncaaioad oilifrs mieln koh mifeC
# eilltnl rWeallad
# u :frstnorye amlmlnnnieia
# nwugkicoktco  iniika
# euctths otumpu
# ,uloir omcrlrnhsrefslpliwnnfleUcl do ovaec lishuoul'ah  nwlEsaUu.oodios ed,ionnbapIdco
# iter 2100, loss: [83.55287729]
# cwowycoEe ow
#  o .cesusrtwtoonet t:ws w fAitoor' iohch emee
# e   dt rg,,lntoswthhoh  ouuureBouwneoatnt w u. dseoiuh n houdueiuhwtoetodh rs. n s rwoswos iue nertwehd
# etqeieUdo o.o:o vdtptlh o  s'rcwseoi
# iter 2200, loss: [83.66551929]
# LoIoo:v vvleulmEwSaU
# tuo Itrv,UC lsno w
# : .ts ld n  cCi'atyha:
# rel haI.h rzb
# l uostohk scnk:fhlwov hiyhob  ukIoTIttclb olEy; YIfuscwollEk wu Hun.sakuIht di
# A:'l  Sustl:u omy mm aEgmvpsvv ImuEnsaln :Ui
# iter 2300, loss: [83.61832821]
# oT ceOenli d seIo  sosdite  d w  ,,usvg  e
# onpH oreej ouR e
# ethse ped oririaa r oo :nd d,  yU dfsn yhiwn
# o hvtI  t s oh oe ni hue
# sno of  oeichhit o,,eh oetae
# ts eiTrlto ,l.e ne ied,TS  hozh, h hh fob
# iter 2400, loss: [83.7397252]
# du sa ciu ' 'oa huuTt pdiuti dCoe u  d,aBnuod  ycz n,w,
#  ine hn hg,renhutey o 'd ese
# wt'ey
# akI
# a,
# rdn t'u,ssduioIsh, rnHtmra 'iaunbt-c  u,us ea   u,     ,oi dwrtorsuohr l'i
#  hen t oiaiisaeoiies
#
# c
# e
# iter 2500, loss: [83.81119522]
# eaef hnne tak
# ea rea mmt nOyeebnhnHheeiioe iyieIe te,e eim'saUl oinnhojuk S i, aoho sceonhnhT o ieo tvIonoodsh.o   ino
# rnthtssy eoiuhodinhspunuhhio'eiH inuot  U
#  wtaaso :enhg d iuhsNto eua gcmhsnrStbn
# iter 2600, loss: [83.5899624]
# ey
# ShdSe
# aO,tet
# N? hOS ye
# oe:IaHeurgr h  el; .to
# h hw
#
# el g sda se
# hoaTUOsh hlondestmsefa    mi
# t
# hd nye? ni hw doahOt
#
# h
# :OSsa
# rmaoo am NTrpA sT I hUtSId
#  nnielAbihUSneiSsek hOdl;ORkt asoadhtO
# o
# iter 2700, loss: [83.59879155]
# S
# hNae ,n R rNeCrC soE  e
#  O otcdooollbdeea
#   aIUsiIOcH ra ,Y  Ir sN  ilss NMUlepnMwnAOt
# IioE fsONvei-aw   roLtBNTS ei oy  S g i Np hsiE  a mhAberIIns
# rtR;cS
# Ir c
# n , eNrLnmTsonlNwku
# bn  hglSe
# ,CUa
# iter 2800, loss: [83.7979423]
# eWdhidses fAeoahefis e eId eatINiorIhLewob eierecdop yo
#  ed ees'bdedkd eeC,ef  noi   , dhoeo,' :bTe:onI:eotradddC-snd ,oedte'rdedSrT,orstekomheddeadime
# mee e ofmel
#  eds d rdben
# btbIOtsh'cabh
# ddehmhro
# iter 2900, loss: [83.93470291]
# ionhehe erwtIktwA
# bo htrbhs we   es'pehhrlUmhr:hewt thewwnu?o wekh iworrLe hwatit
# shrtcew, aMr tuste,itm
# hwarrmhlw ,  eerweiy  hr icwiieaWOieiesotbkrg  h irloruhttrdb hthnawwoiatubii ttea  iswr e, rWi
# iter 3000, loss: [84.04786818]
# ou gse,manRoroeSSrBeio  O N.s
# odte n e vovl osr  kCw
# T n e
# lpn l  eo veyieaunr hh ou,tauwelN.SctmCgdeOt nldsm ryaOeimmv:ll
#
# Iy: e oo d,eo wa o  ytsro a:e!u ey  yelrRnf eooyieisa   e eoe
#   olosus rr r
# iter 3100, loss: [84.67304066]
# orervhwwbhbar,hny
# nI
#  e rsusmdoIEBaohnodet
# O aIha ,vTc,hUo-eneaoNmrefuly :as:SHIy   hlehyhr LhCitph
# I unt lrCab owt
#  ottrhd
# tUenoneh attrr, hiI
# h ryoaolMe h  hneawv-s nl  b onrUTewor'C
#
# eoyMaabdueEIr
# iter 3200, loss: [85.00636755]
#
# rhino
# o lnemd,np
# is
# fnttldgtlybh ?nnotlMgsin :rnoonrbier
# ? Ineneco
# tuuoiioormsooean:sroe ei
# t
# iaon
# t
# nFollboo.e
# r
# boti
#  nbnnta
#
# eeninohi,nbtvNwegsbban,enhhn
# n
# otwnnthoeeokoS
# nS unS
# ansua
#
# yoln oobayy
# iter 3300, loss: [85.07513351]
# it  arscvthtleh wr
# ooho,   t  thntyno,hyceNebdut  enyosRtesc bnaoaoIcRta l,    nLIed,hetsoebhta  s  nenher  thB yt dt hhtlmsNdI
# mo,,.dp
# ocTtc ta u, e  hcheaedhe  etotw MaO,rrtu  ttotweh . eaheiItahmr
# iter 3400, loss: [85.1617347]
#
# rl
# l
# l:M aInl retehAr O wrr
# fkl
# drONci-Nlv smCyuUakS atv otri
# slae  aHs
# Us ioueUimriatnp
# :I, MNrm
# n.i  w,
#
#  tknIglsM:f tipt rw'Tiel Laonehoe mLOtf, wy:iykipe rheV rpbibU m Nft
# i fMial:oNifImag Yt yi
# iter 3500, loss: [84.98042437]
# l
# ohcecoeeA
#  AtlowiAccrioV
# atBRee qdo
#
# m.nadtaa
#
# ehls'cliAidscioWiUwBmWlaAli WS h
#
# hn,wo
# m.e?:oU
# a in ,leyc,baBR:Stewo
# ttU i
# c
# otloia cuoy
# ioc hecntoowuTm
# e:Obo.oae;Cl Rcfcloel
# cnmicaesCle  d
# tn v eU
# iter 3600, loss: [84.92509975]
# othLe ae
# srt
# sulu.b
# claed
# ow  s
# Bledkbc ea S c idOasISIt
# e Me
# naO
# iUt! irrctsooWpsavkaI:o ol,Ieak zkchyeee:oii
#  tl
# et.aNrOddic R n
#
# ohle
# hlIOelcTaoarihd
# ld ael,
# aanlOo
# lIhaC CuRmo lhn  p eera
# t
# Nn:hc
# iter 3700, loss: [85.0195451]
# o  e
# ie-omIeoToi'
# d  .ro  yed  mars
#  ghodnrseo  cInestoaehmemIca'srvIn remnem .bIo!sion :Ue
# kr eoo''rIn  o alHoeoI en fN!srMIsmlor
#  mCaoo tmevooS   ,h  oeo'v UrSoen  'poeofRehootroMoyt e,s he loyc,aaT
# iter 3800, loss: [85.0568295]
# Mrae ah:nheueenrv enL uAesabesye eu sed.v,;etos'NI. otatetkyey . toohY ee!iehr s.d ae se he arscoeoinm  aaeyeel erih
# iaeeeI
# ae
# rlyeY e envetma  uRh,u
# emtR ;a  hrhu.,e-e,hmeIies    trr eam,emte snn e m
# iter 3900, loss: [84.930715]
# ufret  .ti rh
# Nrso bTscot p
# soso o'f
# obltmotRu eomtmO.xuf o-erwrkn
# omIo.lo noo,i ooH  oot whha sihh
# ru bsh hs
# flalwa
# hnanM Rsht h?o? .pT Nn nt.oI yIahlu  ms
# t?oooc  nh:burn! dioC, od nuu ut  ytom fhl
# iter 4000, loss: [84.89517178]
# e btnro,e em oen
# oees ppb  rotm t aeh
# sslo  aa
# mr:lbeots nrd ne i  nfivrpvfmrteni sm:Ivovv:ss iRs  ls oaootp  m ies,i?oc wbme eiha stsevh foi
# vuoon  aegs
# tv l.ao eoeoeutsl saahna  tdwoLpauu bsaaslt
# iter 4100, loss: [84.87942084]
# opW h,ii    se  veo! h O,twr psaii  r aon
# T byewmhYaahkpt er:LimbmsesI dhnslz r endaoge Or
# aechohe ktcs  snofnr  ssoh ae  ecettcgeau setore aeotnhmoowemi eco eSa   trhhh vsdifhieeryllyetth O   esha i
# iter 4200, loss: [84.57198556]
# RWswnsse
# !mvvc:m:OomeseiansUeeL,
#  s
#   eei n ouUutfnmt
# y e
# It let
# !  e clsermmaaTLtomeyemL,gt:osS sm :ne Umtamno es sioton,hmt  tonWekaNteA ei U ynmts  tl shdotethcef,s'. NW
# nsieoen iwAison ahn sW
#
#
# iter 4300, loss: [84.70267791]
# ndooiye tp ntt  ioubvrtn nne'
#  niu etdrgrh bhrttest itey hlmhnssnrmii so couostn eeeti oot norO it sPyhta Dsiln etlysbtbromceyatUdoatdrUisaAedat taheoAtew' rn  e ps vnhtmaoe tovysit
# m d itni tioa aet
# iter 4400, loss: [84.39589667]
#   nielr kt  mfonksveninIrrte
# aniha u tIsu
# nU:tva
#  'ra.oh
# mErdSy
# Ia
# Sna: ninnow
# os:m
#   iswntfcr Sbon sioh c ,h htoow
# h . o
# w
# nte hhhrtIvmierwtinr:rronSmrmhNaaykrg. Si-o sils
# dreDercehooFoganiog
# rsoda
# iter 4500, loss: [84.09890705]
# td ueortmc  ergSoted wn,nd u n ei dyiha:ef
# ecsotS
# psom:nruvTSSniiiS ti,iempwirieenr' slewiomtr fso suveic teeuhet   sdu gtaSe Itp ;to uh
#
# rh r'elp iurpdt,oemre
# geaseeTn eemtholeae,prvxc neesrcireet
# iter 4600, loss: [83.73635138]
# g,aes o
# nS
# RSsi tNt:!ois ioop-rhR
# eoyndvlp SIeeN!eaaehsbumCe
# kco
#
# onephaCIsen
# s!CUynI:l
# h  hioasod;TtS,taWietiritv
#
# s,o: Weiod sUar hyrNtC rsnUr thdgskpt-t asN iw-ost
# domr
# imeIsuhnSonuotc e sIeSchCIn
# iter 4700, loss: [83.80768953]
#  ??,nomtedt
# rhonanu
# TNul ns biorgrwd
# C tbtghcureI, t EEegyfTsuya wSe,yl iUE ?Y  eo utMf bugIp arnyNUS!im w:ethiiwro'Ir,Ue
# h ers ktnt rtrsteM ,erENruo f' oUh Y?tBhIv,oStEntedo tIr eu
# wIniNa VrN,
# eI
#
#
# iter 4800, loss: [83.91492666]
# aAbwnCriripxbihewts m l W
# i, hy
# Cneh Ceo:ao i :ol ncnecabahoosn,umr
# u inf msohnWsumf arrgwEuoees
# fotta
#
# C rsiie, e.anClo dgwarnrieinWaal rd    wne
# H,iee  t
#
# mloie, aohwrnfyheoiUneFndtseu ishndduiii:
# iter 4900, loss: [83.96519236]
#  srirfnoenBtT uieeel npotd noo on i ut ye on  baNt
# u annfBru:iettre hoee eih hk : ttb EoeaahIsel   shyotU,atn nhpsI tihaso
# iepl IWeosteev  lueh  oY t  s s iIahpeAhtsetthnscttlrIioe sa Itorszityhho  r
# iter 5000, loss: [83.83265656]
# sI,w ebf ed  tfIdceao y d.i,ymr ewoen ooa svtbelaeCops obyi  u,wSore fAceteu  e
# uIdptmnAntod,sa
# aw rmalrpisget   Onnw  ueosnped cou s aed
# IHrbe deUerdfCbttsn
# !eslm lodClwthfetr unptwIerefrat?re oh ns
# iter 5100, loss: [83.69073291]
# w'eAdt  nSofhma
#  h  a ,cin tw
# oAt rhoynnmu nohIYehirlaodw
#  t Si a nteh eenEmoahesNIaot l
# osmua iu Sld ,tty,.o i i     eet:uue ugemdaiaeosyts
# FntaroawIrrnaS toos , MI  aaeiiwn oNuenar t 'wCN ceircdtnpr
# iter 5200, loss: [83.69243063]
# nEr etarif n'mofi:li e ?uoiynstfNogmi kagucc uoh hn
#  eeMaweo ir
# ir lpwfmw isht t:U at M,saftgoy,reeeU  s tn yhsoethmaoy o egeeohub,isdrymorpis  N,y
# sn inCnoouotr d ioEnrsl
# cn khfn,Ia ten rrfSet     ge
# iter 5300, loss: [83.52124622]
# ; , ey
# ueagepcetSet tdno
# :Su h dcm
# e merooNdensothspbst
# sgefhoahs lreqt h:lSausta d'c eu
# eioov.iet  lw Taaloeaf iO
# t wOwdf ct shkosat  t Wn tT
# abWd ttYmaneF thf o s, m hetcahaddsuy  omN
# r
# OIuhp
# my ev
# iter 5400, loss: [83.40536095]
# Tierfa:tis mlfe  ghseEho'elth mc
# oo t.eurahsroi hhturo a
# trNtos tireUo ,
#  ilestd s o:dee rw A  c fey   p
# lentlss
# e n
# hne iasemadlt,m nponisa AY soI Tt iatIose
#  ohponf,dibm
# eSs C o Trsoau; e ,Lm ne
# iter 5500, loss: [83.36908662]
# etonosoa hoinonrnethdanced  e
# oi
# uno,hEe r
# i wld  n lshfin  eooaanf o, fsntssh urr
# hf psle
# l,otO datbeo whaaouhrh.haatephgrt oettu a wh:ae l,iaseemkpieo ehalrT ehosoetdockoohaotu at odoe h: aohounapyt
# iter 5600, loss: [83.19690449]
# ttnhoeotpntoaoorolrrtmfogssdrt tntss
# nn we tssoneotneo rs o u
# yagautsi
# ;tssiyl;nombedsrnniclnnehrltl  ooksnoooonstisllrpweeF.tdieeadsigoihehoeumdenstieo;oo ;uijn uusnrhetas ti ioii'uwonnttomnwpe b ynt
# iter 5700, loss: [82.93088746]
#
# a ftnat
#  .v i  i- eni b ngo fs  gbri
# f tn tthtgabtohl   h he bb ay  es hhUbi ai  t se:w ,
# htsbeosmct  nwnnbbr oeoenea arttai siniilahaeeiadnh hha it enlnn.t
# laana toh thlnsie deg
# c :o  dvnnnda hpo
# iter 5800, loss: [82.95466232]
# sn.so y
# rindpt,ooeeproetaeeh  nooaTuet
# n ateiib htU cms easrhte rta
# aith tpl e tmpt fmse nn C tor
# eeAuhirf erc  rhhdum:datcerS vohh. orhh hah ipsnhtthd,
# fr   aeUhehdtpIqeefeI ksrr swe
# ir
# db sdo ;
# w
# de
# iter 5900, loss: [82.92473489]
# o oeep'ebk r
# huakklFi, sh l:eo
# l a:h
# sasome m:ih  ct lu  h s ,ea f
#  xttA i
# rmoSerwos m,e dlllhd.sB.arowoe hHohnn
# nWoisbph wrer:'owsoas  !huisrgaeeovodipetoasrh
#  icS ieDr:ehhuhUnats h eheh  n,hRtpusiU
# iter 6000, loss: [82.81969972]
# oeua Ttotiw sWa.atanv ee L eOns lv, u:Hh
# gNhM N mu
# maaawpei hl r.riddoeok,tpedO sai oecorndUhtha  tr ahs ossia
# o
# u
#  Oe! sa
# aofata l Psisp Uh m-aSomw Wo rPnh llv ieN sn
# kdt  me satrItoeh  rfedsea et e
# iter 6100, loss: [82.91453418]
# er HGs   i ei h.Odf Iwousao ';meoOv e e  bmm e oThloi Mspa os aieoiinhaeF tmssn sreuTuaar ns;  madanhnfdn lsI bdAc,rdbr, r,aNnraep  sfv ywdae  - gshosseee hvd  ter o lT r fettgam e u o U  th
#  rehsrm
# iter 6200, loss: [82.96637634]
#  siin t  eskfeefhnrten iad a
# eeAnkhwtndb t:ee lbenhtytwNmo.h:tKyh
# mdm  e,nroeeda; sWn  ,,eotor, T 'onni;e n  oasetoTee  sem nEssrdTpttynstend Tho esow eddsetn  hewthtm esheehdhodrtsd.,gtF ctcmmaSevaG
#
# iter 6300, loss: [82.86943501]
# leenotdOiBd  haIm
#
# uOgdE oe G.enu u.S
# G lTl  ty aeaT
# oE yahug
#   ahar Loe ollmab
#  yodth ells dn ieaoht fsdpt  doGefaloTod oee   l
# menerhH.Osdm i a    rc   mr daynt,t lo nhdagBoaao: OsnWiecehahauefltS?
# iter 6400, loss: [83.09458056]
# ue ,th heeddh  ded .
#  a  r
# Ldh  shntoCb  C  re G   otdlr hstdo
#  lr mllrT  t dlt  tad n oeeTnaRhrrgtpdhre nsg  cs ehtabeoa,  agdoen,nchti  snsb rT stof
# cehentrbsn itetaosw'nraedc do dtin uthetesmet n h
# iter 6500, loss: [82.9724906]
# l,sseeoos'oson hs uf
# dbue rh!da bEpk lEttEel n
#  sso
# cl
# Wyea,reeris
# mee
# eeeg EAInkkrrEEGl n tyEeNC
# t
# lhuenAedi tnsodrr!dwD
# t ocw
# bneuoPnasWrtetsae nonutu rppwlutei
# i
# l
# finhonsEtnetvrc
# lfosrw.s aaYyrE
# iter 6600, loss: [83.04715982]
# a. ET TswroehestwOr udOtyuoaRmneehsdsegHueeuuew nnS  d oeOErt
# limrGsYheoctt, neT
# utttdan olITtesEenuY?irotna p ueEsLtsthK Uf ia fhY hletsmoodumt ceD
# sracWsrLr ktEaiauUo:nbuh osdhaDa,lte emthcNAec:? U
# iter 6700, loss: [83.35349506]
# rtrwpt oiondygrn yueeoisrs terfsrEni.l
# rswe ten raw;et
# keneynrt rd posrnL   r
# d y,ky  ctno
# hrd efurphe:auio hyahotihn erh
# teinuw koe ai e,  tUeguh.oehnmoy r,nusohoin eawhee yres htrn st   ccodnnAcah
# iter 6800, loss: [83.33575406]
#
# naaosn ,.  shSdo vYea pr rooRweW
#
# rehoRh  c eeohekaohoni
# rh e .  T orgsalh:nutu   l   ndLMnho;o
# mNAeWbhssn kbWnlese aehe    mR,rwOmk.vA tdro nt'v,ue Cna,AeaB ri wieh h ch R. rgetltl nyNrhgwtnNinavTe
#
# iter 6900, loss: [83.52809349]
# ,ro
# gofnerelceYrTrdyt  :,un, HAoeun Tmdh heE h I  amsebyf r AyGdiBlor Aryh sT,en ueeiDoeowfar oslo
# yNo
# voryr
# h
# docnna mmoouyw f  EeEr rcweR.lrseo rgmyocGdefmtocoyuaode s ydfoh
# on?  ueo sjh!
# cyfsa te
# iter 7000, loss: [83.67988811]
#  le  R swmdev n  mamciy oeen'snsh ee iiZeatseEkscdNfh'iemimy
# hoiym  m  e trH
# e,aarmma leeyunmt.g
# a on uUo  ,od mnyeru
# prguc mtrn od  yes
#
# winukemEr
# nrnno awegU m  eE
# pnTemnnl meto y el h
# ia  cm cO
# iter 7100, loss: [83.81636072]
# eo  s c Luss  r boW
#  :d u:ern Erho resa,Ln
#  y  tn htcsokeutG  LL,,rT rota  oE  yaR es
# h
# tu
# trcrk earguafrtfTfg , n ,
# Toduhoe wbe!t d  eSaGepl  pbeefuo lsv,veAClsLrlatc nebaeoWeanInooaa.opseohnenulTl v
# iter 7200, loss: [83.87003991]
# dysioE on ip
# dqn y
# grrhtmsnuhs  tcI utj oshrEeee h,rtpu.s Nue'drf'depdShben  r:edd  ianr tcnnmeselmts U  o setenl:rueb
# whoA d om t ta ie es vO:taiLhoddteohpt; h lwltu'eeae i,edHstsgA
# veStk,T ;,t mif i
# iter 7300, loss: [84.00762909]
# eall, farytol eead teuaeddRo  teGeR
# lddd
# Aalf  h  dngh.aaEltaN  rsllrt Ns
#  Eden  eryT d
# y:h  TEF p:roA i dy
# AdeMe co iCryCt pAstmoimtpt '
# eO thfoM  Rd m Con
# hQR etrhh
# EcTeE: Ec
# SRlEyo
#  MAEA
# rtGethi
# iter 7400, loss: [83.95341525]
# aaeewe hts'e
#  o
#  me;eeh syCBtd,shslhtme:eneBnr ioGeenoGSeitauwsoAIaieueriOamathieetvaobtetn-uvewAareeb o t l.re
# toe.OcniselN knEtpfrgteQhtseeu
# y ttft
# ne QieochIoy aigile  omlata eGrhn,EdsduO eeAO nei
# iter 7500, loss: [84.07762694]
# ettr hltoeh ha gRr
# ea u gGGh?b vero uehdtaathewscal us y nd lhaesl lna l,eOC!mhc ia,' teyeahh m
# dp
#  hr
# !pdI edwaedrrtto:de Tim dndd Ger mtiIbeta, echde,
# Eaeee hn,e   aa i;eaCucVd atn:u ttho
#  sm
# ms
#  e
# iter 7600, loss: [84.05232229]
# sottscnhtdh gh ?i n wrs R ,,k m trt  glm,ehat  utl
# o  oisoose  i p;roWoeCsnAnLs aaoid o hnayu
# nl Ki ne sLdwwouii tudvsb  nMp me ditbon'hu n
#  uHo itf wd rtu,hAta,Rr
# aA: tl
# nmhrhhnub
# c  yhi:h wm ,b
# iter 7700, loss: [83.93067278]
# a e  f,feom   hrTolerril .eMs'nso'tam  ns nhoti?y;vRmes r sna
#  dhe UnRi sg;r r  eI uY 'iI,
# ibeus hrEiooRnwss
# d l
# ghiteemieyhw
# Eiha',aeh  iI l:thiht nt Oiatpra yOd esi, uae
# u c imwdaloslMsSgii
# o
# toow
# iter 7800, loss: [83.80003478]
# si  y, i ta ro ttt ntt iiM yciudse
#  mtt  iRnmsaidttol eehts.emh aitn aF ehel thevnead  s
# iutlr hrSth i .tm  c.eeeeL np tte
# ts aef ra waektoforkalt.
# tm eoIet nmilhas to hteelwhFehl iau
# wpste: eFhvw : o
# iter 7900, loss: [83.37252577]
# ftrnigean hrwc:w?d,:ethecdn
# tsoNhuten tjmhaat En cetttp ter mboety rnh
#  geo
# sr doe:ee h
# slrdrhe g:. e   r. h acdaoh dor uihoi,e.sfscad itr-c nu Ldn  dr svu Selceo icNeedeorhoou,rne
# dnee,aessrnoenewos
# iter 8000, loss: [83.30043902]
# d:crttwhou,ul u
# dtheRrtsbgiee
# v SM
# e  oDC   c repR otlo nieooyrerofgofeto t daw orh e ol  toe red
# Eee
# : ho meR- aslMtnomeo
#   opnt e
# ieooiMtaat r
# filitlieroAn otWternslh nt
# hA e;
#
# y,itfl iEo'g tfrt
# iter 8100, loss: [83.17676791]
#  :sr CHrD bKo.T
# a esn;eaoWhv;e W wTr sT a:nh N
# eonaEeI eyguralvadIauOy uDMthGenIh l!teuhde mocdl,ls htIa u
# vtaism biu yyegarioeam
# toI Ya hssiae sk g,rWy
# r
# G.p
# wyna
# n
# AceimIg Nk : 'asyH,
# :o
# khlWesggo
# iter 8200, loss: [83.26995153]
# dm o stdwlrarlroeI ssT
# moiLud meHdh:ISeTeer
#  neWBrgsWpr sdelBnre  anatrcRkU
#  idoBeoanenee;a oreGmbVk Uy
# st
# eaiNaM:edrDoh
# ntm pe radd,cyra TemdI idc
# hiwDTd srewrhh nuh vkw
# li:M
# aE boyTtTawh dl dr oayhu
# iter 8300, loss: [83.33346823]
# aaon o   ;rh dhlcnerhih  nHUoel,a .yaynydigylrrabE m ra nhrn'rpryeg uryoycin,Wynagpyeprtno ynsi!h !rlG hon
# lcoeaBgchaGl t
#
#  Bo  Cer ,auohh;oWgeohum' u!msaonin sb ,r iaoarrreeRfhwte;otmnh,E!oia
# oot
# !
# iter 8400, loss: [83.28442434]
# ,htuhoyTalnRiae wyets hniah n i'ofe tem fdnt e sy ri;
#   a rpoaa msi hern fao rrTenflmwe
# am i i, ni dbnh dradarr:eoordtngve inn  Aa  s,e if
# auetpshns'hnv u: shlmarlosinrrv i vtb  daye.a hamnui ye dt r:
# iter 8500, loss: [83.33493401]
# rp gn odsl sy  htU
#
# a: noroeir vu etnonogmryho h  sr rr:
# coO
# beonyi u RrrhC   ds byrev,r mry hyohhr
# rhnadwMorhgwcwh pTyo: h hCi cestsnoonEo cru
# eeEYam arsEfcs
# aarLn
# sharhnterm eerdHr gy iha hten
#  rh
# iter 8600, loss: [83.39338461]
# dsponliimr
# t nuvio n
#  Foyod z  e
#  a dw,i  h  ohnaa Mn i t  hosoi  t nwl d: aHwo  eh
# dh tnr mrgs d ;OT Hde
# dnn nhnhoT odb
# GhdtoiT:
# l:glti?i
# glin
# fp zhheiccoIodzy  hscek ,Inr l rderoena did iir
# e ;amS
# iter 8700, loss: [83.4412811]
# k
#
# shete eo d ne uslatiectg ueet lts hI edtsshs dennoaaH'aoDd  ot   rYhl pOOonl,oidwdtsOCWela yts s
# n tusHlttt
# grho ,e'pon tnWceph e!rdc u voo ,eCk   amyegHtand' ta   rdR'fe :koSeKf tmwoh acckordwodGn
# iter 8800, loss: [83.37868618]
# MiBai
# Q,ilNHdcc. cYHryOUr,Srnl Kmdm wl:eglgsec'dKetywEdBlU;a ,Zo,hi'
# ! Ltm KetyaervlRef.net
# htpewAHAlo
# H sA,EESi:e,twAb  a
# ElHahRuoS eDsdUy gOoy HUaOai
# HorhEdlwInsbEwhp
# eraCnslL,oi
# ie:trd ezlyM,nrw
# iter 8900, loss: [83.75653353]
# n,aoe naottito aOehA WKspeAp: a ytiafa FnitstsBo:
# hnssiellyaaI
# mrulhR i ,a E d; epsheo.nntinohttftiit HfUob
#  inpi e nwli rnYitse dteK,   e ased cled
# oiapsrneIynCm oirtnariecearnfordrdebt lmosnryoagt.
# iter 9000, loss: [83.75008301]
# :ar  o nKamtT,
# shrio
# .
# n  nBdouh  l  odtY UnoayCr Y
# nn:  udYrh .
# ,i onh a n
# C RRponorhsoiGod a oscEoonhrbHdItt  o,  aiP:ugoNtrcctihl imee
# ll  Eh
# hsi
#   ,oUoas r
# Belreswocw talf dcwh uecdIWTeA:rh
#   Yt
#
# iter 9100, loss: [83.97320518]
# o  c,a tmUte,selnastwNI.hetsBsk
# gtsoITesBoelgasn u hyht e
# o, T;dk
# o
# ree
# NftGWlIddn.a
# YmbOopolI.i NeeRmboa aEka hT .or tDolh
#
# NrOrhbYodlyi,pt hIirh, movt: ls  a lr ggotoeorthfimcWstCh
# ;me tweAel HhB
# iter 9200, loss: [84.24351605]
# a ehtM lsAs   wrl drnesddlo
# aSMhN eyeih  s    on.ndereeeor hieNnAhfuCl?
# t  sgnuSers  h hwhosskrlhBi ue te
#   sdshnYfL
# le  oey.g tislswyaWrsott nAAk
# eelUy ote o  r daer .dh
# nknCet n Hml pa.ytnd ge
# bnaN
# iter 9300, loss: [84.25650681]
# mlotmp h hwi
#  iS  etr
# tfcna
# ty nehC niho:oE  p np  tm  t: Wlgu lhlNSl h
# or oGTt  ,uteoto , ittotEoe  nt!, nt e i ousnAiw,lByhstir,n:iomreroIpm,nrS
#  'nrntrBg
# t ,eoet  etisstps reh,nes oeo;i hHThl te
#
# iter 9400, loss: [84.02487643]
# h
# ABn:o.hoea   hulh,Swoo,lt
# f t hlrSh i
# iiahrIaGotH bndHc    kor tbowodlo
# EIgroeeymtn
# difr Wt lheeu
# wooSAIri:Gui
# hioowynvpyaIirGf,;b
# dh
# mfmetoSi
# wdv
#  iBe rirm ru
# eN
#  td ss ,voatyIk yrgwrraMolkoanhl I
# iter 9500, loss: [83.94895086]
# tboaOIn ,mheGguU
# edraGi  amdgreeIhig' d rchsn n YK NiennH
# c',b, lBlB pYdcYoO c
#
# p mce.ea IuwHaInae c
# seoee
# t ,re, M a cBfolAlA uoccHse:gn  t.Wb ce rHUs to
# otueilendO m,h rlArric
# h w tce GoUny kaB
# oo
# iter 9600, loss: [84.10321351]
# ymT y apreiIml hadni noiwItrs pfIlfoeddaera IoShhhS
# I oeTe e
# e rr
# HalTdn oEus:   sytA aas cuem, e orho deid-dtiggS d    iatIh
# n:ae  ocs r tse hmoyntS ssfioc- iasmicReyeiit daT ut mrI,spiE uTsehanlta
# iter 9700, loss: [84.12579497]
# t
# eDKNteri i.O e  shteBy  a  dnrlh Mc,EGacIporhaehat rnio ydaF  n!hmettpaiUpS ,bdesLtL,lseoerwesIdo eetrCne eodgs tmrhek eomes:Teneaio  aa LeeR Lu
# m  dh geFi oouai gNcrh.!oOoTa,l a :pouovasaew eIrOav
# iter 9800, loss: [84.14275301]
# o
# a, HcdoNhiGl eWeher aef f  ihts hewarweoeou e
# ilai p p oIns
# pee eefd e
# lgteytfbv,.msOteid,htheer
# w acT
# glpA f
# a eodfoc, w ga n, .mu  ,awcxreaesT
#  prcnwallr ,msrTsee l n h pddcfst c
# yf s'vu
# haC  rd
# iter 9900, loss: [83.89487825]
# af Rririrlinrpr;t  onm e
# he,ahIUmft rtlu
# lrUomtcrfR deGds ibt yrnn   Bim
# bysitlb
# BdnnWsrL , ef
#  s
#  tsiaLpxeBaiidhosl;ndnv- rl  ! ia cewimlsc,diher odimLebeF cr erm
#  mteohmhnieo,e acb;
#  z
# hnL
# Tffos u
# iter 10000, loss: [83.76956907]
# tIh owsme'B dordmasm heEmB
# dhotu
# bfhhoh
# Aer dsiEElk  w dyaoArxc Ki
# tReoog  taoombhrsdsnhiawmaHntoea  hacee Cgf m yrni;hids Bbhtuw rntmC.ty h t
# aASs trAsna
# ro;t tnStehT gisee
# nSc
#  dvt,Hn   unBmicttHrm
# iter 10100, loss: [83.74803372]
# nrueteeuBownoco.hofeinhhuyrtnstfograaser
# a eyfw W at bS rnt ,und uoitrher,, elrtt oyre a
# itadt.l noiyerlaord reorff tn rysp
#
# rttydllapft
#  dy egeteNto?FoeKher ewaG
# T'is
#  uTe,u p -nelsahls EaroosyRg
# tu
# iter 10200, loss: [83.64132265]
# ley ry.aayBu lbrI fdnefaiht dd u
# ln BeKOhe y
# rbei s  etn N mhha.od
#  dTtd st oy dprdeaa mie ed
# stYi  , osreehcttGlae o a,ten,yntrIe
# au rsae la
# b oiat:aco
# sea dcneyonc d
#  bnfputeneowesarIo-denastc c
#
# iter 10300, loss: [83.32321331]
# cldrlegyccsToN
#  M:rean:os
#  heIp.wiosdqliuf yue kaiybl
# niihhfdtenwcai
# wlrour: cooewlS: fhes erb a Usp, lS:;,eietke
# aeyiloa
#
#  huu
#  so h
# N ho hn ls
# dsm  enKrohuIulhCc y G, cf Sanp!s, vokni rMyEn:IsB o
# iter 10400, loss: [83.38132819]
# oi? o
# tOnivtls,eerfttnnYerrbaodsue ocWtoreaonSd ,euouryatn  eih uA ihc,tnAu,,iaghiNt;
#
# I tenw,rweh  eoh tenVLtu  lhosted
#   rs wcrtieuFToYbaucrttrtptgee
# sdrl r y hbsldcdm
# sli:Le,umnis r
# tOAv,YoeR'eu'd
# iter 10500, loss: [83.56337071]
# aRILscrdvuthEeoeBd nhNt Hl.a
# an!rlo
#  bIIa
# HIrIuisoildctgtr jelca Rhf  hygfd slhead  I
# nremretnm?aYhwnkfHd yvpr duttt EiWe
# Nolah
# tatdw ek dFl.be yhgyw
# Saeyasi htI oaA:i awysmeva'tHIh
#
# tes
#
# a,d
# aeH
# iu
# iter 10600, loss: [83.67888382]
# s  i gslRrkTb Ir hea
# gatmf  to  etiolTgevot maalenha rnhay  eerO Roe It:eUuesuat oleTag itboTooeseagehet  Dmy   om ttcaae  agspty  oiyan :en,o
# a nravdaan aaoohight o
# sa'ue,ottbsmens i o y  surr sao
# iter 10700, loss: [83.91476296]
#  oH C KWr aIssnKyeetttakelWhKpeHMilkc,GdvIdmh te p;iUKn
# wte hmRehIltesr:oi
# tRdloUs Id,ada ahMmekdi aeCIgiotKDr:ldfo,hqudQooasI  g CKa  d uo   hKes KyA tltlrok:oKvbdC  iko,s caReho sM
# Y
#   ,Ie.aKrk o oc
# iter 10800, loss: [84.13129663]
# oh on  maptta aorCmaiw Atugon fr '
# eot hRn net,lt er 't w.AseiannhsCs, HyIa oip ihlrsdhlddhbadnH:E,tt to
#  e
#  U
# useYndoeoGB saIn newsrcmeh,wnlrcgi t' tIdIetaioreiw tiipi
# oewI
# rI m rm b  e iuyooo. tth,s
# iter 10900, loss: [84.10481965]
# y cralU eyl modtnjpr enpnehnEeNBn'o H g mr btiiuIann GR,seAyst o
# ReocnE
# e'oo d nrE dnrshCssuON
# libnns, ureeeteese T Gr or ee: nQioDeeeuoo iyeeoAUn vl a:roW
# eeeift ,iesueawb:vi rRmlItnf   l leu:a cG
# iter 11000, loss: [84.22063411]
# Eo eod m  ydasughobh ereo   alamsetcgnrhsrehernh
#  l!thiithEeehCew h iingaefa h
# at nre:ho nueeaueb  Prhsinetinuies:t isa uhthetEnwh
# bsdleneahnherhhE eQ R uwhlyesofottuteo
# hhIwirdottiinh far oss,
# ihyrd
# iter 11100, loss: [84.03570974]
# ti'Etatoh.lv, hng!nrbo f ewtohSirthA  ruuh::eD  Ad oi
# h:aaUorePruEgo   WEator
# , nt ANaotar tHE  !rmhvsi aa ?cwhL mhehuuhdNshypahE,Hs,cslbr.hrgtearbeni sorhssnaoolTe!s o
# ot aZtdaS,rmlr tnaerwaer yuutri
# iter 11200, loss: [83.93649502]
# etu  OeapEah tf
# tter er rgrv?at e
# rrser fhbtthtlsO .hRthmdtsfseuoevitit aEelnoe h,he eo atyeHEhs s
# dynsobf uhehssneI,tg
# wtdd
# iaehsits thuecake  a,t. M:rrdon, Te fdsh n;,eet,hyai
# ndol aomIterOdys ty a
# iter 11300, loss: [84.14016337]
#   ahn hw Qs  hA
# Usoyhtef
# erlt asht h h ytv  tr ts sbbhmnoIt yneaBrio HekctfE.rtett   N terf
#  lyQanneyyIesIb hrsfte't l Inbedatiier Zgh Te
# oTewGIntrs   :hhi edeefcloHtitkrI NB gtom  twmh:nn
# EnIfeT y l
# iter 11400, loss: [84.26601672]
# dehl  rtue ylUTldbto mseAun'sgtlyNon
# o
# e Ms  ie e oeet uip n  olIls HlIcp TaAdulimFb
# hoot Ehiwc y:rdI
# n
# hErlRuosIyoidw
# .
#  En s.atsreoe
# Nlf oeei w h i en
#    caer lAktiHA lvHetphvoefBuuI r hesGvEdss s
#
# iter 11500, loss: [84.34770373]
#
# cGeiW ,K ThleREAaIhc ,K, nlb  iyIyDr I  I. I
# D Dyw
#
# iKn. lsAl
# ila RyIZro hgaisIn,e ftB aeo
# yygI
# e gR yashy
# rrmHm
# is
# iQR Qins
# daifgrAhIeyUn,ewed eIeo
# d  It I a.iEh:o ggAomwvnhaHr.bwu  a
# TIh.nheB
# er
# iter 11600, loss: [84.15278499]
# INvHra iar tbkhthlweo,eorTpmeEoyn roapt:he se owh a ahc
# eqeIehwe teah HhsramgeI.ma sIatIaunhtlt.hconihtgho Os h  h, g httTse i hnycTsthsca
# tY    heUaeheHlrrtth hrrw, ha oi
# :tTweEtwcm   ,ew loik,Gso m
# iter 11700, loss: [84.43034198]
# leha Rlns ::rinol ee,oo u ilofg  onS fs ms ltsECID ltreioskorht r ih
#  m,ra  orrrlamr y nrhpCleiUe npaafiWecarMvsr
#  i Rga htidy- aNn i
# wh e,RrCa vNilW day
# enssiefntmaArtnn'opl
# ellnnott d
# i
#
# H oh son
# iter 11800, loss: [84.51589542]
#  o elhss sA I lndm eto ybeueYe e pId leS, Sia. e
# hda'ertgwdeAia a,mndIuAAr eseRrv lngueo a,l  :hremor
# wKh l-mla;f
# :so  vtl fpwdsmoRpam
# b,svo me C!n,n umeolth  em aIobarm:l c Cu iilwemahleriR t.hmm
# iter 11900, loss: [84.5955707]
#
# a de RieISe aeferSnosktybielneh
# ,?Oetryhresrbrorr  arta,peiyei ars.e:rih arKidty: m
# aRdlccm reok ioMsfehrrbft
# a ver ,rr r  nU Srrteroage erm, dwek:founrn woI .   m'lrkebsP elibfgd
#
#  oHD nIii Sd
# ;aNem
# iter 12000, loss: [84.49572722]
# ehnnrir fmshT
# Niehoe  rs y
# ao.esgmocratud shwayuo ptothoaA, imsn ooyOicigmmwil  bdtymR
# s ufrAsn yfrnl ta
# mo'tboE  o i i o sa
# d elS
# .
# i oamEtyh soh
# e rdednunsd hrtre Grswoyi ur I nn
# laersWrssnsadung i
# iter 12100, loss: [84.32924427]
# ' Roo. o crti r, p,oac
# oIsnenurYeas
# lC?' E
# iotSMi eneeh'cyrClusaIdirG s eyyh
# ,t,n,iiy,INOidong'ehnRmicluscort,eRfWIAirIrm  Wl
# MdtfHo s oobosu,t
# ma,ClothUmh odaneodtu aduiosWpduutothoipotH
# il
# ComRmGmhh
# iter 12200, loss: [84.37180153]
# aeeei e
# okereGdfcdiris unfEyeo :aohebevira . hdo.trutMnhratoe ivhuOien
# rtGio e emfornorsesvbw rsshinf is hB sdmoi bte sBnsr sCi'n dC  Coeeul,onerg: or I drb hte tsorGibY csdvprndbaedminailsodnh
# -e ss
# iter 12300, loss: [84.39117884]
# dpco t
# eid,cW.faA d mtdlrmr
# m rlyI,lrrrfer u   tahrhu F
# ee Rle RsfUrtu eoil  r oe
# l AkatdI t dAIlieIdtrl gRNeo!ft
# ggduFhIt dlhmleoI
# R
# d d
# cakchr tvmlaiuiIlsf bmuls ,ip
# AeRsdA,I dtPoshn
# yieao,hAorac
# iter 12400, loss: [84.3511407]
# ngoho'coH tsoflerhe y O    d lhrr Tlletri:dac  fshlieoa tr,luput l   edrfls oeotTa  erh     hlydny  hTI nnI sHd en ottdtlo,ottddcAyddloortm''l
#  .ve  sfs Doade :eetsmfataehorIoy oiItf.o  . rccabu ma
# iter 12500, loss: [84.05708759]
# NItsft,oeeh HhoRp Un t,,gIahf oD:wyGyiatdo efo
# m
# sAa,Kr r fIw'a hA aorroa fImoK yeEfNoi t eooT efinye rNIaoImse noro Gi G.elksotyksamuseel le iyGd r n rIo,h
#  lwa:Islnomi ahmali e Ha en a
# d   h Cas  :
# iter 12600, loss: [84.1353964]
# o e,euevd eeed eshg ikrDsoill w H,eerki towInnsyordoa:wu f,t e cidotthn tl yGdte eMdro shksa,ae dhhcs  sfnejlct e
# oe  ;nE r,aasr Rps
#  eaa
# laHM eehthooI,gan,ttnnisoneafs :asA.m?lm  soeo
# e bw,riiuh
# !  ,
# iter 12700, loss: [84.00303077]
# eisgieTs
# e wehEfidoydbg a hg  wdod, y a ihodsilrrh h omem:r Iedoyt uCs  : t lnThmddB uvhvr tabe brstaprwWbaem
# im  idts gFt om
# aMhdr W,eryi ef
# a lotaoel  wm apcnettdnm rs i lHt lnmpwdodmiqlvogWdsgmcuF
# iter 12800, loss: [83.78116146]
# hcou aN  srmctI,o sheeoeson ue
# r:iei a  g olin  ahlryaniIeet thgnvUw   h deb etRysss  lodnnares fN,t woB los oyah.ah d s
# ooili,Huilaw noo 'o trne e rs
# thyt
# dcr Hh lgtrl  Wrno nnl bta:e,,osTnjoupm
#  y
# iter 12900, loss: [83.62403884]
#  Akipoa
# h N A acs hWa tnI-thnomsp htsahiucaesAarge e oheayg'bseOtaM: regKRsak
# wwaA  oghv H   reOreobA,yDtcG  redTees e,cud,tee,ue
# oaDusedtn   ehtwImh fw rBnsIsuewrds  :
# ebknitesteteCtharodd gehn eeLed
# iter 13000, loss: [83.57790441]
# hted eyw f,trpeali
#  We ntnt
# r  utsbaa,tr gtaOeoe tAtunvol,ofhIredn r almhe ljoh ett,isiht
# meadw!emesde h't itaettasf hi hdoOtt rrrontdhtudvd'lee,fseu uIrohrip udodrayw s
#  sraea, os ot!t drs
# tthttlaeu
# iter 13100, loss: [83.32321402]
# nrmryhrey YI faif leny-o s'yUvo
# pse eW eeUt, Wan FCeca slde'lafms
# onc ded
# lrapd.Hth nhrpmYleh:toddsnei ssdrpwrosmk
# hfoorp'sonhehs rhhmoNtAeiu  'ayia oYor n wMTy aogh
# er haslcr  tei.,peyyep
# rwbsdhFe,Ly
# iter 13200, loss: [83.35075327]
# uaEo'efatfOrsinTs aahbo  eototloo d l i Lerniin ehtert
#  t
#
# aoeo oMrmhfnbgu,ehango Ic win f aB
# ig oe foecyIe adtiLOllJryogayeat  -ftk e .  t ootileOtnetOtsyo nsfMfd s enoosefhw
# ncrn iraabgoitdy h
# ,
# hwO
# iter 13300, loss: [83.32679053]
# deANta
# h :asduO,e
# bd oidoetr, oo,
# htlnm mT emateH
# rlldOte
# yirvae v
# DeWlHd c,.uya alrwof, eyhkgyftorce o
# h du  r? oN
# ar urht arert;;omehn-enn inthi  topitcdno fhyrl o:, tna  d hb   l e  ntlHsdhn
# ReBr
# iter 13400, loss: [83.26265276]
# icn   topvrrr v shs vdOoyltoi-ilo
# dipo hm
#  S co nal
# u
# hte  p
# et due fct
# Tsho
#  o uovtlstmteeoAt eB  tiuoern iotetT vtnhosn
# rnr:mt
#  cto  a   o,d ehve?he J ne noor ehlW,uh ocreooohr'itnnr   hrnseyta ha o
# iter 13500, loss: [83.01556471]
# KuaGyedebrewO qhtsu;ai-r
# hiWrKdeeagr gfnoecdraEnberhun netr stnwiGnfe nrrmmg
# a ueghhseyoin e Dlh tci Fohor  T
# ;tiy
# lh e,efoarSth e n f ,i noFnmio
# r yomw
#  nra
# habn ei,iase
# me l dhwi  h ord Ttnawi e y
# iter 13600, loss: [83.08555292]
# nieD  oniei;baaed
# bba  fnie
# ahtAepneei oR  otuGonheFan
# luei,ARiot mtmsl nes?noleydvhFsG enihhhlau eoeb Rh m h,oh
# ar ,rlvIkmv enr n NatiN  BhroCo N eeg rtfseindousg
# u  y t hA n  innpoocm
# udrticRyy
# lej
# iter 13700, loss: [83.13789362]
#  Bn lH tafsgemoe osietvosh fpaaalnif tuoe eeia
# uac A a cecapwfHcit,eotonsthrur ewhtri rtcrhartdtgmss nhrie  mfathm ce loRo Oonira lttiin Y O iheMnnttitfa o
# tcnRdp eWWDhotyv byh  iWfOdaeiT df afii vue
# iter 13800, loss: [83.10427011]
# rtihp o sn   gotnsddtshoyr tsskehyoaymnas
# e as fed omel masIn,nfo rt ope ros lmt,saae otiiauua:eplctmef olp   a oaJat,
#  rhoia aheGr r ssy
# tOaht
# to ohhs  tset It halyoteliti atr o shotuc tKre ioesout
#
# iter 13900, loss: [82.96596949]
# s odboaedeehc denshHl Hydfgpiat
# asedonto ntte vieiu  olet saimr nn mGgThmoiospynd ie   ui Mhn;:n harege'eao  aaeeiaaAipeneoo  naen wetaa ac
# mAw  vha l,aKisdvu,dglnnaaena
# AghItbfeomm btai
# nmntudqoit
# H
# iter 14000, loss: [82.74790361]
# yybdnilntnespotn intenIow  foore t,lsmn in iebnd oyt,Rs-HuhahtspueAu hehdor ostt  istao gonmbh
# t i yvmeas:nslt:dwtbehrer wt eis imls'   avntm dneCceypolwetil
#  o; s   :  dope-et oiss
# fyr'en oddbssr
# eem
# iter 14100, loss: [82.6529073]
# lt:iheinA  ahWweehtp e eoathlg  cami
# iet tasa  ohiiHnueto Tl d'f      nsretrd hhrdAicfsree h
# dee r hdP'sEtcoRye Hduio e!eeaeccs d dadtlo
#   nhlwttassessfegboscrnenuvm
# Mifune.omI
# mtIesi
# RheIneect del f
# iter 14200, loss: [82.69022243]
# iBeta .e ashg ltet, hoRedFbeaN.Ol BOr-Ul rwa mom  oo lreoidantsiryo  aa
# lifnngat oI n jd,RCwi
# ioa r?io Ls oOrOr os e otee Y;Lk,sdhDpgN ioab
# asddLByo  Rona
#  an oRO
#  alBcean rubMNerboay  roeuitsoNtm at
# iter 14300, loss: [82.81426657]
# osWsis,edn Ly lnu kdfrl teTkstomt obaetcagkeuIrlioht.isTh  mn  asettenOf:argepy ehciohsim hshatdoorIsnoakwoeghrfgh hemto,,oIeTein,ns httEesytfuufRe soestywtsno hu:i ah f T  di t ht
# u  ,fdkemrE' uuia
# iter 14400, loss: [82.90243633]
# ouic gshWda d
# lh fb 'ot  ifhtrh:bens    hl sasdtin:tnhss et ;h-eaK, hno et,kde ia LeynnodbIoubvpsne t oaGdoesei   eo  w Lmsnothkf.enA?onidaagr:ii
# soei tto,rnd sen
# di:tsaeontitieEhhi   sts ei'  o
# oi u
# iter 14500, loss: [82.77344706]
# o AaUeme
# ,Wm !t'h  tt
# doomtda
# f
#  df hso  au
#  ,  s oah eiRBad k ne steeptyEtrrsreoeIdoo Id atGhah orsnOaIadds
#  YllovdroyInedhrsc gamaeinepoo fl  Maleo cn voonafo,l she,tacyUrhrd sRey  wy tththooah eft
# iter 14600, loss: [82.82792834]
#
# -a Bb' r cod oN ,meusGoBl  l  hl oo
# iblttu Nl  si lyhr
# Ll ,reyllentlai al doalstI nci hor am t htnenfBmr
# ,,n:evEnra o
# eeknetATud
# .iR raIYe, ateigsWty,,:wHntnNu HtsalhersIeaIayunn
# rl st en  Womhi e
# iter 14700, loss: [82.78066647]
# ukssmo,R u  Eo yharcOoeeu
# sl frneriesIDtndl Yrep  porh.t  lO ilkL
# iBMl
# idtuwraro
# i,ae  yaAhurr, eae.m fl pBnoe!oero.yRf er lwL
# n
# rr?Wo  Td doetn ei? m d
# hmoOuo.dsscdrrt LLe,eig d
# tt rL   hR ,antrlt'
# iter 14800, loss: [83.02059118]
# aen
#
# oKnheer rnn,w y,fie t
# mftttngre tmdaahrcewf:ey  oeetrn
#    s  neaatiort mmmell  ':  e bGesf
#   cag
# ei?insna tnYaaGb itm  s tbeta  ittidvftho in
# ntd : e er afts il he e' lter:
#  :yaHa gnkvdeim a,e
# iter 14900, loss: [83.13377904]
# a KmaeroaBh  en s a  aaaEow
#  iBhshbwr:hBloaooe Ikysy utKmclsYyy fwlawtr iotDdvmwycnfrtedtmnlauoeyes etew,ragTccOnwlaghsh:yddwsbotee
# a Iceionodn erp  wi'reOlhtor peeM dm
# bauodo
# edtr srye ie   lile sn
# iter 15000, loss: [83.02482392]
# mt
# rEcasntiriisehkan  db
# i, hddon eLhbtBrrnr .kT:
# efonkvmrre ddoB '.oeewi plossSeh etrbih
# hnlodgldsh gctasi
# w:egeaesrmelemid
# Oot efnta-a oTe o ruun!o rnnosho Eie destenertmd s f,veywnh
# r nsuh nddo
# iter 15100, loss: [82.91050886]
# yN
# lrwcis f Ets    Nas prg E:rTAne eim cgiet,ehuagclksoaNctsnhedo eg lf
# s,ci  -at   s r oItHlsrnyahdaldnrdkreio oPhnb e.lenh.tuhnrr shKhInuF kgOerd ls gaG  nLioan e dlerole lhwuratdres   ihgohnsh e Ta
# iter 15200, loss: [82.83266563]
# ha eemRsUO!i  kH  I n  s gdnespp
# ysrsl?e
# eseeviuete evea!r  taem oreOacAG a-r  eo?tss  RIoflu  ?eDmsekhfa  stara o iogBUees si v
# ibeea Cth !iLrlAsfriAFrns? c,    rIore
# n g   ?clPs:eayebI eiC ?   s o t
# iter 15300, loss: [82.77618169]
#  neti,e eogkeuol kl'ns' vMdeU
# eso,
# dd Rltd
# eooeo lto hRn,sihee oodeD. kode leumra NlsLrersoerpBOAErdfE ddsbswUF  cO  t  f efi
# eoMy
#  oehnCihlsrsnE etEordro dadtoaosSeergn fc,  s a fKif Sa?w iealGnvtN
# iter 15400, loss: [82.78900731]
# Esne erhet beye.drhe :nty.atvhOaao tko,efoske, enhah
# hohhh
# hvpyctre eehuhbdLIlhfnhlm hrrod  WnpsE
# c ceeoplnsMIeeegsysdl s tWcw vp ya,Hp
# eaaipw heThel uryaIl:
# dnww l sh'ndttnYloofhaa ucf fee  TIw   a
# iter 15500, loss: [82.6602512]
# nngygw  t
# ncdI e .r d  ml ioeiswoiaoelHes ef,wioiBI n e kl  t , vnd,a  ma': fscietN  louyh nereMelfm ho ,n-bteuo ie IKll lhaeeqe  dyf fCdttnm mer Okateotlle ss ae r
# sIDA,csdunelieyAhsiins  SeeEsceAoR
# iter 15600, loss: [82.86039845]
# Ual h  i oiunpo rp obcoriayeor hiaoefma a huahohl tei-cessoashdeed efevetl  heupnrhdwdaT aRmnpo  rplh :
# ye
# yne anrnh  yay oaga cu egiTeicbcheed fc deyp d
#
# ahhfbggh eseael
# al raI nrdnneegftmnaintlgacit
# iter 15700, loss: [82.61218985]
# pp nrswuinem,arld efu  risru mg e lerEnmihb aytKacaosflomi: alsnee eldwetbna omU
# I   tc g fMesalaen cgy at
# tc
#  irUaMogslrr ,d
# tnb ItNhitmOld
# e ,GR ea.mffoog
# s  rlm,oftneshtoe pr  noli
# edar d'lolt, ha
# iter 15800, loss: [82.48404497]
# fe kot
# , In rw t sod
# e io Hs esI,
# tg lw
# n alDea :enNdOss  awIdoow IeleyniadwAgna goM? dheRrmsdeo epK y
#  t
# givm wnio  e eRRadn Wormy ho:elaedKid dc ,fs lDau IB:u Hdnrl onwRmlsm udo i
# ttOLi I.awe:  H
# iter 15900, loss: [82.69485113]
# ana
# dfu e awttrlue da h eahadhnslolpYoh ar' Oa,asannm  n .drw,ai weahei .toes r  heRj- Ih', h. ,'aerE
#  Aar  f dksm 'hhdit
# sulsddhtfnd
# ht T:hheoelreubfvrhsteImn  pc :  rddKsmh ttem d bnrteh ekfbtodk
# h
# iter 16000, loss: [82.57592906]
# ,vpNh:ta
# .dldfnsft ahdho eadugu fhGrht reohks n  utd
# tuA i:,Bi  il agttbalgfeih gU,eiretrot  'faeltgk e or  futssog
# eh ttkiwhtcoefthhesaRfgae ddkm aH  methhsu hhadu gjrwna's vo ytlte orhep o fhathtlsy
# iter 16100, loss: [82.41855443]
# t NtetAmAte ldhd twr thoi.e
#  noiS hlamarA he ehugb  ohet
# tlbs,rAia,
# tut
#  d  i bsslrMtp oeOo fhlIth,ro i'ed i    EE
# e tfifrm  eio t uzogsiElsF
#   h
# ry t
# w ntrak
# utenttyea
#   l
#
# hat ri soh gaaTeut
# iter 16200, loss: [82.46409433]
# ufug ,t iIott slpsOmseta Ndfh
# ae;ee
# Ciayge oROipyf
#  he ko  EOEr:Aoieg rtpycreuO ospbihAsKhRtn   s
# rYrd
# o osdrdnE
# .unrlGli et  Ys tlMExpOR mirroneoane,Fiuroof:oeh hhoaibe  nlpi. ic d  og
# haev,rcsuI,Fm
# iter 16300, loss: [82.62202236]
#  U ion,ysew rdo,r isyvaNteorkooe b
# jutohn
# lourhelrds  oaprrj   l :srkcKkwi  ygw
# h os etasa
# yE fk eyp,rfds sfuyguKneod insoro  Gp
# dollOeaib
# brettseaes  p h es oH sethl wt lo nfrttee sOrh
# p  yukDrAa r
# iter 16400, loss: [82.66142481]
# IergethWbaa'mod,Grogavewi  sdnidylkdtR ngs meieelsi
# d m i or enRad yytyMh
# Diw oadnthv,afynoytoe  eyftr rkpsntd B,eeL yNhd la
# n r Rll asknhia heR d imysweawN  drrih pteg ,eket tr ,h
# dsoyEy
# isenoneeE
# iter 16500, loss: [82.65205362]
# wryItosT b
# edeyRrnhostNy nlt cettnaidetRty d  EdmSe hrsN t reyr,s :eorrT  e slbd
# oeiesh
#  IyHe
#  a pdyaaeyrISsiskT  lNtBee  TyeisNe engy s  etiorIity tdotpamaIt GGt  E
# oes
#
# af  apslay A  Iuse.w bi ces
#
# iter 16600, loss: [82.70799568]
# o  no r a u
#   I
# s,l?  .Gb rdIq.so
# ca
# t rRhsnv,h  eoe,  w  Eilfse
# lmosAifoeh
# i
# secEud gchfl  B'dGiy Ilnhnte
# es
# u demnw
# ansulRreou
#  t phuvudeuCsooo h
# yn lte ho oabfhndal uHtR  taG ebnte  ikr a roLe
# iter 16700, loss: [82.87765924]
# ;nk  b k ittlioaseIinHrwus
# rlepstno Untpl
# ennak oBtrk, GolcfedlwsiemslFnyaA;
# giAwt e Oefoe
# ooiHe ldl fgtoe'eehowloai eTe
#  a erbdfcsEoaraN He rnlktemnIo ueoeLtRgl.owmtee
# Ird;wsobMtyfFrogh l ea ee  ;s
# iter 16800, loss: [82.73197483]
# as T ytnndDa moeumuntyofswe,e oott.  W dd;uAdisn
# wTharr oteOi
#  m'gsi  o  hD ehSio csd rsEs eegwtnge  whi  fkE lFesm nteoslrwe ru,had N,st soFIai
# evs nwhfc rsol'UCdgtts
# uOg
# WoTrrDokFrO Udlgt.vsaUoo lu
# iter 16900, loss: [82.78373489]
# herloAswkh
# -ol
#  pknvostEt-nea hlK
# ,
# p OsaIuhSta:eit tpEnottsEat
#
#  u,FM okni ttalle
# RdsURsUd ir
# hbde  Y ra,Tluisblimwh.ne  sEeaL
# nr??lEno .et
# mYeo
#  sontOteKimy.ekTKtErnnoti F ,lhon p te'
# SaEsIk
#
#
# iter 17000, loss: [82.87238668]
# luUaoeOt aY i  a r eCet'in yho
# ,nRa  c yLFnhm inSey
# uo tyntK  u t,sa aoonetH eaatn'ehrtAwA yore ac iteti L
# Is  hdo,Sl   ohhes hSa   Ewtiwas . rki aonooy
# ith maWaIf:o
#  haPa SwonaoyHed,dt as  hddf e
# iter 17100, loss: [83.09588091]
# rItEuoU
# nsorh
# eKGKnGntseyFe
# e
#  o
# aghi UeyiOfBOh: hftt Odi  mwcnHYnKlnoo nODs
#  l nR vct
# iR enIaORhte olhrt em r
# EtSst
# DtHh liK
# n
#  nee eO Y eahm
# YeaIyn aoUarO
#
#  eitoae
# Ylwaa:U iPy
# etl'sRl e eha  aW
# iter 17200, loss: [83.3512292]
# a
# ueo   ga s p'
# t
# aehBdls esio :m. IeE;
# lC.aidvanw lOuh Rel s b
# miraIag.p l r
# e Or
#  r mt Oi oiiiiSkue rDtn rDM ,tiRkra
# etrrkh w ryEtldo i!osHsIda  ossrlgosiKyKIelbd fy t iny OhOUr  esM
# o R . t ngie
# iter 17300, loss: [83.50074653]
#  Nprhthiee utmonsit
# bnwhooeaeCloDY ehrId ataTih oiad.vhotd
# u emw,ooertwrflh pr theh eovntt: eoi,retstnywae s,t. e ea utae w owerde:i'refUnGHehYtg dmgY  euB' trS
# boisiwa psts,rt
# Owto drltw d
# eeabheiahs
# iter 17400, loss: [83.62892521]
#  BtatsoeeNeah wrasw
#  men F  Taaacew kneo beie e pAurnT fa m ehotmut lo
# ia
#    sen  u UnTea srhh weeobr imhorts ese m ndIpi  tnJe
# m ni eNo eeheo hte nhan k, ete
#  a t,aagmTeedt  he f C ruew i kati
# uweh
# iter 17500, loss: [83.20706593]
# yxoweh.hp Bdio:l g
# wR ainll a
# e;
# h eltlhsh  ea  rrpmoPrtnhdoR koaoolHowhD  ,t mNdr
#
# eia,iaia
# slpr ti tal t
# uoeB l
# dae,bIa oog
# iva    ihn
# dhsao
# a s
#    ntw.aoIyTRni e!e BesnKInd iotiiye  o InPyeI
# os af
# iter 17600, loss: [83.09377083]
#  e aehoeuihNrBYsmesd oirtn xu ehsnrIsetgfi hs;  era ange i
# mtyeeohhId
# hoL e eN, untNH
# prdlt  riet idremRtayh
# dd;HrR
#  E hGrn
# fruohtgt
# a  f
# okoTOl S Ndhndhsyeroon  BmassuOf, h    vfrlhdurWohndddoftHNoi
# iter 17700, loss: [83.1586663]
#
# Szs  ao IueeAmPt RfP
#
# utek S
# Ni:iN
# r aRn
# huSkiA :upd'er:OfNRbN ihtPhlh u iGes ny mAe errihihhoyatMotI  a;cd,a oahaom idoAb
# maPh
#
# sO Mi  L E:bdltfr
# tist  iA d
# d
# M m,.bHSR
# R
# to  :m:afSdM,N :Ep:si
# iter 17800, loss: [83.24917051]
# nieoGtac et,esYayad r E i Ob eO,pw.reevnrwn
# pour thOT a a  fCtntuio,cipe i aTon
# rswr as sete togod.ted fa gCkyTyn npTw  n:sg
# toroueha To ahaelatokeici ey
# e Be,
# ,? rpSrelw;u
# lr
# br,aed nei.slu,dt,:etf!n
# iter 17900, loss: [83.38727587]
# fsew?N oh
# naNstdvk
# yuLh,aeog
# eo
# hsO eh
# e:gt.te
#  cshwgno:yau sooI,.fR thtsoiAdtn
# nLchvh nlnh
# gsw:eotse
# fe Bdip'il
# fIc-o
# s
# at hp
# s-ormoadvpOsyigvOutON
#  ea.tfMhe.tnh ?re O aO ovrOaaEEeu patn
# Iy s:sarG
# iter 18000, loss: [83.3344796]
#  e tfsAeitpe aish stegihOhenoh:o etrisiecse edsntooFlneyR,u  tt vetiurtom:ei.t a L tm d mrpmw sSo eu otd,tbyOte eh h Irrait
# thrruaI
# Weipeee ,eetoes s
# iswhkoOdeiis!  eesaht lsmW er
# ,voto narhhstrttO
# iter 18100, loss: [83.29751595]
# e., metrif l esonoraa. lgIegn n og re oetisgehlh ef iirnk  tuteeiiltne!c toi h -
# Fossdehion o Ao:etdrdLdtsemainAeoesh
# gg han ,ec ss he
# bi  o
# see
# ep pm
# oawnis edeiIdS dnsn rg orIho n tsshyen  noouhm u
# iter 18200, loss: [83.03379029]
# isttrslwosre   gseuhbo
# eeffnl Ee srmmefoca. hkue;e,lrEaOet yn
# tb eefhseahadwr naetaoC 'p utp n'eenuseeteayihhbl omh'i acie
# imi
# ,a  eh'si u ena
# aheuu Vs;Ode- dbteierdgd sageWtn,eete' ea pGcldee akh Ln-
# iter 18300, loss: [82.99953976]
# ysof db
# hhyyAt ee tSl acehIwEehNu dd -ttnsAnh   eyuo  hudyiGetepdr ethP aisetu d  ses hn nmtCah o Dir hhy'ol,l h:no  yu :s  dtns  twoa ame ?boo hd Nhw Iee
# oaf ehrw ohhtyfsyauh
#  Tta  ht i'tma
# afkescc
# iter 18400, loss: [82.9610972]
# eoishl estms usn
# me
# foho,ryasmkEseehliPuu ot,maUhgt  :' i;fcyegH'iis i alslast
# rgetayNatm ieat:go enh m sklamaT ur ae ehwoirmee
# sp ple  wYhel
#  gn.m hmep
# ol-u
# t
# tnd ngYic
#  veane toksDo  vtefstwi
# eou
# iter 18500, loss: [82.93159266]
# f u Ao hsheuh d ndw ndmgI srs  CoEois
#  so
#  ei:la a'cnnoht hotO
# igoC
# hbkn
#  S.ol, wiaRi mishr   e e
# tO c  Rboe,rt n s r  een,Nkee slefl
# mcBLoreys tErknene mrwUWtioi ofidiewW so
# euonos,st
# ,,I si,oo:in
# iter 18600, loss: [82.99887227]
# fh ik,
#
#  neh ro:  e'aegSaientiar
#  dnsvaroneIeh;riNs ,,hi f
# vr
# ,a gt anoine r
# cfkdih eAe, e lifooaleenhtb tad  lnteMo
# hoeWnnsk no Oydlne TeNunpfmio, ws n e kosnifdMfbs,Mnstbo eotofweieekmh
# lfsnreusgi
# iter 18700, loss: [82.74362004]
# gcoupt  h-rtseth a
# kngnDe  fn, onwximw t e;besu Oe  rhe
# hOsne.wh.T l doT.enwSbekhtoOsh,aop,,  pm eah, c oa u a plh
# sl nyoadt  oe'rnsktathAatpnwwt  ; :
# o   necee  se  fCuee noNhhe,s
# o  t
#   ioyc ,ihtsI
# iter 18800, loss: [82.63512963]
# louuhonaiIen t
# a!ETsttheko,m Meuacoo mnnndt
# snL dy
# ls dnomee
# Ygn
# ee
# .i : v e  fMst r
#   glmadisltsi,eri tt As
# ayr, wtsaterhrdwr Lalt
# cwfWO
#  rvyeyoupeo rny rU.nuty,so seBTteoeess y e Ia
# ;lRnehtsrr seslo
# iter 18900, loss: [82.7269119]
# lhioih edrs ,eu  eoee
# l Ide
#
# n? hw ewr s rai mNTh eitta ,ra t w
# efxrtpi mtaPe tmo  ef'mhrnre tmase ulel mh
#  ed ynyL
#  n-m
# mhn l
# bLkess oettam'
# ,wtaniO oe
# necembe ho:iht. io
#
#  Tomtiey  i ehhos vb Ao, t
# iter 19000, loss: [82.76580671]
# tise',vtaeeltr,aihuitsyaeirtlOendsaot sed Midhohrlna ueul  sthnfeas onb ,wd e
# et
# oe evdsipetbe se.a?pgerresua oaechneee ss tay,n spcstL yoer
#  Tgwysp, osi  oeta nidtoei h.
#
#
# henfEltRtseeh trbsts,f i
# iter 19100, loss: [82.55959685]
# p
# iNrhce o t
# ho:sEaykhe do tHnriOe egs,hc Ibmrfrl h?ok
# ktl Umd noog re to I retyreohe a  lg
# r
# dote rfrlI.!hsd: d
# mJ,
# p,t eu oeneyah
# euh,tT:
# o,:hncnsevrmh nR:ok te   tonrr
# Ih kts nfrOelwtfeahAeh eLCt
# iter 19200, loss: [82.42659706]
# t
# rawnevomhaerlTbReyccksshweharOnla,u
# nm   v icm !,sudmaew:Teo wteilbvErtai;igu Ei ed , b sNIo snee'uohs
# im nmiteoh olon's
# iuuneM fToogUep
#  ,he,  orihfdoten  v
# rh
# nat's
#  u nh
# ft sIoJhohn
# v niiteitsn
# iter 19300, loss: [82.34735305]
# heeWdIe h te pL u,
# ,gs
# hifei hemnluoihh E lrtehdguhttdelJgiitosiheoiwrileinL
# Ethhtvo tav  eulIs
# arsh hsnOtoo
# RcrnhO Io cc Mttt aDt ly e hsc
# u
#  r fieoht:JghoIhyeiw,hi
#
# i,:eih tem'ou :ds  Mho r  -se sl
# iter 19400, loss: [82.40979073]
#
# hie
# elnaIewknhnn egae m
# Ol!so os n,p tsfbt; .eehloogeIyhcaah
# t
# pt ie .deeeeadaa
# uoouua iRe:oeele Man ooo . in owskauomsgsR
# dtmt eTsRgsaoehee tkr
# t et eE
#   l  bhg i  it
#  m
# HMeRe:uocsr olIWdidatsaiuaa
# iter 19500, loss: [82.28367322]
# i ',OT  epR
# nllImEtnavio
#
# t
# slye tes aFOC eW .otIo';ptNsanOI Ob
# hCOReNO.ipm ewu,o,s,Ruiieirr otthlill:tallefEEa hgue,t
# Ons;RtEe  O ;bv ImaaTtlhal e
# hra;rt Ce:ieeeo.oa eTiunw wrT.eismewaae
#  lR, ote
#  Eo
# iter 19600, loss: [82.31580488]
# !Rnruudi iuo eyoos.sOts
# wgo mw ethsta le O
#   p,co  lhyOftrt tl ts seih noferm cmectcwelRnsoat ffuh r ahoga.ta.y a   h mttbss uanfl
#  h Ro e ;i wsiTctnl tk lirtehdsyaym
# aoNotI ttEEbho  t ur
# tyor.rpnorae
# iter 19700, loss: [82.39861739]
# ennwoathehou,l?ta   '.: .e
#
# uEbIlahe'yfy anou?u h lhIUoaE yiEnf
#  ee
# a'iiib
# eaoahNt flU nfu oiiobpEsmtroeG
# Ol
#
# nuh,io nfbtsy
# :e iyIIeuiissryl o!ea
# eRolge ntubeuyRa; sfht: f!:moR st.safonIset ouyoyyf,
#
# iter 19800, loss: [82.46354799]
# slilee. .E aOyiay dkmrse!Ottf hwoyi
# la .elrl ai.ontro
# dlnlnp dTe nbtC a
# fdsde llrl
#  du.uyI,  tlle en
# h tIey
# kaee;nase n,usoh
# IIaa nh:h
# a  ntt r: ,ur   nE ees h,rtew
# n hlh e
# ah.lda
#
#
#
# shoenIhls
# rE;mt
# iter 19900, loss: [82.31804448]
#   f ys htemew omuyhwwiss l u'  mtAtsdnyotudav nsu ajmwhubide eO eoheoyw wvdeaT
# sso'eNtunn r isaioeh !  ge dr l;ohsvWeT
# Oeow
#  nfnoa ,awm? :wut a  ,dIeay ewh
#   Ses namweyoyth Cnyrtsye miow
#  feoo,ihd
# ,t
# iter 20000, loss: [82.24033744]
# fhteowy g, otw yl, ccrc?iIue,nldnmb o.yd    Fssh'etNe?iho: usl lsd ie-:ohetop.uscd kid,
#  lhrcHhkibwtyda
# tny eo :eR d et buoet u ,hsu
#  h.bch!clrmbta hJctus
#  ss L
# w
# c
# iww;
#  onroecutec afl ri
# eh hsrwh.,i
# iter 20100, loss: [82.14284267]
# imtbhc, h aiimddaad she hytoyEaa  aoaoAs helLa  ,iLellsynsd ludru?
# wi F sC ouasoaf a LsRth
# tIol de  rmV hrt yIhaImeoh e ea,rtbs
# ;h
# ahli- rheh hdpe,ese br hh  ohxhoeo mtndehmiGoswvvod
#  oteihidw,tneen
# iter 20200, loss: [82.02774735]
# odhuItsd   uEoStiI  nlecI:Tnrta: emnak to baly o o TnsrlvMendsstau
# hNtfonITIh o top Ud
# grosiRoiusCrfic vt l
# etto
# sommorsO stdRI  mhswrmauat sdo il
# b :cwereulowA,a -sfirr,.nhatlJ.tlethmtdn Isaneruiodha
# iter 20300, loss: [82.14479731]
# Ebtutaa  w romasgars  ho oe eyA
# dormhs.  aora bta. gf t aharaebt
# rea!a ri,;T?ab Aoimruqse, o aa:rt uc,aMeu Tteosu -t ogb.c
# ms
#  a teo:hi  ,Yeaoetosos  l nt jdeae  ,bekfst . ifh ctcuanrafsw
# oh vy yo,h a
# iter 20400, loss: [82.28542302]
# yTonm neeuktubgummlIeeenhnoRA,rtiaeTtmIOnoLlope s. CeauLoaanuin,ihRisoorkydOteUIeltdl'ihwut
# rgdhoolgicsni tdnete,eattnknlydsemleo? Bju Al   Mi CiolbRgocttf t,Tmss!eooedesnneDhmt:rs
# gr nenteiMsn,sep
# h
# iter 20500, loss: [82.36447307]
# T: AaTo
#  ttdltalhry s
# eoat elus.eig d aultwn
# b;rtgtnoa nhaTehwehbhuerw o
# nrt dnj,rntewg ed'eorvtio',dt
# ttusnfd  v hnda
# ...
# ;el 'i:tn;
# T
# n'rsbla'i
# g e,anitintii eoouAna hntr'oit nategu eN
# fhfeet regbvto c'Ty?IAoatte i
# sCBl' eta t nsTEl
# ueNus nS i
# e etagahaEom l:me;ett'ubA wohtut  uhi
# dr
# idc
# eO :l,eaIm d ihmslr
# aeAne.vom
# iter 40900, loss: [82.85012203]
# tteteyNiwrWw  -Jyy, stsn rN
# an
# e itl a doo ,Oroaaps Bnnatsr
# wpo te:TsenebO  aeep wiketsTh us,ps
# niha nwh ImTrul bteawl m  ,Aegocso
# nMWbufonnn,o der  dRuavsAndERyl  g roi, Msn,sepoee tn
# een nisun
# iter 41000, loss: [82.90795043]
# yuSwnat n
# raitn
#
# cie hcBaosaodon;-o:ora wWsi'h
# twtoedanf
# t s  biairOcam e,eheh nopos  d
# nnne
# Wn l etsd-rDtyf lr  so meA
#  tnItdn  htnneWdademadnai-ao-rair
# lhn
# h tie
# iuemtitc oiOeimqi,
# bo?weoog-ln
# iter 41100, loss: [82.88675617]
# cPomNl v't wuitre lbtteec
# et
# i, hl e epnrAhaow or rnhKa Ol Pra
# I r aecbT d
#  etne efa ro   ; fhh eedA Pololbiemft,n: oh an tee.e e iw swpbs tohgs b ct asnhrh e
#
#  L end .dwn!a c,  -      Nheu
#  n a'iHa
# iter 41200, loss: [82.98578522]
# hha
# mset
# a e ke
#  rdie
# sioanao tmd EIb  trs ssRdeeht;es:eeh
#   ;A  wdbeise o,e t
# w Lso i oeeeo?ienlvRho ottaIye  dlntteEdlab una r Pfot qGlnodV' roi heIn wac   aga p aiEhee rneOiltosg  ea eoe oIeeRb a
# iter 41300, loss: [82.97859432]
# ineh md  I u,To.dyl:e:sBf aenI
# aeodslobnsa hmht rv,aad
# tiwsrogIocod eVs s ,Bee rylUI
#
#  s osO ieeE tuaht:tes hhlocryiss, n eswe
# onieaeyu  .ymrule yte:eo aARdagmee i al,tetyhyhan dedo nedFlio Tyeh Oe nM
# iter 41400, loss: [83.03219835]
# eaUthaeIc,
# i
# lbdl ,c i?Bcseo
# mstwbN?fmOe  efsnuotieii whN  pio c aG hh h co;I dBt  h hhea.tAg
# cco N?Unytsderaedieootde ihe s htlnet eeef  ihad
# i:r  ;cGtlifFt
# f,ie;  i,uEwfA ueAmgfCrra Gn yo  haewsfIR
# iter 41500, loss: [82.95931407]
#
# o f e sa deNesiMemh dYc
# l  o
# t siogo eeyrsrh:w   a n
# ata co,muugoaeuIn
# uOloe cCeucI kyl  e e eteffnll
# wdhmc;.lnuS Lo;wsdsyuhm,
# otRoyt.d yfnrar sAihgl reruwseo
# ,nboOay.yat rorn ecohc
#  tuvI tGh-ussSd
#
# iter 41600, loss: [83.05414983]
# ,isd dset  rteoGIen  w
#   dste,e
# c et H
# n
# iDtwus sooEtrssurponeo
# oe rteh WnBeseeIn
# P toih ehnr
#  nK
# thIp:urx
# rouu e  .TI ed,wt i elsu ay!e
# Goybtbaeca-
# TE yo,seicasnHcgey Asnsuht ry oto a :!nnl,e nml
# iter 41700, loss: [83.17693134]
#  elsPuToddl Awa:dwtneL  e C,tnuhmorlt neNtso rlu nCel
# :r ,fsn  ? llamawi e,e  cnt''keouIfn  osuai I
# tlsoseadyiue!io,e'koopte
# lo ,d
# phduaab tlo miahah.IlUnceeew.mrAavtl S
# I aymB iHTy sn aeosa,rthiuess
# iter 41800, loss: [83.06450975]
#  Oentoehnno
# an
#  gternb wl   maocomMiee
# sctt g.laco ,nB e
# wmi, ytsseshtGeisewetneedei mtuOntneAkay'riorg ,,ltt: s  o
#
# u wrtttrIsNonstgr
#
# ,TOeearOaenOnonHOaaidaO
# ev fa.ace dipnas
# c ths
# e  e i f:e, j gnb
# iter 41900, loss: [83.04335962]
# 'oIdatutleolm
# aulaeatoho  ee uthisewoh nmethIfl
# wmotr dfae
# reaU,Lr meveo;thh eruIneayedre v TehoRearheet
# raa taAWtdelua
#  lnh e  ttdfc edo
# ges ilmeA tFa
#  nNnfITeueaPtaeheoubhhfu toeaeornaNMNnnvoyo  roa
# iter 42000, loss: [82.95682547]
# rout heed
# o i
#  tftIl otoANAp H havt:uA    I rlg:utIe
# aps Fr a,ee r:,sbwaoIy  a:
#  e HUh.svoa
# l:slr esitwK   ayAeEuiHTimg;ur CpA
# elfo, r awtlbopuI
# n tAo faeNNef scidsAhiRi em omd dHl
# Kpt tosenlsysi :sI
# iter 42100, loss: [83.09279836]
# Al:nI u.Rorhi;? of
#  t t
#  o
# T tt gTd
# i
# ohetOlia esIh
# nt,
# Eto uenabl iT dHehimaTe-n: ol:eirooitatse
# !re .ipEhneehqItusmele?ot oh.tl'rwemt
#  Ti eiohm Otr
# eq
#
# sdostAa,e  nnioE
# Te gke v
#
#
# ahrrat r
# eI : lswm
# iter 42200, loss: [83.05994023]
# e,hn f aCc
# oiwet e
# v, mtr,aw
# NlhaaT,arnlrkle m d.oe' epiateu
#  ripRllsp  Id aeuogore
# a reg seo ?totasnmrms o     esErryegoemtum ssvP  ? auoitlo
# .oRa:enT,afPe'ee- enspv:w
# mItet
#  heos e rohEyuoan  .rT  ,
# iter 42300, loss: [83.01704629]
# i iosihm t at tkhtrgemyg, fCar vU  o pIlyogah a,' teali nn
# irYpgt
# m,,ri t   rPcinKpp eoo ht , ah:gtnege  kmu bsao
# it duih bv o eEigiednee
# hu edTi  rdsTeoaf:  y
# ga eemoageetw a lmnu.owc  np'nhdir
#   an
# iter 42400, loss: [82.88574676]
# a athid oIt nn ihe. n e da eea rMhN loP Url:e.ehes iu uhdomt L:to::m.
# e:l'eehui
#   :, rwl  nnooi: umONdNs :miEgt s bT.ohITsot'teaLaUpe  sTdyogR a y  leh teu ag sir ,ihror vmIl d.ot l enTslorTGoa rl sn
# iter 42500, loss: [83.04703374]
# aeW mnii
# io isagoOnmNla
# le,oLbroohinhleeednev
# TiptudddiystOI e'mAa
# oayepoear. s h
#   np rSC, ?oipdh mrtmDna i otBktetoroo
#  if eaas,:mtitwcNodhhTgettyg tigPknPi npIdm
# odeIdia aa dioet
#  tinnr tioeie Vnm
# iter 42600, loss: [83.10180416]
# PNesCe,
# trth h:at m
#  seSs rtroI.sae?e
# et rne alinmr   NaieVdrynru.tohiln
# a:enyrifi n rehi ue
# a
# NonpNiIlAdihCiEofuoIgRy oaUhi iiool E   ehI
#  BN.hyEhhoevidO
# omeNroIm
# til 'bswt.
# thle
#  eCie;nNorshdomtE
# iter 42700, loss: [83.18533157]
#  etorTsV hh
# aOs
# .tsmayy
# n
#  .yseti EE.Ttsll
# uptm-siW:tds:weo
# g.s imth sipfoaCy nhr,tyKaB
# tost eoh
#  ikoifunt
# TyrLeitaw ! LT d gshot rd db s  st SROTolrdllghf
#  hN
# I
# hsnaS:daehu
# hI-Irnps ulaiEtiek hn
# iter 42800, loss: [83.30109478]
# E
# hyd datt
# ktleeyf.s,n oc hm
# liyo.s
# oT u  Po  th yhr' P n,:NaikfnRm ro
# sy
# :ti ,,dtheou ;iOyEeC t'nCoo!fdr.engu f:toeliPrh t  htKuu
# i:T I:Pgim
# ielioirgmA  is
# sAOafFw  t
# oea:Md.
# OceOoa dnawikn n  c
# unr
# iter 42900, loss: [83.50008404]
#  e
# Isnhh
#  oT sAiU   aO
# ohne  nt
# Ar;rutTfeeuhnooli hn-  ,h:ihcattiu  staCC   e
# dtA o KtP s
#   dCgHAohyw, t aepNTlr ouAEp mr
# agcm rt eyhiHnyoEu  sss loy
# taerh  Eood'altac
# ae,Hdm' l
# hrOanAnhU:tTInslse
# iter 43000, loss: [83.73430441]
# c:,s  oyoP,LmEuO: artRet
# ohrttinoi
# rrneobou des  rnIoIwaoir btr .i nWsat,oU Ubg t tr,noNhht hO
# brein tyea
# yeIuesHwe edpoorT.e  i
# e oHgt
# c!To, letwwg tom ,vOtaLR ehTe:aeh acsibrehnb aHeI  on unSeeH
# iter 43100, loss: [83.93230111]
# tys,SWnac aaLhuroe aoersetih
#    uta
# el adnwai,de cehOct ueL,didmmTaapbyr oweh,oOo r Atr  BsNfvsrfr lnrtoasbraeoeis taoiacotwe
# rs or aAae,Ir
# sSdwa
#   yoadtaae?r rCoo
# erri os?ba
# ao
# w
# eaItue hlenhseAo
# iter 43200, loss: [83.5700446]
# as! nt.eauaety
# noeht orrih r nrafoteeogs  igoeiorrdo  Aae!b. ,ynoayhohsssylt, ,roa
#  se  lgHad ae ? e
# atftaeraec
# e.o,eima nt n euhUyops
# uf  ,cha
#  ,rm eT hlt heorf !ahsrmeiyh sy s,
# yo-aOseiti utoaurtui
#
# iter 43300, loss: [83.51023829]
# etkB tto .noecaeNaehwmfnhyTfs  hit h  i yfln eEg nmfecsnr oay e gele r
# oAikssrre
# a ou:i!detIh ttoosoOt  tNlnc
#  o
#     Ihfrl   t  teriw: cvge k
# v Rli
# r srwcad eiiecrg?e!gatey ofuow  kveofnoWrO a rh asy
# iter 43400, loss: [83.42525033]
# o ee wehosO t iPIs ,h  rNrss  AoamOni hR gtRv fuiudsue il fdr odphhh  eloat
#  Sd t
# hthopRI
# nntato ,,    oto a wdft,onounuhjrritErtO  bboEdie roan n,yece?mtS i tr ete nnhasm lottygectnagsgaoeept P
# t odm
# iter 43500, loss: [83.34377564]
#
# oune
# e inetoh eoli rraaershes Teb'mhrtsHei
# ihoynt
# ,it h Bc
#  Timne nwisT
# dahaenirPlvO Hsewil ms o t,k   totie au rt. Mat eo hct:hRnrs u
#
# eh
# oeunrnonaar,rnl siim hgnhbltAghniI.Ih
# u
# nhenagurseeBTebcd.a
# iter 43600, loss: [83.20739622]
#   vtuilrrnnenhednto n  nRsiv t  yw,eryt Pctcn
# ett gc  st stAmionsl  irncehmm,nwstoce
# :,ol,Wouaswd,hrfrqms noTKfme nral
#  lkr,ggnmiim n eeolcebuetitdusaa
# ontr epih lottiAa
# etnmtt uI RItoEre tN odtMa
# iter 43700, loss: [83.09705168]
# n'IPliscEs lRohhtoPCgps oSsitt' io?rtoIta sie iiRPP nnSo peoeed.kmnmtanulT ntths
# tt
# ittywswEat k. wfi stietLglcneetollsAt uL
# Mst
# n
#   mrl:Ihhto aehh l.Fs;ygw  be-e
# dso seie
# .sh
# ten sxttIynd PAPWsiSa
# iter 43800, loss: [83.04670182]
# -khl ge
# yphiaod lIlA
# totIrt cou dn ngolehy
# r
# mL tiw eelsed mreiae aisn.R
# o it OnyEl giethi-lT
# udobsmt iuIo,sa s
#  dehol lwruo ombEaRa hh httmOsRsesnl Iumqeusy
# yaesoiosL ni v uttItiugbalae
# Ssp I.shR m
# iter 43900, loss: [82.97682811]
# TwIrtRdyn ro i  o luyh,hogtdnttd y  bsrBwtu uhsI niOtn dS tss rii
# leWlem
# b okeeh a tyldA tidel cnspueeah ssoesr
# io Se a!s
#  hds' mlaAoE eoaseeas
# tdRlp ha ; i
#  nmvAne
# na
# ddhRe  eTStkvsleeoh  ei e d ido
# iter 44000, loss: [82.98819755]
# hw s eg.tfcsn : 'na ey sraarsohiegrse;weahw
#  ' n ab nnsseoFh.he!ieahlaiofnisIl  e a o'uDh chvgrhe,t ld yDei
# hoshtilfi s
# e.
# sAYt s o
# ewannd wrsWsomDl ts hriPk vrl!b iaen  mytTio stem  ophewwi
#  ahts  dh
# iter 44100, loss: [82.89376168]
# oWshn te ehe',IAhh:e hohenohyCeeic sDi thTeAwua
# eys ns p: l
#  e
#  aaeI aF
# uryh hw
# om,Nrrhror hei. si fai,fFasr
# tkp.sieenleRASdmoaeraimhp !n b
# eWLo!u
# otnrt  lwdhnibeOh ArNi
# eroeernmhia tea
# Eeor lpsnWs
# iter 44200, loss: [83.04734171]
#
# At:od.
#  aOts .nASo ihNs
# etOn'!ehusEhee O
# YtbraeN
#  AiiTSe Z,DertOe
# E;raTsOA,
# ofN ;, INtSnprb h. rna,dsT IA,gr e
# aI:eSv w
# m  aiDieiAm.sSA
#
# aoNSo,tuhpoerSninOdi
# y anIAsg
# Tne
# hhp'TTA edg iRie
# eeSTNIto
# iter 44300, loss: [83.28928258]
#  .btcB:wSds
# Ohormel d nh   hndnho sOniih   aO ;,u Thu,naeuAgB  t nory  wi mTbew n rwgeThu!hrte Rduf fOBoeT h.mrohtds  sNo:
# geo a
# r  : Thunht:NerkAAhtw,ufr
# lusS e?: ao ;td w srTiTe
# re
# wnrt eegsrnIo  e
# iter 44400, loss: [83.4845854]
# wtn nZ?cebrfanl ,np edn ;
# kNlOt pet u'nntt
# fChI,h  O
#  L hsm sh stPu'hc ;e
# sg
#  ee r NaiiierornluY r,.nig oo,Lhtwc;oFSut Nee elGthd at:tn edawooxSwoIn.mAweaant:ho  ION
# hogsocTr'
#   Za
# e  i r; ufe,sks
# nt
# iter 44500, loss: [83.47082513]
# aSI sbOTihOn
# ynr eoefOWaootac
# enno oofde: hoSa oeaesh soenn,ybskeSAS   nomtt tcu u
# yrhvEty alhy m.siea sorheobiihBu trsBAeGAe Onyo aean L hhaaOooyOow hyISIt,
# E;hrtsso dlbedh
# teTNs  ,v
# Io
#
# payN
# ihose
# y
# iter 44600, loss: [83.58128098]
#  eEius inCsmhup.iee
# irco pg
# znmeAin teziesort
# ceehtpi rd.ogS
# eaazonirn tnnn
# tte acsL I Mt
#
#
# gdaNoe dt cehsttbz toniatyt
# u  ee uO
# e tdko
# hic ah th a
# .oswa,osuhm:ro ent i t-otoeo fhat:knoufemr: i
# . emNy
# iter 44700, loss: [83.32192543]
# thlvt ee , l
# letuty  ?efwl,t
# ee ,Fo ol ry
# m  soi.?ORad ea dEh,t se ctms i
# ritelhl N releiohte  ll
# etiwFiosChiysi altitfanpa iotteAdeis svtC a
# hn o!eh ot prnn.hooaftetei,
# s dpwm FeithAkrtlydh c nteeEO
# iter 44800, loss: [83.06913879]
# r
# o uADto trrcitfeu   s  so yittgilsi  s tnha ysmne cyue e:bhocwsttl, yatektcrao ' lvorieoanC
# de
# o timodutge' ,e'EatwsoCoe:,h'aonoattO
# nlrlrwfeu htt  oNo y
#  Wwv. s
#
# ls nNun 'anton emea
# r  I eiucsk
# iter 44900, loss: [82.91084333]
# rT esfgy oi etc adwstemenEo  ,reeo.tc loue,UtysAtg fni,ea yedhea eg tckg neiiiteeConph kolmyuUh  aiaasramU
# dst dy pne eiEhon;n' Aeecietiloehdnsiwssnahlhnphh n
# geh s,hwestttrawirrennetmrauneh,r p-hr yl
# iter 45000, loss: [82.70693451]
# ? dt whno ToSaSrieeeuyd
# w ecSe
# ssnc Fo  grkolsnns eduhc
# wr
# ir
# e-e:isChsetoohea
# e
# tht
# ef
#  W
# tite
# ?'en.yrMri
# In,tu.
# or yadahTasw leuoI deo :tM
#  s
# T  alr:eSoio r ritegM bf
# eeWSuanots,luCr ao
# hyCst i  wcs
# iter 45100, loss: [82.90422494]
# t  tueo ryao lus  n,k
# eeotMoi
# r
#  I
# Yahs:rsheytV uS nr,.snhohselr ,IbgretheCou.ssdm
# l r !rnAS'ck sidUrflo h ,olo!ascrW,'eselau oissrl  tr n
# nsrr,BhTcf
#  desed s nooh
#  orrun
# Nrf .oi
# ,o'uwnl  emrYni.d
# iter 45200, loss: [82.79571071]
# ?enmlIbma: y,iHt,Laelondt fse pib ppAnIu.tiBNccsu n u; stmAsbAmc o adacle osr a
# ale waro .nfaeIid wthin
# br;yts,d .gLl 'motpn nVbmeaIeaitIno ohoelylesttriS oY gsyes nw-twaSld a 'e lkroherit
# wohTA,se Av
# iter 45300, loss: [82.72308551]
# sr So gV rrdon TloiudReema
# nhm  :AIe.,eh,irs.IGrd,rianbu mItium l  s
# rarh Vealsabrhni
# ;ci!'ebttaw,essda;eEidao  lLeth usnastr
# gl
# oeb
# oea.dnnymey sio,tII;anen  l  ksaeGli Ll I:  toiapm sl  OsR rt rd
# iter 45400, loss: [82.74353447]
# hdrlo '  otrhIsrcoSofR.
# lma,cor
# ty ,ulthn?fep el
# rfllt tSe,Ngoi asoliele Nd sa'aSf rFsdohoeadttarogsorenleueki Cnhtishos hesee
# a  c eg gnke itersyeeseoeo tahiyil'   he ?tre torlrkyye elAsaf.
#
# shhf se
# iter 45500, loss: [82.75309464]
# uwfn'TdrudytT.,h ai
# wrnn ksat ruw rIm i
# tuIorg  ieorr  s flu,e,dnp
#  iiw Nan hs
#  tceh
# d
# uprTi osuc  'hmiylee
# ecnka
# megpeh
# d ;eboirSiwi lC r
# hcur'Lhl
# r
# Nmiicf
# mm h
# aieshh
#
# odeeo:efrwnnns
#   srialnosihc
# iter 45600, loss: [82.69414712]
# ea  y
# y trhetn
#   si
# eohw,C  te;hi muasrnoar  wI hoy H R ae mOwlnYNTNPI
# eiICsonnIoaoIt,u eelet'rknwprh ieRntlrh huthAotUmee Uh eotutretdadS
#  tieihttsMm ao ,IrwsnrI,bieoeeTnwrAdomC an
# noRfeAUiaaeT,l o
# iter 45700, loss: [82.70558891]
# otenW,ieetd N? lih: rD-eenrrt, woarflsn
# de ,id  no  h  h sa
# r,titro rydAAkhM uRe  ooaUo,rhplpnFeht Iebo
# ith,pinaAg ' seh,sId daale n eo   e. vmdaw
# !w,snanU f cyrabuu htatenhe
# rcsteT  saI hArprmdosa. h
# iter 45800, loss: [82.61820671]
#
#  vibelee   eto eeO MaytsLcesvafranoelkk tfrDwnr IauE,at t  e ny'otpapfhdo-yMraed
# t nhcro vpsybcmtush cytsakta f-et:iu,drf c osutr gifn raknedyeri deu.tuatse t:u msta,csn,iShosyfalb l  otnhsoi is uIon
# iter 45900, loss: [82.39464274]
# m
# ti ir eDhTh rIstsh,h co ahom Aul h
# w tianehnaU Uln.s l
# hH'tM i Utnmctrrih a, Cefm i epvuuscei,sd tia  reOyoe lru,c BinSet  ms.are e t.inoioHai trsc Pdhfougii nv:rThwoth:dt!ni:tts
# nenSne bt
# so
# s
#  d
# iter 46000, loss: [82.51059955]
# ebRfunbne.m  IhanadsMwUtrlVgran nu e UocshIdrtioc I,i:o touiBMrrpydt: aow e vlioe sssltTrtea goeMadehnowiea  o ooss os pT boodu?dnstehoectA: iHewr h ht hie rta  ahh
#  undnW
# elrly sg UIw initnencE o n U
# iter 46100, loss: [82.60658587]
# neebonornyromaf o isUrrctnioysu oreYg
# e
# oiai
# ee o :k:-ro uc  o.l
#  ugos o sei:ointnrf wtutohihrg d egeoltomylu  see-h stoobs rryl  seuUormhoueerrt  woht mvemeonhyi,irui Y sark. asm ts foeu e
# aavT n
# d
# iter 46200, loss: [82.26949814]
# e  w M t e:.h m rYhevrnUu hOVswBenn do esr  dt niU
# tIhucH bemisnsdtdOrnc   h  i,:toiue did g t hyas waMAeois Aes;O
# u ue u .iAsytsebntepiohtrhi?heiderafieovrebe r r,m,n
# t peM ,eh eUu Lna Ra
# v ot
# aethUw
# iter 46300, loss: [82.49391255]
# smunseweAo
# noeau dn in ea aode ed :ccCtcvhlS N a  lel'n
# mCn
# as
# stmn'fTOleuOs nC -osteeeIbfa drooki haro  RartseCee ewv  eso daefa oltgareth.nd .o iem l -tsam'Hoa
# hhogm  hMnO
# sr
#  ysro
# ho e ols oesNnoy?
# iter 46400, loss: [82.64548637]
# ,
# ,sw gnseoa iladyhastashsrtUaiirlo oe's s hsrgisoeaaenUUtsiar nralC w  sn'obo pr CTom rgt
#  sona
# .tkeaherfarfdstnhBuSas
# ttn
# uooSUooyn vt.h
# i dfsls h hsdnrsdm iuhaoAbes.c:ur h r
# td pn s aphltedIarsrm
# iter 46500, loss: [82.5150865]
# id aafe eitiSt,hroea r enpvyoFuoy aeygr ntoe n miiuro  ttua,iyr  e :ta tiersvtgeog ioapeeni:hduevso
# n tlutoi    ieoftc   s rr,,t tiUr t s thng awvet rhdtbdtheepktfueahfaabO otl
# etre  hoeth  oaMreeon.e
# iter 46600, loss: [82.09596862]
#
# Nftsnaoh,hth t  eer
#
# hd
# ttnboneedoS awElT!iak  omu  oeh i fOih ,
# amSmeslsaebdevot neasHuEgseso a msooaoemk
# ntD?eder ae fgdna  , soaincnneieiptVeftsoof l tfieamynhnihl rU saabprldsd te een aimnl ci-
# iter 46700, loss: [82.08918836]
# lA e cf phonT npoei itertsr
#  atwheydoiMpahI .pfb
# kU cu uSo t ,cont' sar oatoe hhtnviiIateoseo uCeyoxnCneR e:'e tSdatSi  eUyty   nhsoopne C
# :witI oh
# houty' CIaSb
# Opft  a
# nrdwee
#  romt z  noLe ees e U
# iter 46800, loss: [82.15612671]
# , ee sd
# ygisannn    aiu hheesoA ernyhn ay ae  e ssetosnksec tociyunwoaf  rlPee tyih;dehtydmteenMvoe'ee eto   w
# fedtRumwihe e,yenwr yeidptsoogmn  r Ntiip  roolze
# Seh 'rs,rodIIante ue:o kyoa   rgieui
# ie
# iter 46900, loss: [81.92255281]
# vithn
# ap.n
# rWnN efretNhoto n,lu :  her tu niro,uoneltcn
# MirdAhoste
# Eenger t,e.T tn-me ooin  y,s Fdsus.Iosw
# ocT
# e tooece otcydS:oeofcweheoIl arhvyimeau
# iohYhdlIoblhphtruCv dgeydrton e
# e.o.lCldte
#  fn
# iter 47000, loss: [82.05533327]
# dtTrsn:lel,.trhum eUat ihfkeioiee
#  roht
# eaeiycwNariln:gd i .En N.tpTF,,
#
# hz
# wh re oNCW Czz SvS
#
# ; hi
# nyidfe .i e s
# ec?nl'ogeiu irTW
# gsapyvaoentT  y
# eo?rfi :uto-,   r :re;sor - m iyyoindteA YenBnisi
# iter 47100, loss: [82.21123015]
#  o  pths
# uegr mzryi le wlkhts
# , t.u',tfIenmien a c roToakhs ihoiCnU dfehrcdo enb?s hganihwmse Umteno Lt
# neyymeepue td seasseny oi'uuid  rZshdUfca u zeld tlit! cdtotslhgeovto bursyceidcoe Ot
#   :g
# ad
# iter 47200, loss: [82.08522554]
# ldai
# gTIiUoicufd hnoSg'Tdato rehoh eu,aeHphte  imnmvhf
# s
# ao
# hrmbr bsdw
# a  mt re entl
#  ega fontnd i  l
# B :bStitoian o
# scima atlt ,
#  r
# kier rcwo hmw
# :hNoO oRonaSesI 'l t tnlhsaeaen  ieonaeeelu ibn,poo
# iter 47300, loss: [82.06291256]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[195], line 26
#      23 # forward seq_length characters through the net and fetch gradient
#      24 xs, hf, hi, ho, hc, hs, cs, ys, ps, loss = step(inputs=inputs, targets=targets, W=W,
#      25                             vocab_size=vocab_size, hs=hs, cs=cs)
# ---> 26 grads = grad(xs=xs, hf=hf, hi=hi, ho=ho, hc=hc, hs=hs, cs=cs, ps=ps, W=W, targets=targets)
#      28 hs = hs[len(targets)-1]
#      29 cs = cs[len(targets)-1]
#
# Cell In[193], line 43, in grad(W, xs, hf, hi, ho, hc, hs, cs, ps, targets)
#      41 grads['Wi']+=np.dot(X.T, dhi)
#      42 grads['bi']+=dhi
# ---> 43 dXi = np.dot(dhi, W['Wi'].T)
#      45 grads['Wo']+=np.dot(X.T, dho)
#      46 grads['bo']+=dho
#
# KeyboardInterrupt:
