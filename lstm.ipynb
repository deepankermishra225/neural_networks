# %% [markdown]
# <center><b>IMPLEMENTING LSTM USING NUMPY</b><center>
# <hr>
# <ul>
# <li>https://agustinus.kristia.de/techblog/2016/08/12/lstm-backprop/</li>
# <li>https://www.youtube.com/watch?v=8HyCNIVRbSU&ab_channel=TheA.I.Hacker-MichaelPhi</li>

# %%
with open('./shakespeare.txt', 'r') as file:
    data = file.read()

vocab = list(set(data))
ix_to_char = {i:ch for i, ch in enumerate(vocab)}
char_to_ix = {ch:i for i, ch in enumerate(vocab)}

data_size = len(data)
vocab_size = len(vocab)

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
import numpy as np 
W = {}
W['Wf'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wi'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wo'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wc'] = np.random.randn(hidden_size + vocab_size, hidden_size)*0.01
W['Wy'] = np.random.randn(hidden_size, vocab_size)*0.01

W['bf'] = np.zeros((1,hidden_size))
W['bi'] = np.zeros((1,hidden_size))
W['bo'] = np.zeros((1,hidden_size))
W['bc'] = np.zeros((1,hidden_size))
W['by'] = np.zeros((1,vocab_size))

# %%
def encode(char, vocab_size):
    one_hot = np.zeros((1,vocab_size))
    one_hot[:,char_to_ix[char]] = 1
    return one_hot

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def forward(xs, W, hs, cs):
    X = np.column_stack((hs, xs))
    hf = sigmoid(np.dot(X, W['Wf']) + W['bf'])
    hi = sigmoid(np.dot(X, W['Wi']) + W['bi'])
    ho = sigmoid(np.dot(X, W['Wo']) + W['bo'])
    hc = sigmoid(np.dot(X, W['Wc']) + W['bc'])
    cs = hf*cs + hi*hc
    hs = ho*np.tanh(cs)
    ys = np.dot(hs, W['Wy']) + W['by']
    ps = np.exp(ys)
    ps = ps/np.sum(ps)

    return hf, hi, ho, hc, hs, cs, ys, ps

# %%
def one_step(input_char, target_char, W, vocab_size, hs, cs):
    xs = encode(char=input_char, vocab_size=vocab_size)
    hf, hi, ho, hc, hs, cs, ys, ps = forward(xs, W, hs, cs)
    loss = -np.log(ps[:,char_to_ix[target_char]])
    return xs, hf, hi, ho, hc, hs, cs, ys, ps, loss

# %%
def step(inputs, targets, W, vocab_size, hs, cs):
    loss = 0 
    xs, hf, hi, ho, hc, hs, ys, ps, cs = {}, {}, {}, {}, {}, {}, {}, {}, {}
    hs[-1] = np.zeros((1,hidden_size))
    cs[-1] = np.zeros((1,hidden_size))

    for t in range(len(inputs)):
        input_char = inputs[t]
        target_char = targets[t]
        xs[t], hf[t], hi[t], ho[t], hc[t], hs[t], cs[t], ys[t], ps[t], step_loss = one_step(input_char=input_char,
                                                                target_char=target_char,
                                                                W=W,
                                                                vocab_size=vocab_size,
                                                                hs=hs[t-1],
                                                                cs=cs[t-1])
        loss+=step_loss

    return xs, hf, hi, ho, hc, hs, cs, ys, ps, loss

# %%
def clip_grad(grads):
    for grad in grads.keys():
        grads[grad] = np.clip(grads[grad], -5, 5)
    return grads

# %%
def grad(W, xs, hf, hi, ho, hc, hs, cs, ps, targets):
    grads = {}
    for key in W.keys():
        grads[key] = np.zeros_like(W[key])
    
    dhnext = np.zeros_like(hs[0])
    dcnext = np.zeros_like(cs[0])

    for t in reversed(range(len(targets))):
        target_char = targets[t]
        dy = np.copy(ps[t])
        dy[:,char_to_ix[target_char]]-=1

        grads['Wy']+=np.dot(hs[t].T, dy)
        grads['by']+=dy

        dh = np.dot(dy, W['Wy'].T) + dhnext
        
        # Gradient wrt ho
        dho = np.tanh(cs[t])*dh
        dho = sigmoid(ho[t])*(1-sigmoid(ho[t]))*dho

        # Gradient wrt cs
        dc = ho[t]*np.tanh(cs[t])*dh + dcnext

        # Gradient wrt hf
        dhf = sigmoid(hf[t])*(1-sigmoid(hf[t]))*cs[t-1]*dc

        # Gradient wrt hi
        dhi = sigmoid(hi[t])*(1-sigmoid(hi[t]))*hc[t]*dc

        # Gradient wrt ci
        dhc = (1-np.tanh(hc[t])**2)*hi[t]*dc

        X = np.column_stack((hs[t], xs[t]))

        grads['Wf']+=np.dot(X.T, dhf)
        grads['bf']+=dhf

        grads['Wi']+=np.dot(X.T, dhi)
        grads['bi']+=dhi

        grads['Wo']+=np.dot(X.T, dho)
        grads['bo']+=dho

        grads['Wc']+=np.dot(X.T, dhc)
        grads['bc']+=dhc


    grads = clip_grad(grads)

    return grads

# %%
def sample(hs, cs, xs, n, W, vocab_size):
    xs = encode(xs, vocab_size)
    outputs = []

    for t in range(n):
        _, _, _, _, hs, cs, _, p = forward(xs, W, hs, cs)
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        outputs.append(ix_to_char[ix])
        xs = np.zeros_like(xs)
        xs[:,ix]=1

    return outputs

# %%
n,p = 0,0
mVars = {}
for key in W.keys():
  mVars[key] = np.zeros_like(W[key])

smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hs = np.zeros((1,hidden_size)) # reset RNN memory
    cs = np.zeros((1,hidden_size))
    p = 0 # go from start of data
  inputs = data[p:p+seq_length]
  targets = data[p+1:p+seq_length+1]

  # sample from the model now and then
  if n % 100 == 0:
    txt = sample(hs, cs, inputs[0], 200, W, vocab_size)
    txt = ''.join(txt)
    print(txt)

  # forward seq_length characters through the net and fetch gradient
  xs, hf, hi, ho, hc, hs, cs, ys, ps, loss = step(inputs=inputs, targets=targets, W=W, 
                              vocab_size=vocab_size, hs=hs, cs=cs)
  grads = grad(xs=xs, hf=hf, hi=hi, ho=ho, hc=hc, hs=hs, cs=cs, ps=ps, W=W, targets=targets)

  hs = hs[len(targets)-1]
  cs = cs[len(targets)-1]
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: 
    print(f'iter {n}, loss: {smooth_loss}') # print progress

  # perform parameter update with Adagrad
  for key in W.keys():
    param = W[key]
    dparam = grads[key]
    mem = mVars[key]

    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
#  a'ento
# BaC' wval
# HouCthltelnst ibirwnuprt? faos hwrsr mlrclonkutu rs s
# qltCeaee! yaxneh p;yr.rh s he , erd ghlaiw ookoenv nAoe
# bayorce  g  Eonk uenh dx Ma :s
# i apye e yis zn e p ohai?slroowh a vhic
# iter 0, loss: [104.32888462]
# banin
# Irtaze hathhalglle O  ng A?pehe :o
# Oiduthn
#
# sh Cene s inta
# sgpnisy, uarnY inssaty.
#  gha catoulelrh e Oed :o.
# Fi? , G
# Fain ? weB razafnhe
# 'iadne, d molumaretvo: 'epphe voon,  od ryo ptc tiplCiton
# iter 100, loss: [101.19416718]
# ves
# : Wilbst namanoy Nond
# lerthatl'ewhy: piO'e ,hmomutozelsld e dortsis !r  tue, bains staadly
# veYowoe uun
# Whaltifo t lgh Ie reitstt ispr thee tolte ilftres  i,t
# hiWtilnaklity?
# fo
# atfo, izevetl' ieve
# iter 200, loss: [98.21376819]
# tr'gowaun:
#  bacdl oe; caYlels thI sbs Uoe ! y zoben  tiuern;
#
# Fiur uf mube okrssh
# wot,
# thvelostr SoMeby .
# ThtrCid FiFils tablcsAn,: PoUesc
# arw tt isre Ci plnlorr , 'rmo'usaury moony utm te!
# whitrs:
# es
# iter 300, loss: [95.48867862]
# td yoNuneaf porian mod. do rsr thee e tlohutmu
#  rez,n y, opol athye Colile,rW'
# 'ts Woheyothrelits ha, FifaLes :
# ',w paFid ?
#
# meey,
#  ruwincSamuy stpiMMminde.  phifktovee se-r'sri;
# molur urd maatn bowek
# iter 400, loss: [93.03034073]
# d, Fidse buWtyhors Ciasind:
#
#
# rcy
# ArUsss so winss'
# s ktakt e FiWhing re
#  ansot,
# NIn.
# omU RaMr:
# onicnd puIa:
# all yo
# e haBein m nisas .
# thn ma:
# Wrrr ums havezethIn:
# ent usn: Ti rnsy ed ne:
# TIlIr Aar,
# o
# iter 500, loss: [90.96237813]
# faprmems hiatlall:
# WoN yyyoy'foLifounHe sthaed ofunvama.
# kid las lksd,
# SUafwin , Oe ocred piuits
#
# ast hiSot, fid lre lod sa
# ant comoent kese boeneed Cith hy:
# ins yiEkarvevetrs whoninoue g  wheAne wer
# iter 600, loss: [88.8535376]
#  r snCInte ? , , kes n se, th? prmo theo ant,af anAt toWhdizomiR?xld hetethhaenRiweNis haarl LuThsemeS ,
# FaIlh Thdeny
# hafrinw'-dasown;'
# Mils se.
# e.c
# .
# n
# yowoyoCAs em
# FigpomrdS:s,
# WorirsThehendoh ancid
# iter 700, loss: [87.44205596]
#  Tonst Ar t orgoweI e
#  ofer feboeshoLau rae atsa
# IychiAlt InAdkod kacoe 'ot afn Fathbe?
# videang Nomil ane dere.
# aMw atnduhegr
# , thusLikmfeve bne al , ciIUjeV:
# M Asthri;n badye
# ThLARoUhRd reEorr nof ls
# iter 800, loss: [85.92402426]
#
# Wh p't hin doUS; S:ths
# e de, thshfe.
# e,
#
# hin malact,
# usMeornt wool ans thitUelll in'tno
# Vow I ins.sh
# r
# A',
# waheP
# IAor hesed  thelll  oe: 'tI timith
# r
# AntiNete.
# r
# lt,
# Teghte
# tih sabe wipceinded  hli
# iter 900, loss: [84.14428395]
#
# S  twhe wihiin gto hankees we taht go;uhecrruks?
# r wilidiveprYoane  ssh
# , yothouurleve owe Thasdi asses,
# :
# LA! GlpiMed yoMesire!
#  ninasoc.
# fMou,
# bell  fe ersy afane sef thSsI .
# c:llreudy
# mi:
#
# TotofiT
# iter 1000, loss: [82.66669747]
# lim d ou sweAin ciodbe.
# en muryiso,
# Totnr  od itshy itthgrYo.
# LAsigemal  mxols ye cho;
# u onowCoAfRCofe  epr,
# O;uev
# W eayow YoNeurl:
#  Ayularidt, Ager des,
#
# YMd onTh oodghO NaFiNo;
#  wm,s  omacesjem hele
# iter 1100, loss: [81.10692702]
# ngus nyopadd hadrLlths  wwaulesev.
# ;
#
# TCIUIUur
# E
# S:
# M;
#
# AAf diyhgoMye,; Whe IUw Se! thWhtekny arr IrLiVonors
# whg, :
# peRsWhiunt  touth, Ou
#
# S:
# s caLi cOtReI
# w weert, 'sra piee fyI marnr, ? IuveI Ve?
# ou
# iter 1200, loss: [79.7187888]
# le plo aturr royopfark icreved Hokein ativied heof
# a dsmierl;t malles bry ;  ape Aswhae S:wh yod imwiCothI di iM
# t hike Mangst ha,
# uy dupout Au mh I
#
# A'k t chdan e a ths. atoruchaplmis ti brlel tahim
# iter 1300, loss: [78.4255292]
# erf me toetr:
# hiplS:veins,s TobrSenor,
# TCe dond hy inotr, ise heo n, wi, ET g'ismerere,
# Ir reh e f tlgiLiBrhoIn cha-  totiast odBt'esuovya:
# u
# S:C ann mie ofAy
# MI't' taitLrxv!
# Ha be, Ad bid whaiiss yyl
# iter 1400, loss: [77.3718389]
# , leds troethidhalcmyispdhe. vehuonwed
# idnyshielalmitgrge stohe'ip wed ofg tidr-ay wi'tLaat ten nmou.
# be
# Myes
# Yi n wrhal
# n
# MUS:o
# ThEUanotd,
# ineny Cas,erl:
# Wnor puotu toyeEn ao wee Cuov tonigCielanutt
# iter 1500, loss: [76.30155049]
# e; llry?
# he
# Whov mombe hientthatat Loca yyocaLtDaCoese I
# O thgonovayo-rar de
# ked oube
#  orboto'yoLngo:
# Nideews loNo. e
# , noon! ant tototh kveI uspprcBl
# o r ou fcoorey , indae USTeser Od-uy yo fe taRoiu
# iter 1600, loss: [75.34899567]
# e
# g E
# UuMUS:ueal:
# r atbe ,
# 'dAgun.
# e th, res on tardar atr grmeThkn
#
# MNIIErUorofno alseer:
# Bhders hetoMirs !nCud  tacl un toflohed wiaverus asw mall:
# n:
# ' thadrlutNIn Cooucr oshe pha A
# yoOe acMo tod u
# iter 1700, loss: [74.44253296]
# nh y'prColdtuveAt ig ithilds dak the unan :
# Oe
# CIUSENINIUFIENIUM:
# esh ryt
# hidishavirrsagd , np! gern wyon  mcewlti tthto
#
# hI AfNIURIOLA
# LMNN:EEAaln ,
# ncse mros Ip r hyonurdve plwoCowad knthteNos ancow
# iter 1800, loss: [73.7049034]
#  le ipl,
#  b gh::
#
# W
# RILNERRINIUS:
# .
# Aft idonams Vh!
# rshacyre mh me a zeerld that meir  yotitl ke.
# N
#  Mt:NTUS:to?
#  Coysed omus aid,e
#  MIUS:
# ouesd iom
# toI andito
# Thood momy ror d,at mas th.
# e Woi pot'tr
# iter 1900, loss: [72.79494636]
#  thgo aveissood sthes:
# ur, Erd Is hb ven Recrprerdye haams yo tvilehont
# CTOknr an; llNod
# inwed ea hamingid,
# usp ,
# vereveRo wre einst, ktTh mars ank ye frl wNaoursO
# I Op herttee, Apvert ast heeriint en
# iter 2000, loss: [71.94017324]
#  thallmle caol that ans  sthame nde strot Caomr:
# Rsth
# Me a'st togmiirsp ansts?s thot ip, Th! tue towhleat.
# An.
# f icblfas' cney yifowoanng nap thimtoy lltoduLe anf  thibly tr: ngrdd wiipzeAr t?b'dclror
# iter 2100, loss: [71.36603125]
# y he ho ann,
# ter towe hea  youthiad, s shularive.
#
# T, heth: More scwodd
# INUSaUS:
# h
# lleeesc! owtpse nouod bor herd reha.
# I Nakak atry an; towoRpIdr of, Ma ps lohas ro?
# whhitecaIlUel cavet,t Me:
# RuAnl
# iter 2200, loss: [70.56379963]
#  momiss onycd, pntes mozee s istot let.-
# Aer esart anb puca sitdy !rcoanr mienru d hissAntese owintiowcuanst tiar dd geear Rhe irtha, now, abrunth ebhem .
# k  ome slomuk hormed e hosd wiec tharlg hors
# iter 2300, loss: [69.99663607]
# dongort eat
# ofy engos therper olzemaonr: lill tibemaengi', rano u the at ol's,
# unver orBet
# anarsh.
#
# COTUr:s
# rer ha, buken: n've-ss
# anwe thiodtiy-erdiho rof f wapot zande be;
# Coat pou firtsiplotu wegou
# iter 2400, loss: [69.32247081]
# pRo'tse lakevetd lneve thveviSoginghacall-sni carzcmer nof n het ifmer.
# :
# Rowur gilictlvt!
#
# FOo hah  cat s'gren: e afs ou, ann se traacnghy ns; th yed,
# Whe s;
#
# SCoAICu;
# Ttiat
# thamt Motey IAu
# incicew.e
# iter 2500, loss: [68.7956453]
# swaille tiglo ghseevS:
# e py ne thlellue ssocth-e ya yis'titfees:
# CIatom h ithes fe fon he  yountwe ve
# n
# thCiNi!
# werd
#
# OSRIUS:
# LTLUS:er gowdevetegt hiss hay igsaNo:
#
# Ahe nro hi
# Thang deel rheinave
#
# AS:
# iter 2600, loss: [68.24160113]
# oury espr-tFizean,
# HTIUSIONIAn IUL
# Mamt sut be strat.
# u meq nd nhe f asze bme iccoem pof
# OAly t Motrmrs
# Hhey Aitno podveme.
#
# Tuofnd
# ser to ymet rant usco we hyecd thFa hTaud,
# Heheitrsidp tovali ho su
# iter 2700, loss: [67.69421566]
# .
# nab, sow whem?
# .
# CONIibecllI O bk tore ud ceisf wathelceAt 'tecthke ghh y essom..
# Yogi, Ca'dy CoultlWiveord He nfewens.
#  thIAN bard I t Volts whS:w
# Younn iuted,
# e, coy yo
# OiLpe tls Ma limto fhe thit
# iter 2800, loss: [67.07526523]
# sveutg.g, en umibdst frecbre los loithe;,
#
#
# SOTUS:eint?
# ThUS:
# y onArr: yor he- in bank an teesne naiis aserencell thevt eef it whaesd shso wircl:
#  achtlentp
# haOt,
# COCoralcte
# Bnadgr none ghy tuse,'f  h
# iter 2900, loss: [66.66017965]
# ry onhe y. brru s arcen e biey-hall tIhe th inis wur vsipthcobl:
# Mathate.w arh tpatwe miracr cuss uned rad. thue fhem y, noofu byach , wiit hse,,rp
# Whesn ant
# bes atly: To ische'mt Mare sudo
# Thea!d,
# Se
# iter 3000, loss: [66.26405725]
# o ts, ag: At c.
# hherer h icnd.
# r
#
# MS:
# WeL atl, ral
# S:
# wom S:
# SeNail khilve nsuogikgs loe b, noesva yo.
# ouu woll ite itd elm MaIA I ty'icyetrint hielle ppen sovocute USe: nge gomag
# .
#
# SIUS:
# USMEENIUS:
#
# iter 3100, loss: [65.99192923]
# l
# d lis
#  talnte laricevy the d, acwe dles ard,
#
# th:
# veben:
#
# SEu ltb, hatrm
#
# SNIUINI:
# MEENRIUSIUS:a alite rouds thTritfrwee INOLLvLUCigratpiveMitor Lru haarn:
# OLRICIitdt a thhinst bley
# onbroug-y orsath
# iter 3200, loss: [65.58856093]
# r wto bnors
# -pORCIIUS:IrTh isde?
# Whet-r
# Ansro
# thaimed IUYek:r
#  Mirft.
# Wo tchesr.
# Thort not peo s,h siCoatil:
# Robe siumat poralvo:
# ins whkme;
# RuTfareslf acfielt dod do thare.
# The n:
# Biez.
#
# SE:Ie be,
# f
# iter 3300, loss: [65.32411064]
# d n obte the.
#
# Cioutids ha'tt an, USn? ot heen tooy whel
# LAAnths unRo vee otpoopat, leit bey  bres sooshi?
# , s liths,
# Oluyes gcof tow h ele itf Ciamou hteat aye at pos ofe yo omarbl thien thee mam  me
# iter 3400, loss: [64.89369719]
# I IpwLLAr wth thteu isFi tchgils che bthagowid! po stlTharrehy haono y.
# Whevt
#  adve, buRohr
# O'd ket the.
# MEhUCIyUse
# atr, enlabe
#  balless moa feadse- couy,
#
# MORUS:
#
# Tou ro the pagor .
# Matrcehe be e'h?
# iter 3500, loss: [64.60256101]
# COurllea rtot brintho lige
#  alt tore
# Yoberevece eent
# urep
# COstO
# LAwiat thepn yo USr:
# ot oktecrofl Whirusis fas him smer ol, Yovyt.imecan wouf
# Thsom .
# Ha.
# ;
# Lemark disisout shabs eay chacveiswo sadhio'
# iter 3600, loss: [64.46717929]
# NUS:
#  IRUOLMecidld teast nge bslef CUthict In thed
#
# MROUS:
# Thaw a
#  hee makken:
# er,
# agNo
# at huds,
#
# CIilifkee?
# That,
# e, leais balotg! ay hai;aurr tht?rind bonds:
#  her waloline towincIhem shuc sinarize y
# iter 3700, loss: [64.23814095]
# ;
# Te badits,
# b yo ks aal an,
#  I anckalte,;
# !
#  arue, siThous, mye oouk u dalf
# He nake,'
# not anl;ur
# Coy wes ice ous,
#
# S:
# Re. Htgi wenher lled in the wakm.
# I
# YIHiHe, esrered o atll
# AEN
# LNr:?
#  isr siifinn
# iter 3800, loss: [63.90502203]
#  the be thou de!
# Co bo arrs'td eas maimat degobf hi huttied heapcese ilhe Mlepm  sake se iunche inus weresp pomadr our for ice uet nodun nocecomee soou he othes,
#
# Cialemtou thatesth mee
# Whars goad sof
# iter 3900, loss: [63.84729789]
# blo us:
# Migrle yfe sheeto
# BeUSGehan'ce
#
# MORUILNNIans ndler, ped,
# Y ul hut.
# wapee  breonorn bu te thesinlealde toud wooriithim,
# Iaf kef
#  tth. h cu; :
# ANoradonigitonThe Conggo nul?
# Haen kwe y nee niose
# iter 4000, loss: [63.59994633]
# esss
#
# MLUp:r
# Me' topuag ofson ban an-, US:
#  imat ilin sware e. imS:
# anivkem
# theN ycuW,Th cadee zes mowclat yo tawisu-ld hicesnot ande
# e digd yase a at fakn: he, wa prnnde, dols
# Fowe,  fey, lareatle ka
# iter 4100, loss: [63.41846194]
# yalit, Fid Eresllusverer, anne therray ined are reer tou?
# Ve a fagtl ne dlold Pratlas ofze ymals hicvotritenst tsalle sowd moclccesh:
# Thee!s arstanile Jott zecoswhaasy,, of wof tsou  dhea; rilind fend
# iter 4200, loss: [63.35502061]
# Romul ittos?
# Co hamlshek agee
# I con ars Wae e chatesrind.
#
# SRou tr haty onouavd oft?mlme.
# I thomHeowp ouly:
#  yor an the! ntoou de unt or. rtent wo'ss.
# Touu lvey deh ye
#
# Choof whord, thim, kency?n:
# Le
# iter 4300, loss: [63.12342954]
# ht weghes:
#
# Chonpak, fof to pe thie
# Whus pbe ift oreo
# Torpe f tr
# OIAnd pnowNIomf nomy
#
# COMUMINUS:
# Me ow
# Yiare, newa hes on ' hanlg u hku inoune t urrer,.
#
# Corya kr mom urite cod ul on otuppl yo! foo
# iter 4400, loss: [63.08914207]
#  litrovatpet hy bt
#  tbe.
# Whe ac,
# mecnnginep we? beol!
# CIntwhd USorLt.
# Thlyd, .
# Thgie
# AVcENasmlto-ny erton-ul iin ifinwe dere hivin ang ham hah eml satee le,
#
#
# COou t mathaf vie I the Yoncen fit veo '
# iter 4500, loss: [63.14038883]
# hontom intiveMoUS sRollrt kk: Myey fogr dint grars
# Yey  gner no att animpecmarn than fotrtrs thiruestnelg thsivingmr ling thar; owge
# Wiy, eree ouin shive arken,d nuesthrv
# bers bE fl obefeind bet,
# Whar
# iter 4600, loss: [63.10811313]
#  e an hNams Thdr tn:
#
# ARINININIIUWnit spre He isd', icusans eahe the,r wotoly afst thacvethTod alen sou'gs mared,?
#
# MIUrLENIINOLUS:
# Yod tee.u
# YiIale d, to fofd sidfeyg agusanpeS:
# Thet
# Bngoot denosdst
# iter 4700, loss: [62.97112635]
# f
# COUS:
# OrS:se wees:
#  Ihits, itt dize,
# Whnypeintog, atd noo got theveelse Sere wnoof a', irbe inrad  seen utlit houdl iunort tho ne-a gharng trers
# USred udd,
# A paNowOs ou rin crinlen:
#
# Inelre hrt habr
# iter 4800, loss: [62.83153321]
#  yo tizs coipkeus to An tsole vo helramliak haNUIe tinti-y? bed,
#
# COUSLILUIUNE:
# hiS:e xiliThat hat donryd .
# owj so y hebs he tsitlr ,
# COUS:
# Yos , hat orpl:
# net miarmes
# d
# CiWhe USOfTis spte mdnt Lee'u
# iter 4900, loss: [62.81021326]
# er tcare ag hth tfou, retlan
# MIONIUUSananred anh op
# FIro d mo rinnsot touy eos cilvaciih shayo x.anvo yu tr mI anocFrENbeifsaard ?i ckns he gll: joMath b a?
# Coin ay on sco, nks alt ga tmanfs; mare NIE
# iter 5000, loss: [62.78043085]
# hol hsro xapamyt of teer
# Coodh tss be utithisveENedu  matre iwho ticliill th marbl ay ee he ateren maridh ow:
# ann'athe y inav lrm:
# Momare nowresspsred
# I une, tositortho th be mah,l lofluy platu tiTiGo
# iter 5100, loss: [62.66716482]
# et louvefm de wer was tou cne ther yatyou itiniflle alt ale ou he asacd
# S:O lrot hees nesu thy o, the m. arinjo wfiisf.tr etrot orne
# e otb'e coMs:
# re chulluv .
# urto
# IAem
#
# AMENINI:
# Whony Yoe I IUnandas
# iter 5200, loss: [62.55451121]
# ,
# yo't t, tod;e thove inre cand ig ant at than omy ke fha st.
# Iloul,e atshe avery kar e ceastrUSn-he-ee,
# no frearl ;. ar his teanerslard lethe, haerer wes eolt eout ar
# alrd trallda collmparit- ou
# Culy
# iter 5300, loss: [62.53942976]
# s anme ane, thelal pUous
#  fary-bem ery.
#
# Thit s, an 'To
# IUS:
# COMNenits ThTe winforarsatd osr ste
# Whie
# SICOu ;
# MEVrdicoirGsnto S:ngan enithavn inmaLrd isCoNoatit ipruth, s ey yo, sminsenf,  hy, balud y
# iter 5400, loss: [62.57926896]
# ele, mayou rd thy.
# O pu:
# , the saun pusr en mstrt.
#
# MIUArnd wy rort brur l;u jishend oublse ymo chter inanim fyon'sthe cbusngat fe gmxe hear
# r dro itfuhy ieno anil ule sold theitwndenac htsh ry y anea
# iter 5500, loss: [62.75844362]
#  uu s! anze!
# Anaytunovts:
# Coit
# A:
# FINIUS:
# Ann  mot, ! unh h ot st themin bakh asow nimouas'cin o he yond.
# he dome  as, nom plinerrtof ow bag
# OLme b IUSonf one MaThe ra, ust urNoatngs
# Fothrth anosanhr
# iter 5600, loss: [62.79147136]
# m potacas, ronked thenad e'sld Ierer ghothu, neofwe ao engssew, phal ntu sabotth ordod er, owut whissr
# ENIUVOFo pUSsterd'owerd yo
# Fe dge ncoo bn caler ons bof. ben poRow hoNmIOn mys,
# I IUNUNEacLUheFo
# iter 5700, loss: [62.79238619]
# t o, tor corhak tonole hi is he thadn:r,; sthir benvit en ahled og nin himouanmoe pou ouncmy ris ar arce nin,
# blopcoevle btre,ilu enovee coytere f sorstamlo d; akwela. inur be -om lerntalee d'ou hilas
# iter 5800, loss: [62.84924942]
# usleth
#
# VORINIOAS:
# yo:
#
#
# MENIUS:
# S:se:
# Bld see orute,r'res.-e nooralld, pas; ers,
#
#
# S:
# Hel' wpire kac notst orl i'id
# SRIel yomes oud;
# , Thilour, tovesipre cance Aa th ot.
# fao lad uldeu? wher-es tean h
# iter 5900, loss: [62.80595094]
# w
# Dh:
# hihe rt, aves powls '; aye ee mar ondrs whe! ag yo ne wol theaveal, ThAr hI wted f toe kiles thimaton, and so ar be gsase te, to oy serrs,
# Thirnot I IUel tonrtl Wars are y cEher urta.
# e ned e bo
# iter 6000, loss: [62.85886043]
# ire meane oa tod suspt diono, on dodr thme livo whaye asveprENgrthat-ls
# inarh Direatd anne
#
# AENIURIURMIUFMININIUS:
#  then le ar
# athirs yhirnd hec-rset coro eapbr
# As y weanlid dot uon'y onlisu
#
# Mo:r
# oun
# iter 6100, loss: [62.79350145]
# r e RUere d enra-yu ood are him:
#  wRrUS:
# wiheit hwie ho ond,
#  afe s!nort yoo thiscengs
# Withaielf HeidRo zer, esan k thim wunt He ob: ul at
# :
# itb miPlurDoe ntntbiks meante pa unt, Mle gou  hels Stlcuso
# iter 6200, loss: [63.09262732]
#  wwaea h, dehe tof wit ore bles w ands!
# Whep,
# thUkacuserAn shicbulp y, ou  ho yo.
# on; Toolerd'yoyoaf fal ot on thitt vind athou gs pot hi
# ADME:
# BRnerereu nay an heiatou s'd; wale reoristen
#
# Airp onde
# iter 6300, loss: [63.46676872]
# iTo he hatme ot yo ofg kxnt tond xoan touu pie, do no  or ay thaser ye maiali I ark,
# Yod no
# MEMEENfof 'doukiTothAl wayull CiThe teAtr Halle tooninves  C tser
# MECILAend any, erst: nol.
# Sef ool mord ed
# iter 6400, loss: [63.89139846]
# hunagma, rhS:,
# orRTirne
# ARE:
# Whate
# BCOCIOLl'Gdes .
# Heis meve bus yot pengbeodrsd thatwe,
# Bublrt he,
#
# MEn 'Shex
# Perswaes tol  yo foourf daeithacd kiecly cren torvoFoure  pTiul
# Sye anl isI haenp aranm,
# iter 6500, loss: [64.09415211]
# ud ian, at In Vo'odd thiygoL
# Vo:
# Me wan Caiise vihty evs,
#  oud whel ains!r
# SIAnrd! oulo pukp inofan ar!;
# Ther sangs fte th lear reery onen toren yssiWulet foun her tos,
#
# Fod cef mis alm euis! I pende
# iter 6600, loss: [64.37598518]
# e Hod adarg eoto bEldr th tter hy d
# WWep-'d tr gouly sthe iobade.
# Herd bc:
# W MECCGOS:
# hiinTojlDeam.
# Ob ldrzeTo
# AFoLAant mo-d?
# OLAlYomere,  he melmt omAsthfaBuwicadmHeerusrts! s
# FENEOLAAncTh Ce e
# CIUf
# iter 6700, loss: [64.60706565]
# o itnaermage a f af whaise.
#
# GLAd loat
# SlOet thoundt MaTh, coul thaomnt llav'y ch, wi bbut whavt:
# Gigy xlfot Go'dn ergr'dusomwie tierheNou  art hongs',
# LAer.
# Alu wiy Vo tVicountren
# SR:
# ernd mous tred
# iter 6800, loss: [64.52805515]
# eawi
# LA:
# Fo tthimha
# SLAIAAfl owRokes
# 'TRus arbed Ro.
# T MEMES:A
# Y UF:
# heat y wannd ered!
# Tibet haw buy enevige, peibd mentt yo
#
# GLACOcCRE:
# LAplemI mapt tNEMEOCS:
# The rep WhinTrseusG foacToIf hat tCoA A
# iter 6900, loss: [64.46118966]
# thukntn TEtroro d eah  whe
# GBer cmee odu wi-o.
# Yostn.e-r.
# Woknceild Vo ainidd,
# Y omI HeesonspryTadomeatle ave
# F, EkFom'lm wele'at.
# eals.
# Thip owe me:
#
#  ANENS:
# BTeat jul, sus zechmeinYod eo wenchitiat
# iter 7000, loss: [64.96091125]
# ouldereceage-xeten.
#
# COUTDES:n I Buat ho .
# PrS:el thawntrh.
# Hos vein:
# ouy nod okF Gytrs ofbl mMEftyorcAdA mat het eayo litt xnt esGorouycsolret ins inllMytohu?  IOomsipilbe
# BMEESS:
# GEVEA: s lovgert no
# iter 7100, loss: [65.48254182]
# g onme she y hisnefyilr:
#
# BTRoran.
# ERy Gm:
#  f'kweio.
# lloms toYypEodWhrearh xypo.
# Whe grcel  C Iy ras ereaonlet
# CEI STrean ald myive Tiranicas thou  orieows an narh MacindisThd ans hy t ru thuf ir HeYo
# iter 7200, loss: [65.67974542]
# kebutorulde thy ookiorout ungxn anuvgt iAran gou lclimgeict vien bo b llurea porAd
# AESGT:
# The t Weh NEoaliWopethtilafcurngs.
#
# H shaiteDlvahtceeanoest Elloy ortoTa'dti ves peat hoso t ob-u ae sheor sou
# iter 7300, loss: [65.84370811]
# it? I  hisI kebeafirbsalert ake lo mouloBd!
# RT nospe. strepae,
#
# Hedt titrseoon futhteNsI  thar dor ThLaufanuso
# A dENBCE:
# VA cMEsUSTR:Aupdl
# s hatl, are YoI :
# Lis,t an
# GThe heenzebuhang.
# Wher krdican s
# iter 7400, loss: [65.92040903]
# haouen,
# ETRA'doromy ir Cb' toipro And Rofu etod, hibMy rNEaSAnadwag!kssoun kormad or n ain ,
# O'Hew ; Goutthiby! yr:
# Thatpy let'dd jonomele thord amd WhswpoveelcoI !
# ghhad xturdoleca hem It holal eglgy
# iter 7500, loss: [65.96878197]
# RUE:
# ThatgeA hed Doatme.
# W inrs ono bt bomatrsishiprol eayade heerrsimerNol Py, Pecae
# trprCior vdstem.
# ThisthBuWer'thOfk'enYe, pontn,a lid asS:
# GGARlo ylou mel ak d wobSe thean esh, ua y in yorl, lo m
# iter 7600, loss: [65.81747498]
# 'dmye t WhouThfybued munurdo fan natont Thatv!maPe.
# med
# At bal
# Mou is bew
# guamu antao nsacd , hehat Ane An xisonby
# SAUC noo! fhemncRued mtrtethinhem ai heoda ee gobin thar dme nd tbeass.
#
# FGORhcI  Aar
# iter 7700, loss: [65.87743649]
# Tu;r on no no ofded,p
# Bumme anh cer:re aini If lotses the s,- pis ofs woolpi bnoer itisto.
# RUIN, th fer
# FMIANG prS:amofd biirndamen fleie to meeao d va CARR:?
# ER:
# The , nozed voinrtllBttondinhactLAI t
# iter 7800, loss: [65.92170469]
# ' :
# Bu eLacucerun wiwig Ann cer reanTor ans als rikwgenbd inrpe ortogoust inllvestofulllceThiclle thy,ue hise tres o ne dos hus beue stulee's thy afmint,
# Medstimeki wa tod tinm pute huinenaslltow urle
# iter 7900, loss: [65.83122336]
# UUFser its
# menour nd Su'n'd bhar oun byavnct
# witoerntnopucen dyvergYo tNourllfor Ot omt inhylo'd Ademiupouet ry then uead d: pllos:
# uTadRiTh.
# ef therg nau,
#
# An sod seru we oun, afs gomeile 'rasfeerrat
# iter 8000, loss: [65.5092507]
# iiane toefb? s;ee worreitd to
# Het tirit, e agh vithadvi ced stain neiore arbe ggolg;Y coum irokg-wetes cave blais thid y fit f yeerenesr
# Thenst orent wht co
# Bre t,m thrivet .
# heo  ame fo I bu
# o ne bes
# iter 8100, loss: [65.08459854]
#  denachen wionil; doed lte fod arrsares
# thab: himtr,
#
# LAHestr:unupbld;ncareten
# ARANRIarpeenth bMlwathngerMa npaarseink Tod Ankestuns,enith, :
#
# Aor fary, inh rin
# re titrer cot' kontpe re y enice urowe
# iter 8200, loss: [65.2544811]
#  aw thivese;
# h,-
# Blam mdifief pstl, ndele ndatlol thoueafyred ergsinonH,ar s, ghlfs meprn t  cAAe .
# I acWifry enr pot,t hiBw?
# MaGlonstthBuYogfTi mMAarer ifo thatilMR ymel:
#
# Torg
# VeDaxtd Iff sondront e
# iter 8300, loss: [65.28318967]
# hutaredAg
# F, CEncBrs ecthpr;
# Asuein, indoy doend ryotu e  ouy deveg ofthert ury
# or mFisptoneMlthBut NIPre hewrHab;tod quu r semerousAnd: mit ute ghe mat itdechT'okthtondner llI CEmousiv'nMabuwet terrt
# iter 8400, loss: [65.48082178]
#  otif nus scrisneTod amiserakofet yo,u
# Y hiSal macs,
# BnAs s hate l'eaO Dol de?
# wa: anofge'dgoouide, , Iw bw the Me mim be, thedp asry hacy anYos, bent tho  at  irma Rorp en:
# Rral cenpef ha tou releucl
# iter 8500, loss: [65.69616009]
# d ond Puthwee al ag in iszid fol kr'dcaG stthcuq acaly.s pourst.
# Yeesl, at:
# nis toye mes ID
#
# REIuldeu rie
#
#
# SOMNne hswhane gncyong himOe!
# oc rMAprThs um hEee hat non orthusthnt:
# WhisJod REBrewI  A at
# iter 8600, loss: [65.80055623]
# deerw arthrdaranviwang uerg flde bNilim me noo  tilneamulpyrsn,orsiI ath:
# Saritd ,
# YuchToouorint qu pSe t them'dranturovMl- erarnywioue eiayh of elotr, lirewitheup dst:
# Yed ppThyo mWein-ue wo tinshtat
# iter 8700, loss: [65.7659861]
# but eafwam-od vymmerns.
# Ye fvest wcEM ANGSlopr wate tixl
# Barthswinsi
# Wndw zeat
# MLAPr:
# t oueakns,
#
# I ESaitoT, this
# Torage Ye, t e, RIt tho puchsiNopt tanhy thonl esiswabetogon:
#
#
# Sen Md ak of Aa o behe
# iter 8800, loss: [65.74130478]
#  vojuatwid wyalofgein'd pder
# HERELHCyObHRcE:
# COID
# DAe elmletr,
# O, ERS:t
# Fe th ms:
# e sotrea, stalotof ourever
# Thom Mrind mtoll,
# Whismencagomers guneehs y seldot wiS mkemers aje, umsathtoe, CwCIanFitod
# iter 8900, loss: [66.25671588]
# hVo achacths.ew anckber avp  batKt hver Maly weu, hEinh  wo repyZlusR:
# SHent makre af hilon!
# RIW ats, uw is wou s sou, dilmisunhaa Hes, yobanif'd bRIitdek .
# Tillby
# AScomccouredWeal any tod borvEla th,
# iter 9000, loss: [66.14936544]
# eThonstolons, lAsinof lGau ge t-OMat herl toul leand
# MILAd s heth RYEEDLAucvimuzsoupan thage old th
# NIUomd, myol, omons my o mows fyouusay youth!
# Teat, I the pl c
# SHL:
# White pscoh,
#
# IAndld ou ad pisik
# iter 9100, loss: [66.08229762]
# te 'ln fiilallomy;.
# IUdd an a nendoc
# IULimnoere gotonds, ncoR fark zestult ERhenngy tatre tur ard anl , e f ztprheonbeenngoramLAheh state myTothBue Lon,;
#
# MREESRRSSRRLtpOe fy tomwaO:
# MEMUCR:MSendqe re
# iter 9200, loss: [65.77760225]
# llisRi igen.
#
#
# UCHEMS:
# H in ir VoGos neeandy,
# Iair chisr fagao thblGoom IUCBURMeSnot o  so hat misizndley ofswityoyokm wegwiwid oou owas sonrcat ngou dein, zeve d'd
# BRIOUBRIMY: het omrsp ; d De rofity
# iter 9300, loss: [65.62333916]
# emyere iothe nghtngSiinns
# A:
#  han aanioso dorsen litoul winor told s bradveYoglHeatr  fven  yo A:
# WOUCES:
# :
# CIwoe ord UCINARane  a Co''ud thy asis.
# STmed nod;
# ennd cofs.
#
# G, OEUCESSTIS Gou the, kor mo
# iter 9400, loss: [65.43296011]
# ssw wimisAslyermu hy ina ThI otinUathtit vem itou
# CTE:
# Therl  AWhvES:
# Py dot ut io war,
# S:
#
# Thirsty'ht'dar Che ould peme of
#
# HHe grea ne cohe nordut,
# Whme:
# Y sot thy hiz
# Iu  thatalg esmamy hin
# BAHRENR
# iter 9500, loss: [65.14135679]
#  Ean as sorea  theagt tus ot prambl you rt are, sout berd pamy urFiolDactugFi astad id.
# MathSend .
# SeENGoIw'rim sesG:n ho whe .
#
# BARNGS:GBOOOANYou sh.
# haYo oreng-t INYoul tiiue gour:
# Whimchwaicso cou;
# iter 9600, loss: [65.15421934]
# e thesave an thumest Afn do, enmue e! itrll I?
#
# IDDBnawd ourder
# ind hornd thly udr, pass ansilein k viics cry fast bisAkblt lutf
#
# S:
# Ie t ort or lHlenk. I'dhet s!
#  tthapedest?
# GAd th hASWate my s
# Bwha
# iter 9700, loss: [64.96951138]
# oryelcjomwin me sectken?ad Iy deisVotersotpu! Osthatdibrinuc b:
# Ord avinanco;
# y siYousp,,
# Be men.
# Ge'dd atitrofg fule dot yren, sa'dBuhad th, ro tllblSTmat tr stheat ERNGM:Sp:
# Thlyp arTo mgos erore En
# iter 9800, loss: [64.81507708]
# d AstaknWh,
# Theid sariy mat yo tourens maseser, iiet ma, oud'slen fpabk, WIU ot ale  inen moUevency,ed lveplr thdee the eind yilfqwil. bSean a thamo , mi br oraie intime,
# UC, e haMlewe, gond ureave: D
# iter 9900, loss: [64.575759]
#  fire cheinke roodwn, cethwaWet wipovepihenser theed ws your in ofur ut ch oil ser,
# Anvesen wowath nd,ac dane thel, den  am GwEN ANG:
# e llO , may otdearifatosDes I thit.
# COzes re
# THOHASTvet brllit nI,
# iter 10000, loss: [64.38456231]
# itki ostI ary'fhanondef Inthev loM;l an houst hite dis Anne un, ceMos rcacin ne hil by bye myimh  cSTrxtr tBuonTootnt ds; yourst ire gek
# thody Yowy frlr:
# y
# The Buzs, isetlow tiyeucnemoYoer he the n'of
# iter 10100, loss: [64.23782817]
# thacgoMyw gr t'dasLo s wig, coeve orngsiupt nosu is yjue no mam:
# aygseem.
# haO u s vawen itn,ndLeS:An fang ond mas ort,
# Ar gar:
# H lty  hAr Rort,h e.
# Olokunng bude Tow ysaytaeour yooud ind;
# IC aallo
# Yol
# iter 10200, loss: [64.13368393]
# nh ic s hourd wofmistup ior woh waw, e he
# Thitusma atille lovie hin mun.
# Ho th, th owge kne ositcciee S:
# IUSTIMIrOfe V: edhs tt wor!
#
# : hoextlf ce ae do?
# Fob'y be:
# to ler rAnd tigt Ithed e buens,
# Penl
# iter 10300, loss: [64.05455725]
# wgAnr heveHafae lyange Cligfine, kimer  heury catsarikd bawvle vild afceve tareafelsmurew ousowslyl prlet le
# MArSTeny wihals:
# Youlat-dw merisl.
# MlESyerdu, Rmourd, im fry If aanf sirdo m;
# G, Hivice u,p
# iter 10400, loss: [63.84661899]
# ERUCINecerk,r
# OONearlrert leR:
#
# GRKYEAINDENAsEES:
# Whee genctheeagl ly mourd dinllILhd dl ery.
# o ndist?r remaa ne m algy,
# LAFresOrryscen gaphet eminclnd; paure kis ro?
# He hgEse rr.
#
# Thitl llI il ilel t
# iter 10500, loss: [63.92831144]
#
# I halces, nofo bre Garer wamongrs.
# Heu Cael, poh g d CoI hDpuvel,y enatt:
# SMsy morel,
#
# H indetor dender ae bole
# Ye s leniant ElUCESNE:
# G
#  MS:
#
# ALOhe ty wh amng!
# he to thes fisal d NosmI or u  de oud
# iter 10600, loss: [64.07416796]
# r;l mito thy o  ar y AES:
# Rlamh n-Tintarh  amilpnSet,: huere up cebu ao theec, tored youna we. .
# WharBuitim itakn wiroddage nod,
# ThicOfWeisdiurnoldC
#
# HLOhedt thayo py t arirore iuu d'
# MADd so n bny pa
# iter 10700, loss: [64.2367016]
# sAnmain RDeYerte led Ip zTEMS:
# ApIDngt brERs.benssaid, myirry tamalDor wis vato foat;!
# I wath RGI:
# Thasoreanork.
# The fu wI llgrf an mrewlakblby hren nond yore, I IG I I it Imafd if
# Ararh Dsowt EiIn:
#
# iter 10800, loss: [64.17349687]
# ?
# igo Fids thucenspatleplo theret wibent tond.
# Wikh, doul,
# NoUlBd cnI tERADB:
# CKadromwatNaetor.
# S:
# Wou gh shyd eaam and lo?
# htCHHADI iswa ota Br azfthy swlioftaard ?' fou n asin eab be ofwisitwler at,
# iter 10900, loss: [64.23140901]
# owlgfitheg er satle
# B:
# elSllle thst.
# G Ii, olutkickesismye Nathe orof thiogrin.
# LIad gI biu t brAvM HAy s
# elld ar thitl hamfus cclRUCitf hiRREL inj, lyen rorord nI Ranwh a s EGNGSHARTI ir
# A:
# d INprUCO
# iter 11000, loss: [64.56147752]
# nshigon hy gi bolel':
#
# Watigreaseny?w
# oyr, eadr ay Isasantr thul
# Whey thice onsuunt
#  yhenard doar es hexecel, Igalpiwis,
# Tacth Ravond armeriodane ha ghe go:
#  har,'My be dela swilly ewbouancuep  clim.
#
# iter 11100, loss: [64.55331507]
# or ord tot yo inusthTu o not youe wnges?
#
# DkesU.
# Whnitherel toBue 'gt,inmye  y lto of wourl.
#
# Thhi no sewry byath ic;
# Wes ENE:
# Gousare tiah plisve EGans'tol to rno ow bed,
# As herss afren wilofnseceyom
# iter 11200, loss: [64.39885555]
# ofe lwis brit ndUnch
# YS:
# I hy ho, loule, hortne leinbe y oncethers moricofe  ior an imt YoCccER
# STEHHED cM:
# Fnourl adix wilS w,?
# Thedbeckee dso, liw'eet sours tmou ve glest'c fee thag wamy,e noogal t
# iter 11300, loss: [64.35318808]
# tastenla  torpeeid yo
# Whe, ifd blo adcot! supandun, thatlory bl-rercshy akt tont dpylud nou  y'uch.
# Thou pWeurcl that CIY:
# ASI  iGnf berdinNE: HAM tisten Fomp mase noCgdistun ou I shav sery 'mE:Wiy,!
#
# iter 11400, loss: [64.23854498]
# , hod meay yourostetalserf at'say my eof on maveCHisth n why RIryot mogul myowmeanchars: neinmorscegeY?oul RI hadd haske  whar no  kend, the orHe,
# To to thelk, sornst;
#
# A iWholeThtendrsty sttat.
# Wo lo
# iter 11500, loss: [63.92093144]
# TAERLE:
#
# AE:n, serume thonand the anWh mI Ge cyu ul b a  horssst we hat RI:
# AMgrac
# A, prdes thsat weRll toue:
#
# p hivd gh batrlllveraou cogeidt.
# Tau goidncVos meounfmpurs my adlou rar ar wor; gly th sa
# iter 11600, loss: [63.75159358]
# in the molondw na-dl torpl ret gornd inTaofco res,
#
# ERKI: gor isETe an.
# or onn'rtabla ?
# UC:
#
# Tac EBrHA m ATERKEKS:
#
#
# rUQs Yovosue onas fey  notgord;
# TrAR:
# RIIm dorgon men,ess,
# I hoe h otes theunt lipe
# iter 11700, loss: [63.43373561]
# NEENBEIS:
# ai  nilk'Telmer'f litpeley ai s If dol NGIand coue deeerss ofy bat des
# Tim SeT:
#
# ThaI Iidss
#  hitmetherouFivl wofd,.
#
# TisbeerCHmeld thimareran farcorrll
# DLe ggicng
# TBESTEKD:
# LI touasy ndes th
# iter 11800, loss: [63.37335029]
#  upth the amWa
# Frsylosd' hat CiA nuced
# th pendl;
# edNren ye divy us d enentcethislemi-tcELIUEM:
# ESdod Your ath IIIIId y youlsenes,
# INog.
# Provat!  sks cyat sedsIwlo hee; gast,
#  ninm, kn: melats yout ith
# iter 11900, loss: [63.28647636]
# the eiwou y my ip theaMAt Anldj
#  facas inguefd toon gorend ardl  theyo las.
# Why wiy teter noy vem onf zeot onit, thowpparefWhngt isatO'enchat shert shuapeelvechufthswaralt lep th pll
# Ads; isanthlekito
# iter 12000, loss: [63.45819894]
# he for!rttlerllinkavel in cisbumy heer naloy, ble yous winod press
# Pes mitospelethS:
# TIhe wiRen, kapdmyl,
# Ens Ihenn wabl too m-Must, ce shod tr;
# BEINhor thinlot devengetalh gA
# ThisAnY thy meavt'k,
#
# D
# iter 12100, loss: [63.56329203]
# evecel eang take foal car on
#  IHd: hove gheinene afr ans bly inten woudptd ug m
# SPry  sf homen thut thure,
# Lomaur as'fby thatminkipilud; e noofkeiptipYern odldO gonus ey igigdist mlee pe
#
# BEY:
#
# KKILIA
# iter 12200, loss: [63.74669134]
# d Ilon of ars fom usoo, ine suine dep?ldtor dis, t gast hy lourgiw,
# e bee,
#
# AEEDLOKIorhainke b conveabse touI' trouy.
# Shivt dor Cameiul-l thco nodco, ofThale thwen.
#  nord doud?
# Waleal
# ES ENGH CHARTM:
#
# iter 12300, loss: [63.79667146]
# Ne ghe HARD ealse walllou nicrurdiogs.
#
# DEurs MiNhe Wr rel,'ol'dpa tei wasr.
# whes.
# Tarek ce sxtUM Cg: would nom,w
#
# L thearod:
# , riinaran o fofan. br icIO vinoelaby thuemeleon inres, yotlscsinlleb span
# iter 12400, loss: [64.04677466]
# Sth pinDars aas Iil?
# Arar soondmer KIR: mir;
# adR:
# Y:
# ur nd  l:
#  EESER SKILIKINAHAsAnderpps heb
# Y, wiwar dordt's thoml mof etse there det llin hfer jot trelve.
#
# F ithe mat py
# Srord seree miaile ags non
# iter 12500, loss: [63.95196937]
# Re,r anctrtayers!
#
# IUS:
# KINI UCINgHlThCAndNo sronegsurer vewes cl, fr kPr gof pet shansu an?
# lanl  dereineny dso lo, tomoof'ulsg
#
# KISd:
# P atr br cING oraddsel bys maer, bolIT'l:
# chorEABtI ic twod yst
# iter 12600, loss: [63.83325064]
# or si'd
# gLharrost
# MVEnT
# KAns bumlge lav, dry decr oI:
# And ndinig fchescoa arBy
# ARC:
# ins Earaso mihet  mecencGooud hamd:
#
# FLING:
# n, pry re a ino foor meas nve rYoug moms they tercgor; Ihe di ro lio:
#  a
# iter 12700, loss: [63.8776156]
# e, odrourl;
#
# AindlsteritS R:
# hacg ou.
# G  ylo llwinI ju ar thy eracy ne tralt gas?
# DYor you. ll I h IINIUCERTHSNIYO:
# ut my ouanepRIRIINI, I Gondnst wh.
#
# Ft:
# Welm thpyd der my.
# Whatseryd!e ap whe ket is
# iter 12800, loss: [63.95906839]
# akofvenve to wroum, wither ing,
#
# Hsrhelf we,
# Th r rd  bI He f
# :
# And myn Loweftst
# Ty  owokiri sler!
# Hos thasAs hasldafs.r
# Yis insawertns woof;
# An IBCIt goem inKoev, ea towRIINYood hic mindiya?
# weg heb
# iter 12900, loss: [63.98873343]
# he sheven ofra he bun I afthe,
# Iif  are twonafr ar has ha  mip cfild hasule thu hens;
# BThosThhosath st silletop'elijf yoendf ofId umde
# as hererdn buf ar aan u anth inaser
#  It II: ioMsimprestae , to s
# iter 13000, loss: [64.18579905]
# ensen;
#  coLo:
#
# WerG simeus toret wnuml aias?
# WhagI;Edilrornve bas h foul af bsy e.-
#  an thes marenkidnn caserps, waroreay naq theowr, ast us pswab bealse , nocu, , unnc
# T
# K:
#
# KQUse  bse chasteras yobe
# iter 13100, loss: [64.07498718]
# thitoue tod ar hent kisithet ot!
# Easrts
# Fo inngt, malorr.
# INoomsy unPtwid ood dr sre on me thicis ithiunthyrBvitu e
# er tofles ve
# FG In:
# Anck
# KD ordive soundslomats son
#  rUC BMNENCHh ba ithel desore dy
# iter 13200, loss: [64.16093349]
#
# erRone,
# ButhAsorf IICad, acritf deiter yses ins sor tueh rle nanosen sull soly Ankath, , g shey ps ruc s wristhe thei an myik, thBur tove
#
# RI I  Iird ther ajud.
#
# By  sde ghis hatert, enolo thacof gy
# iter 13300, loss: [64.12388803]
#
# Dhar'slealthinasesng,
# D- m lwem ifed
# Tor llalio:
# Daved dey,
# Achof Lodladdrth thipngew dona willinshat nofEaven-waviads,
#
# Aasemene miris'swe ry iss vi WorSidecrerts s brlurro br ond coreeriad, me IlI:
# iter 13400, loss: [64.2001498]
# y gimou ond tr a t nad;
# Tesiffistharstey witou a  ye,
# Dor hil's kur ms ony trlut nelcs hinnd-und iironcace yovases thoul?
# HAINGe s.
# A norun,,
# Oians thalr mer,
# Aed, inawor thir afrt myob toule
# Anoul'dr
# iter 13500, loss: [64.11275703]
#  mes grone nong wese rongurVoetom fhe tanth th thKde byee dinemeatac doy; ThNGofnotitaly wher thoun y. nd is vester serpnes
# Annd,
# fed rt
# YrisUB iINI An sutowus.
# d ouor h soucungh mo fe senlf, Bowss; a
# iter 13600, loss: [64.08578692]
#  wady four fud ;
# icthI'p -hos doueth dlyuully pofle, noof tere:
# WhunivUsYl
# T:
# o  touly,
# Bu'msesibuengvere; An irort thEe.
# Hesm
# TIO the ; e y duend,
# hand sersice cean awed ansice'tesdpst pyue miatle
# Me
# iter 13700, loss: [64.11812653]
#  rrrikerd ffe inPllld ind esish nse; souan suats woRnord hed
# Aserr toalvead dou Weced yoayl hawnne whatet foecusin:
# Four an y unmyp ilbad ob whate Oyerotrirds warn,pf pant lolib;
# s ghst war IIIH:
# Whit
# iter 13800, loss: [64.07338695]
# ab y hess hse the!
#
# RHAKIIE:
# TH nBonrd st;
#
# Aoarrel ge this,
# Anncs gabey's goash youb n ulr't ou:s them Geursst sean pubed anrincBuurdst wonaliite the,.
# Uirigd ble  sosoung, osh nulngs;,
# I hicapher:
# o
# iter 13900, loss: [63.88181185]
#  isilard, byu igesinrial ithe'terd:
#
# TCHO:
# elen Mle thenssWistisegd;
#
# Thind, shidait kefu arle dlein thin bsbe hal idToh ye wwlit Athe? narsy wow
# Lot rot ai, hin rinse wer
# Th olfpts ya to lhond sepdep
# iter 14000, loss: [63.82467092]
# leadsto wiof;
# .
# Ssannsei houpk,
# ui.
# Whpor:
#
# TVOat mI IInd bavet ye pune thy com.
# Ada  sieys hala e cont Dhe he  mam all'y al
# horlit pe the,
# Hiis theu linet dacenes  ans spluent dy sor of inh,
# Air geec
# iter 14100, loss: [63.60602958]
# ndel
# My a  yo to mouze doest shom, dow'r rort tom iondm,
# Toonf ty ond  hel; Re, , y  the Misin:
# Rs
# KINE:
# n' aslelow s owhele fore whonf onefe lpssrs
#
# DOFasFat soon chearest, mye hahntisl thererr'wif u
# iter 14200, loss: [63.42743433]
# all II FiiyhirZTNGI histou'n nsean I Co terpOMad,ubth, icndmo aOlds,
#
# KSEBD UYOLDK ND q
# DYO hIatourglsel envearh mhinrg banr coathat Se's inowd
# 'l nim lishe wmigeaowcithayFirds,
# stcheer dibl mim sArte
# iter 14300, loss: [63.58702017]
# d
# OIOAI Led can, ou.
# ay LUC:
# inar ofom brattounde tho Goud wiata rufiveshenjt ar annse inthurMy Ghatthenf igd  h RNGR licth he-r, won fed yoisMeccertord!
# GResenhas odgelews:
# Winas, thouve sanoueep.
# ot
# iter 14400, loss: [63.68312982]
# re lithesan linve mitrir lictg ancet hed Marsoseoubseugey's:
#
# K brer odry.
#
# L It irmd  inowe, beg an
# FA ININacCH gisSas igou hagd ead opgor enw, wisen youp voin sutF shin mriossy,
#
# BUCABD - e Kit her
# iter 14500, loss: [63.64614564]
# e doob somerd
# end h!
# thaun h iotqty pared hap hirm pol pa I:
# Sod repeCHn ote-d, gwals? blh, adg. vea procine, boty deto,
#
# Lhir'sm hadr thair e bos torespyse.
# Shac f thin bTaatlisiwigI F sw ats igl, ar
# iter 14600, loss: [63.58720932]
# oDp or nieeneseinoot hoc:
# o mian gl?
# Oeadw
#  hitist p:
# Ansh a?
# CHhis touB ouey nk fifoncve
# BDUhs f rrimd hiq
# Y worgofs
# IOf Coly, isamglO, foust'er thTuT rort d os nuce:
# Whhates rye ofo cee isish tRilen
# iter 14700, loss: [63.55645956]
# af dael or he ng met ine;
# Thenk melee sime frerooralibrt-eses,
# eit dayoinflenpne, eor'rh, d : ecwh.
#
# BUMUEKIENDYOYD art thisAnholgh madreuc wneulr asd wo ritrstrY neilh mndows, fly nostotay whorrowave
# iter 14800, loss: [63.48130272]
# omplt thed;
#
# H:
# NGH  Reameesenss
# AngO,
# INing n
# EIf thy y neeie af ter anav nathee andiund thert blim al Fithe my Pvemer thesy feth toun my wieNipl ganelllghevr mod hall ly ig her ves;
# Band themn,
# ed.
#
# iter 14900, loss: [63.41727402]
#  hose ofs ind mye the n omt Mat-e,
# rege wrte Coavigh,w ind fan LAe  thomde.
# Wocfise,
# THrou nte masisY OLG kseinof?
# e ru!
# Ani ro'groe wis thin Nor noune teup sersueabs fuamy wails magvel,
# Ang:- low wea
# iter 15000, loss: [63.20016629]
# knles sur sts Wutlsitn se fans gry th thayrn the torgafh vet et nou e haur dy nlotan pseseer hfefradirde go fe supl do ly tor che,
# Worpd doml wher
# TEominiile,  that wof faths cor,
# Boortl IkWanl ho k t
# iter 15100, loss: [63.11917471]
# ry Idy reHdS: of mow,
# enR y emengacenl. sertwhe gond hs,
# Thaindss!
# Whatul mbive pur tat
# DOFerFa, eors ck eefsencyfelolore lamt
# gut eise fle on goo, maw ke;
# I Vo th lis Eris cHariscicBits not a r theat
# iter 15200, loss: [62.97322595]
# ur noaybesrrkt byBamus ofo na, IB thit IL KIhii inedy Kor:
#
# LOMN KIBIBENF  OESOFRYu n stKlom invitrs de RICI Inghard rillid hesang rke qu, amat outhy tor sjr the
# At CGAs iin
# brhe thncof elaint ew rree
# iter 15300, loss: [62.9122817]
# eld be:
# fee ! amnd thes
# ourthand, evivissesamy long gout ater,
# Reerod ans ,
# Anthery,
# ou w, cunnt:
#
# LBuV  illlatwon hat,  fow Hathanvereearnt af sulffo
# POh y kilangerss; nonaY lsBuitg not tas Marthis a
# iter 15400, loss: [62.9327878]
# !ayer ade,
#
# CmadI INCaasW tly eu ocme cgG
# BBOEN CENUC:
# otherze he fol, ir,
# rir:
# o ialeAlo Sug picis sthy hithe:
# Whayowac bang nome.
#
# DUE i  isa shep reurs as le ranom dle theeer njor bel rtelx hallyl!
# iter 15500, loss: [62.84519993]
#  pil
# OFs falet faWhibouet ss.
# Cough thare:
#
# Khe y omw therre beah- aramy che the I peren Reace th,
# Anquver esy inthe;
# ReCaav, hea  hautrens sou sitacnlls thite
# Fiinave your, kice Ayelody ayl isger ave
# iter 15600, loss: [62.82375233]
#
#
# DOLINLowe- ofst war'd ant art en bl wo n'a's dyrse,
# Whe ono  n lef ans oke laceng ghacr:
#
# KWintoK'd, al;
#
# Berr keff walous sulbly be as farettn normiccud
# anth bewn hathit wuthedeice ofdes orghtr cro
# iter 15700, loss: [62.80482034]
# stxt proud 'eley osaz amy wpeas y freals oms, mo orifd inotrireg rllot lebe ig ilceaim or yo,
# Hinon.
# Annet dat ghule o wa jon' frorfef: towplaton the,
# White, thee shape ode ses nongs ling mos nowthlct
# iter 15800, loss: [62.74822077]
# ceabeatbeled Fope chie toolaart endCs  song nas de hathigbe, met
# or may mopuflks core thy ithed an, ansp kio fo,
#
# UHETERLSORLDod: ot to, ofsh soul ngoun'metbbe i ou fmay'd
# W:
# WheaNarest boud there-:
# s
# iter 15900, loss: [62.55479835]
# viMII y men,
#
# Sil aret of Lof;
# rowkiss,
# Thorded
# ilndwor't ee ecels thouod maI le wepnelbLave wo n nkesiganf hanry kinglll tikh'drornt the of peake he;
# et Ys e!P hin.
# herds, ce himedg
# Berd wreankS ok t
# iter 16000, loss: [62.61430281]
#  yo Yon hamaslin lit flu anA ?
# CEonanhess aid of thea,
# ilasror thou
# S mem dhese tw joul  thake inI Anso
# Msor mang
# WUnkieel coate gori, ars alvir
# Ary etisilok your re eth.
# Mo mo in uncerd, coue coul sa
# iter 16100, loss: [62.494719]
# o f lo mye
# Bet rewaa oue inherveng wloe, safinthiignctan our thinstrett:
# ke nga as thatIi rkawd de
# OThish thill, lo.
# The ThalVoaxiod.
#
# LlIHOINI I Fod whofe dalor tow thee, noond y. bee 's oinEle inhat
# iter 16200, loss: [62.39215636]
# wld youere,
# w horrt E necar, ble.
# AK E:
# GH ct mer le ae.
# OK RAR he ldats uth wir eny cor  owy.
#
# Tho thagerond waneEpter,
#
# Q nher fo, e acalR loukhs hir eghed,
# An lo,
# hir
# BINhe h thy geindoy? bosl; mul
# iter 16300, loss: [62.58717566]
# ner tont, Ul ilen hymAd thes am thee thase;'tn thinWend miokn wtuse to,  whithaterth mimoued,
#  yanbeigd eat.
#  int shary wishonndrtleltalh mis hot O Mer rong anxd't Hou has nounc eligti ofOls Iyrout de
# iter 16400, loss: [62.60214915]
#  igh mearseayour ar glieeprsinld thend ther trirh tdot outl wreauctl yol ktty Roy, u thy, thetmein hakd, fie
# ASk it hatarargod dilogler s,
# Ole lly an foungoun esleofj bend, by illif.
# Ashoodso brTe:
# e'
# iter 16500, loss: [62.36412639]
# gery
# OlYt, on foeteRy rfourl coner fand?
#  avek I, hgat soum y muy len; mied,l?y htatg meajrl barr l y
# N Hamstcom khitoravd yout wadied
# glll tor sithede y Irtostcout  deinat mate; ford s callep raorg
# iter 16600, loss: [62.2397199]
#  on yob may aloh,
# oous the the
# ThMiratthor he odrew?, ff Tal ll' cry nd:
# fo ad?e
#  fry the tiiengstNae ble madsem kithaus newiust vapa'dowerr lare whitarFi'gy?t fast bond of not huse,
# Thicsoe;ue bly :
#
# iter 16700, loss: [62.09835819]
# umemnaenarn? so fiwf chy pethef thivil?
# Anst dovond un the thindonse thou yoayo no bel akorpacritMuot-' lo f my dit a wet toatth, eud.y
# That wy wh od lo thad ineme sheles
# y par tond bat theen If I Nit
# iter 16800, loss: [62.08596919]
# il wn
# AHESERTUR:
# UMCHn haatswim;
# Whearviebbnd nee, al mherit wevelsbut bl gcret fang upe,
# hes tour
# OLJOAn rf threayus hee wenid, nosteawld sbef taladly cguslay IRuthiwo with you
# Chhe As alist fand my
# iter 16900, loss: [61.91141352]
#
#  ath noe'ed:,
# If and.
#
# QM: dat:
# ARI OFic a a ghe my mouer.
# ea fos toongr's,
# ABd icrth,Aresher teurrs mey  wieannturrc, d os arns,
#
# D:
# n eire, Buryoremt
# Thinweace  the I:
# ; aet antabed aft theadle II
# iter 17000, loss: [61.98574554]
# re bot.
# Wilr s of sire thoks mercown
# Whome'd ikh mispratarBemy,  gtuy greams bre thee whe wio'n casniterncon viretithon ain, loww:
# OFvithobg onakt
# Svip wes,
# Af feantr wh tht thim aend noss bya len!, b
# iter 17100, loss: [61.8430545]
#  arike.
#
# DCYin lhall my od thy toRele theee stoud upchl EtORKEIN YLEe s as:
# Anheg,
# , onThmt, es's'swerenderrt invel Go g e.
#
# Dlo rthOeey epatber vy me henkss wam,
# Satt banakacee thiee, y, shy eal wib
# iter 17200, loss: [61.76548574]
# Savent r:
# AnARGRn meap a  ar gip;
# Whisoluse  b lirla thave Yowf
# Ane uts le fagk, I' ond teeasy.
# Whisnghegrec lnor goerce thee tofr.
#
# KG OFF: move myoat  ayl is hisGod seew
# Au, ?
# o'rct to apabit sterou
# iter 17300, loss: [61.72080221]
#  thin okteem
# QUKEERD:
#
# D Y:
# NYORLOak
# Hlounp fou or, ealssl
# G anklpanpom; ofit,
# ard aienig cdimy brapmeld town Arisk fry,d
# Thatt lle
# Thitt n:
# Yord.
# HerywiR:
#
# MHOKYN OIFI  is thy unl avesgeild agsh-
# De,
# iter 17400, loss: [61.81914298]
# gingouf spkebnt tlioret deneencter kkrs? h'l
# Afgar ve heard gol, I:
# Asawaip ngont.u dod nork s yearfpt bi,  wrre Rind fhes mase parud thcetrem;
# 'TCYd Tat chals at cym
# A:
# MAroren'wegsTisou, at:
#
# D tUC
# iter 17500, loss: [61.7924335]
# g opr thoulepleagerl,
# ey:
# do do'y.,
# Got wous,
# er it eindotaid dake suten ang; wor maify, wIow y thou;
# ict sereh,s
# Shsook gs twiat walgd miwntistt Maln voure e.
# AKF  iis t w RTE  I:
#
# KKIBEE F .
# Thstng
# iter 17600, loss: [61.70841429]
# spee foked. miar nauys atht,
# Thirivematlilyy gh shod soo buu ngieJove.
# no l mo of s owigWeK'dber eve proithe
# TherngCl:
# Drhaz thel prl, ok ptanotm;e
# OFrofnt lazd'sdse, d tos fadtanl'p move, yo beeran.,
# iter 17700, loss: [61.69708681]
# Yowrests, any heielethitea mend therice hosg ur entom of feavim cha on y thinch tord ortade ig plegntls coof I the; Youns ur hjaves' sole fmat cen thilwse lendowTinoer nds of s lou ne w ag I arml; I:
#
# iter 17800, loss: [61.9405649]
# itewy piMav hi otTard soul linfon  fou, a s
# e
# HaNo hounter tor wisther mang willal afambl bate eit
# SHann thily pr tmath:
# Athetle ld thore,  hit at ond selit whas fatreh the goupure, nselu, os tho that
# iter 17900, loss: [62.27848751]
#
# Schrim:
# s hirs seasiod sosut, LeG  dedI at houigle utrssls
# HI Icard ! theage thoued odn anese; thdirt whe  thate!r ngfoEld an ter cout pigl,
#
# KBEK:  irnet
# uric dNORIANMNosshts wste ieerd. wheuters!
#
#
# iter 18000, loss: [62.37961597]
# ige;
# Thousard enong avist thil thon:
#
# N II Bey inoug d hidgent he wog s hat rhavhepeee toE shoue damatser, eins! Buh  nh,,
# Whersthujl-oure!
# INher he lvacies
#
# O:r:
# And isfaamt thun'th B; or hsithor to
# iter 18100, loss: [62.41507755]
# Foup at in thabps toukl nothe k thme
# Bn tok Ief sopue, Yethoum!
# Bihavgh kef, Sron adinerwn, wilomk
#
# DO:
# Whey saflepbTin  mory sen shas y ou thelitthine y le
#
# TOUNE:
# stUS r MNG ne eof on es.
# I nianlg a
# iter 18200, loss: [62.34793805]
#
# Co nomy,
#
# Kopim bo f werull ths Thobl band asl tuy s.
#
# A
# GS Mg:
# II ll ttitth teacsat Aminy reigonmaofe d owif hmag shak, utndd oireatto awrs mam meakd winsoms lod of, son ofVeesay sicond sl he.
# pof f
# iter 18300, loss: [62.5199501]
# ly thuvewr gourel mirgeksany, fers, wive an chun mowodK'e
# NOhe I d y inbisod:
#
# N pearl wiane ntoans.
# So s eely cor,-shay here sou punen,s has:
# .
# Fow ilrlayth,
#
# We ndormbe no sat ce or
# II fe! salontena
# iter 18400, loss: [62.73905634]
# all, ue s  upfu fin m thal,  srossVonced'r,
#
# WOMTo nHEd Joddu theafrt I ave IOr hind',''forer pre onGou ano.
# I rdy kes therd neant wew llY be dey-, Gs tbu- liesconghes seicfo, ip tou his anteem pe
# Mou
# iter 18500, loss: [62.87906176]
# vet ed.
#
# G nhens IlIrThy akcris oAm bo yeitheree poRe thy I:
# ThirefLOmyrs ar br ferou fcalities shatI itur mI  bed thtilsl bouing soul:
# SYoru y sorg fo as enthit kher he thou, utso whade fat cate hith
# iter 18600, loss: [62.93939028]
# n torvear;
# S of hild;
#
# Re esend is
# S
# TIthe 'darpe pen romigsb, pas cre
# HUilt coup ord inl utled tr,  lAicet, a or ithu,
# I' founts,
#
# AP:
# HDilf me y onl,
# FEarre s-epeeds, the.
# HeROM: It takd IIhe d on g
# iter 18700, loss: [62.90656529]
# uusnabe,
# AYis.
# No t heass,
# Ait ne't hasmalod foe:
# eile diish:
# IChis ty geer tey C onSure de dyotadptwima may o deeUt, rills move o for are,
#
# Tidn goret me mounds bis:
# e d nain fre trouss oflaMaailes,
# iter 18800, loss: [63.0486498]
# toe drstty calimalt ok  mloray ald he gun ancive frangs
#
# Thiral, Wis axsaent coI mafpout! gour, xls engbr.
# RICEANBUM:
# ence g a esai.
# Wefiiov.
#
# Tish wow of loved.
# Low fo co?
# Anstasy nemad yoor fithep,
# iter 18900, loss: [63.18265514]
# b mout tilishe
#
# Fond  ar Po wae, hove cinoke aithe,
# ShithtagTh-s al okAsine nobe toults pmar
# MThCEe teith ther d eandLrhaveo d uthilos then,
# Whivndprke gVeesdive theen age isor shen he ibn'bnd
# Mmy dep
# iter 19000, loss: [63.01380407]
# d.?
# e hay lat an anomt on, Wh I ce onthepe sergto oonds eherke
# elle nokink' Buss gour ble ane!,.
# coin s ver ses eltalBect hen' vant goue whernd maarnstint wither corarn ishe is athinI mkle.
# ICVeompea
# iter 19100, loss: [62.89265548]
# aom  inknced Iigr te thig t thigtoave; ke ut bs
# mlamowt atrir hep-Bou, thsee.
# ONhencedd ht mis fhileU:
#
# OCBEScom Eind; my ape ngotute:
# Sale ag fnit dShe thop cerye  honr folo mor horn ote caavrimd hut
# iter 19200, loss: [62.63495106]
# m
# And, emed nitor sosjuant winde  chs
# Tou 'ne,
# Wherg?aceld to now ind:
#
# AThOMETOMI:BgUMe s! foeg Pam laove to fefusts,
# Thhakn ficlp whpe oht thincea anl sither whe fonoves.
# OMO: itk:
#
# As pepet,asp tho
# iter 19300, loss: [62.48203467]
# n ck gwol kntamesee ack.
# rot of hig my Ksecly bergge, s, wiPthe tad, sinotht me thake, an,
# ge cou?
# Pfout pugty we dweamy-t onod
# LAF air len grridech, d th
# Thow havesw!
# MA ionde setDes thirnowa thatisn
# iter 19400, loss: [62.29958529]
# avetBtn, frwoeat titef .
#
# Jicth toy wy os hatrit The my mengh:
#
# Rhe reve fanes reAUavls.
# :
# Thhehe meisol b stiay am thes somu eidlen pocten.
# n sehitns thue pl, loerase y thof my an yoe waris ings
#
# Jon
# iter 19500, loss: [62.41662308]
# I pe:
# Mal Buscse tillll ksou of tiwroc twe enddutserrer wenorus;
#
# LEELEMEOREMNOUM IO: an yieD eee s army!
# Com wh lIUFat ghirRaayprut pinurr be
# JSaxnd,
#
# JEO IP ig he me, theseyd, li.
# Ther s.
#
# OAnet rin
# iter 19600, loss: [62.33567437]
# by al,  the meit nond sterk
# Ay lanning whaven-U
# ErIOCO
# Rf irreadhamd art ofthine reumrien hacet warert ps
#
# IBE:
# AnD d rad detw thoenc owareld
#  fhant oes lie thaud, thapthe.
# ThatZAORiteathknuss ttoun ?
# iter 19700, loss: [62.68309562]
# rerersbuwey hogomer woong ensup te
# I pre albetooud?urst biced myowule che ay:
#
# NEHY: NGame k; tlol gors whe hogde llowg wicoy ep h thenits,
# Aes Mit e
# Mor-ton ifd xadoof'mart rwiled thorad, int: wong s
# iter 19800, loss: [62.48028454]
# houl ous, ba ath tom mye bk adniw
# A
# CUn withep, re wou whuac, reg gr ofofo. eric dnd,
# ;
#  m e, .
# Whthe pe mac nthinane  ud isor  fe hasthlll yom! to a taneayhi in, Whusve
# WUELEREM:
# Whou?
# ur gad you soa
# iter 19900, loss: [62.39492962]
# e, ains tour inritile,
# do tpah, moud shor piley wowl sid an'st.
#
# Jw;of
# A eale, Wy iin thamw ve nareu.
# yrel ans.
# Iu leay thesem, to wor,
# e : g,igoo-l thou.
# LII: it bis o th notsr morg with be not w hed
# iter 20000, loss: [62.45209008]
# a prhot w, rel.p ve thor,
# LIO baing wasllb clhe rids ond sousee thfant, my gro sou, ; Ha thit ibr th :
#
# Fesas wers!ansu'tI h owd enere ttep thaef heyntoy?:
# To t ror
# Aof co to wthee an sehls hir gouit
# iter 20100, loss: [62.3880838]
# isY g hathee no khatco daen thea as ncom thord
# Oall: ish swh, e Go tII:
# Ang, l fadir, shee
#
#
# AKfTKTULMEETE:MNos, oftare suenducat h velur th
# mdep tode wast masd ar ds tou yoy.
# Tuitoun, lat in hove, ma
# iter 20200, loss: [62.30909138]
# dou, fighe's, sedlkl allter, inboy mye,-isle an reg-riwie, I fheas Het ellouir ntilg ge treustuel,
# Anot ah owselat tiy!
#
# Jep ble wnay fiwns llim Ore't, on ble oware idomitn wome fhon ruouu Goove ee 'c
# iter 20300, loss: [62.48224033]
# osuopek'en rs agr haiit why mo!', bur:al.
#
# Gaaa : is thil;
# Iwai-ld ther masmiat en-teeote lutsin. Ef yhea o e  hitanateald nougnsly thete sinsAwwous bouu,
# y. nO  cha I AwUTEUBhere foM:the teagAR mcais
# iter 20400, loss: [62.74133066]
# tatif awion mey, thy aue nged crer?
# ERCB INGo wiant baur okn thereent sristet ad:
# istutrtry fais s liok
# 'dBUursoat.
# Buf, fmact dse geAnorie.
# owt out
#
# Dord.
# y Illy of lagh therstud, isg t ure'pfre,, hu
# iter 20500, loss: [62.99224559]
# elt n;ilveacd :
# Therd? mla sOu fith isend che,
# er thpe mon thyormtatt rop vall sais, riing, thene
# Whec, lad
# on
#
#
# RI :
# ...
# G ssemserrer besh ouse fyour inf hit bTonFthovary tan
# F:
# hath towtouro Pour hag,
# Lowad mais bath the gird .
# ivret youp wous e, I,'lless taie
# OARRDETINWI JHod ofre porilhib,
# oundlr;
# t
# iter 59200, loss: [63.17719809]
# d toikidbee nearbe ionive,
# x
# Aa wat Rarliseh inqucet treatishafe, hike t sre fmet oriour ras l
# WWh cd Whhipr th: e
# HICINo u f:e soueesnbtus ais hous CHLOisnendayade' and ho  yo! seatou misou, u  satil
# iter 59300, loss: [63.12208121]
# P:
# ARetountbl imim mante livult nito o, Br t wores oke bnidbt seed minde es iove eips.n mat teee. mylly?
# RBAnNGelldewer thabH old, kiy lorrig,
#
# Se shtuckle ar pa
# WENDY Ikellom by s fey tereneRUKEYENG
# iter 59400, loss: [63.0559283]
# Bl met caranr rv sigens webl;
# D s hoUug ous nore
# W ITRENGARAMIN OSON:
# enfo n!
# n il.
# atinknmorean:
# er t tul fords youor now, ur ow, and wid, enshayanorau.
# , shergoasmos as motru'se wabal o.ra maevhino
# iter 59500, loss: [63.03736666]
# oud.
# A
# WCHw th t rood: be,
# s;s:
# Whal aes,
# Tr can hey punb:
#
# Grf gstengh bor whosl
# LShatan
# Aan the on u anu leor sho memihot the, hem fo shomor gal swonf your ghy id.
# s no gau weg ict w
# Fco geaveave,
# iter 59600, loss: [62.93208478]
#
# FivBut erh,s thofes rrome mel aid maingod goOleners sie ist shte glullyNJarron Anak .
# Harist to nsen yourec y tuld, othet bis weaI dormttullf dest fouhs t oel,
#
#
# L AcRUMDY WIBESXitaron thes of hatere
# iter 59700, loss: [62.93291725]
# thy, mysisoumst potwh tnscemer to hailn asore
# RII th kMis lint foathooltem,  de vecass,
# Wo pasuemm;
# n int obond,  eanRi
# Ak Ci watrevem como.
# ut ith of o Caughad yooued tht the,  I hplund in pLHANI ENE
# iter 59800, loss: [62.8124493]
# lwaoullor dothaniove 'l'daralWh
# Yus how aand,
#
#
# LINB:
# ldgmem gors ith
# Wlyope the thonote! thyot hus hen thNas Jat heapwe the is imcs bf in bgoak lon w, the hith yo meer,  son my here eckoan igacimg ml
# iter 59900, loss: [62.73159818]
# fet ingh wheclswad my,
# It daefl peraco t,e mel.
# Toder rare wit ther, y
# L'Oemdethy tale Iold myome to D de wak pimisdingistooully fo:
# HIcl II sttome los s likesmou wilat tse
# Ms virer
#
# Du mothS: Oatyo,
# iter 60000, loss: [62.81379662]
# h istaethey toot so fow wh Tratinit ains einis ithey t de wuh po,reey, y thes
#
# An aof or,
# alinabf eer lem;
# Le, mue Ist Pe a  thate,  thom shahe
# ARENECDERI H:
# inanr oud giSie un,
#
# Orld to Bull pom hear
# iter 60100, loss: [62.73529607]
# d dCatobed houecks wOF thin
# Fo whe p Mk gon po n okd all, ritouo qu, utdrGoCuloHOR:
# IShomn aianr th'thir I glalf n sss ofn oftht'sou to engss,
#
#
# Bue:
# INRKTEATSR IFn socel Aend bofey!
# Wit tohe thitharr
# iter 60200, loss: [62.70105913]
# a my auns igrer
# ThH rinprgr
# SCaOfs ive A:
# TAUKERKCHARHINS:
#
# DARHBETG crusisl: atheath yot ay the ither therou bllt ye'le,  thec'd gavinede the lap adesco wante ware le sne t ar mih, mil avendan.
# omr t
# iter 60300, loss: [62.64791735]
# o miviagem.
# wllbgn?
# Bunon, r ot hes s.
# A
# AMh t tKBAR
# LNGERROLNGRRD ir shiy;
# Mnlntoue Thenwce ls Eou me, ngldhaht engHaut thaseest fe wagit
# Tha pakde tiegonoroup h ay eSss pest
# GON UGK ETHK:
#  thathemy
# iter 60400, loss: [62.63270545]
# e fan whaser;  of  treahey, ndy, tho ofkeek ye woy an feadrlats shy iest and
# W witenl thot tht, kies it ldezer nued tmlfayhaurd brrth topalw Gy perers irt'er th th horntrp it mllstenty lrvN gilll ror,
# iter 60500, loss: [62.62102485]
#  athe the ish dam speap,
#
# H:
# mooug,
# Thet my tou siendFrec the, s lo is is hes ound.
# ocs.
# I k, ond houngee lewo Mi.
# UKRYmu s cou le lofr?
# Antoou themais gunc, boged Skrawitoulourne hee.
# Ingot  and grer
# iter 60600, loss: [62.59118236]
# l werinis lor my.
#
# QN ordies?H ade he vs gone? ond asre, ofins, stound
# Ayor.
# BnThelrkithe foke n: landnigneagsgil an?d m? fas icanct lliAve wus lime wover esh wof trof If Dis id Mok thasam:
#
# HANatroll
# iter 60700, loss: [62.51676016]
# d vepruepit of faf d ik tte your,  thou re gtry nevergn ephirerer rusoll;
#
# Kmir.
# r. kertw by IOORWTOR IZ INVORN
# nOadatandioporis ael for,
# NGighaof thutty meare.
# Wh ter tor alllor.
# y, ray kunt'd;
# n'all
# iter 60800, loss: [62.39808575]
# ar taront t hruson, Bue!er dolg,
# CYHe nit hoo yo maheaste iot theerh irs and h onore sou oud,
# Wbll:
# Then,  io A fared I :
# e wixt y yorso, url to et bmayour lautet the ant aneamgron o r re!
#
#
# MOMNECRG
#
# iter 60900, loss: [62.54472645]
# itens, pacet id shoawllquond
# Hnicase werlet mey,
#
# The havep wat,
#  at llachicieblHABARTENHE A:
# RYERGRUCERS:
# nd vind,
#
# G ilol.
# er, d rotok oby warol'dinhe nDiRRIPRS R GLecakinFil hatS:
#
# Ss matater him,
# iter 61000, loss: [62.65600449]
# fag fausty dibE bull'se
# bHen,'d hetlveerinf e Prcay hee,  kep,
# Nora
# An:
# s he Dt moer t kinzpndFi ises is falac mwadenculd gisf hearwifijeer nd,
# Hend 'ais  four indie nto fo mere, s,
# ROye:
# IIpI:
# HOR O:
# iter 61100, loss: [62.44983942]
#
# W c, aind shy foug haseete, ererer ad hs breve cstern:n her
# TOP BORmy thou
# Tho us seh'an!:
#  hetis morelf, n, Wigo,ro  at whe ma:
# VOHANGORROF HABHETYoufl;:' lnesih gearsoukingc, riAc.
# t mare
# II INLEN
# iter 61200, loss: [62.29035934]
# youlld youa  brninge oru hikeank,
# Thh ter
# SBE de fom-trhroths t ciebiree  arint gay lrs BING EK:G heavnout? pomobrusiteaatht nntere chelc.
# Bushe h.
# I th bund withe enh,
# Wh th the thes ken erst kofs nt
# iter 61300, loss: [62.17782109]
# m,
# hes?
#
# Farhoore thrgiehartsurop ne in thn lu.
#
# BHees to ande not e fEIdZZ rosndowre
# Frenfwe g ttr bids,
# Whd lro my id hruof hathirnge have mosedd en:
# Ta in peamests.
# Alveh lrep t fladilrbaiN of
# T il
# iter 61400, loss: [62.11450734]
#  ARYO LICMCE Thavaniselntese ngrerers bF do rto thlagdy das.
# s tuI theacKpstitRUANHBTHDHLANGINRNHord der,
# hW ae tori:
# An3 OU pow lie.
# chhtrngmceek seeSiep to Thdasure of wiyoourc ay re? wayI chd lit m
# iter 61500, loss: [61.93624893]
# ,
# d sibeam avi te est?
#
# AG IR:
# Y ndiss yougan;
# An mokf lore as old therie pom of
# Wpi ashe tslssfed, gol trawerng mome havear.
# e med shulme n
# HINanuct we has Hr HOL:
# SBitteng'shanecein ue thilseRavagr
# iter 61600, loss: [62.04090694]
# I CHI: I ng s
# Wry tbeere.
#
# L-ondol,  ao Mueaad lone Buchat th tea, hu thamste, e What de gig itou'dhe del amains ith id aavinon ond;
# Tht !
# wer den av, indy fom you  foff-haiseo ur ified wad ngh hon th
# iter 61700, loss: [62.03025604]
# sourt ashlvinave?
#
#
# KOFUSERRIO MRECK:
# icsuG meurd y If:
# wad.
#
# Denrce,
# Act
# Anowsearhemoul ICNGBES:
# aat,
# FUlitanrn
# F
# KGRINFO ROKICB:
#  g may hrit d aadt,' andoe edbed te Raipot Gazouacthtuironaterractat
# iter 61800, loss: [61.95451495]
# Y IKwon wice bl dengousp or y aids wumamt? corat douncg fobut po w M:
# OBy myimanparogir kes sier- kowes oal
# FblSattordreerngad'.yo ishe? ne
# sisret todes ary beests that loutht ull INarhal.
#
# DING LOilr
# iter 61900, loss: [61.94445325]
# dl inr ary forabus and iewieblateredt lAnD pee user's orome thirome he fathou f  losurndneldcube thimwlp youn ngprer mosul haingiserew shainnd
# Thithiss krelisp sby uefeer hot healy gout'eer,
# ndh
#
# HAGh
# iter 62000, loss: [62.03168998]
# B thinos muste
# Whiithilame ar ahiring orf-e ll Iomend,
# Chi:
# Me tors e bofdof bisean fe ve,  the.
#
# Fol foacnt bt you-seere, o, agread lit rar roni st u nod shl hearre, ngk? hs bvet lor souongerhs
#
# Bor
# iter 62100, loss: [61.96988728]
#  CI Fn silt oron mid,
# Thal wim geagin uced,s pom aree?
# DUNUKCHndat houk'aa
#
# REROPOLLIY:
# G thel onans:
#  iaced brs youd akreritherd,
# 'l b thad hom lon,  im 'es,
# Yecet cllept; iothgostere ORe e Gond, y h
# iter 62200, loss: [61.88976913]
# peoke nlisp Iy swyrea:
# leve to vome?
# My wRDHAK: he s t sWastm s'inon diceeds ouceersttry,
# FTounse toulaasaing darinstese ef haye, mantpr tulBy th intiereht'd pitiedlgeom thowef hamges w taricthhirgy g
# iter 62300, loss: [61.87764569]
# thhie the dilens po  br:
# mot arBuquamstncstrey- litecen ofne heemss itie nal to my-a
# HCEt zistthaks womeecses aney,
#
# Ang stil horaentof werofape Rit s't, ith ispoBE'sHAt ijes u lor I sout
# Wanone.
# Anxt
# iter 62400, loss: [62.04756571]
# thr ith sneh  hiche tus bod he ped mear four to my thueearfh bl cuK:
# Sowd llawathen, hep;
# Ondy sw,  y furta:
#  my,A tongap, I rer,y ith ster brk wll anch iong-
# NS:
# nae? toulimiof ho.
# G , toe, one the l
# iter 62500, loss: [62.37113285]
# elt
# TUKOBF shi,
# TOFw cINV:
# A ar oodt owar ram kow aand are loveerysin gowse Ireh aginowd le,
# Aiel.
#  of prrtr:
# Vokands?
# Aarferalndgawou tae sion ay heand mas moud, whouOR aladltermy can, nol
#
# Gu sherat
# iter 62600, loss: [62.40362621]
# he wh: iul sund Oorland lof theeaorer; of Ge co ateasis pr ne weamatGB RI OFHANETDL I L:
#  Bhet s Mat mea?
# ArouRIithe irerogarurtichas
# Romel howur beagaun ror.
# A isn fi:
# exonf nodlend dorepasteramt?
# Fo
# iter 62700, loss: [62.47070896]
# Anveld
# Thedc wio ohis a r waen  Balav, nlk' heant dhowMINDOND RCHENY: shu te isne yore ttute wS:
# Anrtidouupqul r hive bghtairinn moof ofave ty
# ShalseKeS tEGI:
# Dorl norave tt necteaGu yorom,
# HHeWhieget
# iter 62800, loss: [62.35825153]
# lan
# ThiPutuned tal this dis tou ind,
#
#
# L atece Eris IlestestuNof whe; the e
# T
# TCEd bontsusiobeste
# Ar BORENO:lganurbeh,
#
# TOL O:
# DEOFYOARIBOMC is-riny May ait stulporac jout ront shel,
# And oul oke fo do
# iter 62900, loss: [62.51247686]
# aive ctein col-o rearist key.
#
#
# KO:
# Why wend lk pCim beaid-amy
#
# Toud
# IDOecpabme pd of woint? lof to the bom ar'el tUTARNG IZI:
# M
# Oe SBe d'les fmio fio bit the calfatolad pris comn stanha
# TI INGBloThke
# iter 63000, loss: [62.59548437]
# weawcRODE:
# K:
# WESTLAMMNBENG:
# Sg, he, es wap
#
# D:
# LOMOFLEESlls t hnomecrse this a MyigEROFam mor
#
# nOnYet  woober LYe:
# Foco meamgo wum'del ar cke ais tou asay
# E lithe serss daig tRGUCESROLCAPHOMK:
# drt fo
# iter 63100, loss: [62.70536106]
#  hiw tEif thdl theen, Joroldinh vie ch t; ate am rerill buld areath te farkicel sithu bfor ith lfo thatt not cagimngerh' byoy t WId PBEpred ge,  fiu.
# Boq l' Ie shalouy apr ueed, ous hed ing tioar thau
# iter 63200, loss: [62.78930439]
# or I mad: goe are to wajexkied KE hinifl mDarnt-lcongogMaIS:
#  wisy, hiceror ant dranfouwe's e!
# n the go, rse,
# Nor how and sy imabofe fo lim of hat der:
# h Ound Iap:
# mamyat to taf ansoO,borrurd ofers g
# iter 63300, loss: [62.86337966]
# ghe morreris tsweaoff nde,  gat
# Aprnttapat targhact en.
# O RarY wanis trde thit Id i thne'de.-s
# TIir w louth
# Wy ran in.
# ,
# us, llt.u? Iwsw's,
# hang gavurh' purt th fea'dcere bieRU dBE II: r thak hinge th
# iter 63400, loss: [62.99667666]
#  ist; de wign ROnongin prorel thot phasey,
# Blf iry i:
# BNGILROSBTARO:
# LEn  te ll iricomlalo r thk my st h:
# Lootathenc thl
# AF RDCEBS:
# Ank gt iothe ste rone porlaveratveenobf'e.
# d, Nould pres of yourou B
# iter 63500, loss: [63.13023401]
# nd
# Aof sour, inlogkth ease meav fuc loond tteenpanch'ehel thinend't-t nor lat aur
# Tale?A ve hus fralop th'e bom--kee w cere wener nt fore t sh! mours t lkir haghe icoo-lambeCirn lol! hath fI Berst s a
# iter 63600, loss: [63.00453107]
# us the vak :
# QUEY:
# AUTo, my hatamof da lous swows Iom rdeerelight b de the ie oo,
# OMAlak hinfoins!
# Milr, adur the tm' may nar, f y owh ts u 'sinMat nithe thiSon us ould-fs isirss and ooad tou r ed, or
# iter 63700, loss: [62.92159109]
# c pouaginle wompees.
# BUnU:
# BE thy mon thnion y? thees reEs bdy ifeg mit I ond thued, on the aosou yooonint, ty agh,
# Sie verted  on;
#
#
# KIee presl uever tor;
# BENt aainge ou.
# rpMEf omshwatrde tho'k leasy
# iter 63800, loss: [62.72496441]
# :
# nomeand oud enigh thinnoude t anfl ly tlat fraald Sowgers ame fe  yoKa:
# Ana at a, ers won teO:I e sete neasuspmbred. thanayer glim thil
# Lhi Eaiayty, cel be tound hon ar ith theAs bise; be,
# ftheat wo
# iter 63900, loss: [62.58219208]
# ely Thicent the s wurro,
# '  theslt kempn, 'de: ugh tramat es mioooy,
#
# Tthave By ith Res era rs
#
# nOy thase  meon foked BRDIOTHONOI:
#
# NOF:
# CESo ith t wowth
# Ters soe ndhy taket oryOuld'boud yooun:e tiela
# iter 64000, loss: [62.41200129]
# ieg Olllt OMEvorayerPrVO
# CKYI: I:
# Ihom I-tws iselt how neid co 'ton,
# teuram tal bror thete omearne eares caesnt:
# Thel food yoond,
# N'Danisngt poed Iofel, ifd the,  wooke ipes
# IIncencl' and.
#
# BI :
# ELUEA
# iter 64100, loss: [62.52171131]
# s mund gootl,  morato d.t sree enter frlowPe
# AG:
# WBOUF:
# ROEOD:
# Anisamdssteagoure t aan thearerGotorort the duln.
# TTh sere.
#
#
# MUE:
# AMOMgoliksa
# Tou wht t,
# r ughy bthe Keitimr der jowahe;
#  iu, Heble  yoo
# iter 64200, loss: [62.39789097]
# MRAENC:
# lotth Is athatowaytte, ncge,  aci th tle hed w
# RCond,  bovpit m-seeead;
#
# Tmee if hare feeth t higer t
# T
# Holr shew;
# yodeht tis momppo dre, nel IIwxJRMutint  hert as,
# OM fand,
# tepast iieivould t
# iter 64300, loss: [62.71221298]
# s goow to no Hhey yoG prome; touns ethind Co
# Fadeald of deo-ade.
# Sh min Iw hicBte se hieas ore tha t Boul you lon hier
# Toinge is toores:
# Nof nggunt mimhe Intty bavargep'
# That iglt s;
# Toloulis an thee
# iter 64400, loss: [62.56755414]
# eirhadu mow bany li of e th of mo pomis heee'te, yose, s anke fI  rar,
# tyrearhon.
# Mret p of wo et of s tmec cupgeern men! boud,'
# Bnove loud,
#
# JUSOFEBA CHlee sapom wisl aligheish. a al?
# whermeSy bord p
# iter 64500, loss: [62.57252506]
# t whe Sh tere wulevto ofe ald an cod techespes, Anwige riv,  oof pun nelyer lo I e th the itheeitle ongoue ofje what chy ck,
# Asa inp inye.
# rve s ong
# R:
# By, e!, h thel go r ndt wiie! use nutht thew; sr
# iter 64600, loss: [62.52177377]
# saGof t an wom wai, grthnoNGht
# JHoammy'sery.
#  caerveom lout.
#
# Bsou ma,  we, w hanc loni.
# Av awh:
#  tn say lougst:
#  heRows lo I lon heittr hllT: the waarj har fure, e bu?
# IGROol thy al ts
# NEU:
# ETrofoRAW
# iter 64700, loss: [62.46459607]
# ave ne doumes
#
# Thon'd nowes e ofd mor, eseev;
# To th; s ova dinfote fay srorw toran wau of hatot:
# o'int ileg
# Thy e,  I-r, isuseatw.
# :
# te yoe the de bin n and bay ye,  cay bon tte wye ame be lodl ovik,
# iter 64800, loss: [62.41433252]
#  orftath, de k ato.ou ive c foad ang la fuawlyqull himneh  wiem lossees; sunis fweevs k,  khte-re, yoe al upinteere Ged ce.
# G e ke his odes statou, hert have
# Amuar old ulngtat lnsstaon heetict lory of
# iter 64900, loss: [62.4779715]
# HOI:S:
# mye spanlaome, tooue you acanou tteasay,  poud the sne a notit lithadied, py Cdeative ovend keasted MLI:
# TLECZ:
# APhat tinFon trre!
# Voare,:
# Whe gall Marok srravigcet omo nf whal
# Mal ir.
# Iftaly b
# iter 65000, loss: [62.8064432]
# fend thast tou;
#
#
# LOMOMIND:
#
# O:
# Tojo thar ke; Eippit atit!-'s grapaiI h we yope and. k!heb
#
#
# Kmy b ino'd yeniempes, u d:icWiTILIOR:
# OMateet, w ew'ctaatinr,aad swo he them.
# Js nows.
#
# M howkniondgept be
# iter 65100, loss: [63.03849442]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[183], line 24
#      21   print(txt)
#      23 # forward seq_length characters through the net and fetch gradient
# ---> 24 xs, hf, hi, ho, hc, hs, cs, ys, ps, loss = step(inputs=inputs, targets=targets, W=W,
#      25                             vocab_size=vocab_size, hs=hs, cs=cs)
#      26 grads = grad(xs=xs, hf=hf, hi=hi, ho=ho, hc=hc, hs=hs, cs=cs, ps=ps, W=W, targets=targets)
#      28 hs = hs[len(targets)-1]
#
# Cell In[178], line 10, in step(inputs, targets, W, vocab_size, hs, cs)
#       8     input_char = inputs[t]
#       9     target_char = targets[t]
# ---> 10     xs[t], hf[t], hi[t], ho[t], hc[t], hs[t], cs[t], ys[t], ps[t], step_loss = one_step(input_char=input_char,
#      11                                                             target_char=target_char,
#      12                                                             W=W,
#      13                                                             vocab_size=vocab_size,
#      14                                                             hs=hs[t-1],
#      15                                                             cs=cs[t-1])
#      16     loss+=step_loss
#      18 return xs, hf, hi, ho, hc, hs, cs, ys, ps, loss
#
# Cell In[177], line 3, in one_step(input_char, target_char, W, vocab_size, hs, cs)
#       1 def one_step(input_char, target_char, W, vocab_size, hs, cs):
#       2     xs = encode(char=input_char, vocab_size=vocab_size)
# ----> 3     hf, hi, ho, hc, hs, cs, ys, ps = forward(xs, W, hs, cs)
#       4     loss = -np.log(ps[:,char_to_ix[target_char]])
#       5     return xs, hf, hi, ho, hc, hs, cs, ys, ps, loss
#
# Cell In[176], line 5, in forward(xs, W, hs, cs)
#       3 hf = sigmoid(np.dot(X, W['Wf']) + W['bf'])
#       4 hi = sigmoid(np.dot(X, W['Wi']) + W['bi'])
# ----> 5 ho = sigmoid(np.dot(X, W['Wo']) + W['bo'])
#       6 hc = sigmoid(np.dot(X, W['Wc']) + W['bc'])
#       7 cs = hf*cs + hi*hc
#
# KeyboardInterrupt:
